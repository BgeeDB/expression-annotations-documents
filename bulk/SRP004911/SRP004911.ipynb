# %% [markdown]
# ## SRP004911
#
# **paper:** [PMID: 22174244](https://pmc.ncbi.nlm.nih.gov/articles/PMC3264428/) - A natural deletion of the HoxC cluster in elasmobranch fishes, 2011
#
# **date, curator:** 2026-06-10, Sara Carsanaro
#
# **notes**
# * i do not know if organogenesis stage or late embryonic stage is more appropriate here, so just annotating as embryo stage

# %% [markdown]
# ### annotation summary

# %%
anat_summary = library_to_add[['infoOrgan', 'anatId', 'anatName', 'anatAnnotationStatus']]
unique_anat = anat_summary.drop_duplicates()
display_df(unique_anat)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_e4989">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4989_level0_col0" class="col_heading level0 col0" >infoOrgan</th>
#       <th id="T_e4989_level0_col1" class="col_heading level0 col1" >anatId</th>
#       <th id="T_e4989_level0_col2" class="col_heading level0 col2" >anatName</th>
#       <th id="T_e4989_level0_col3" class="col_heading level0 col3" >anatAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4989_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4989_row0_col0" class="data row0 col0" >embryo</td>
#       <td id="T_e4989_row0_col1" class="data row0 col1" >UBERON:0000922</td>
#       <td id="T_e4989_row0_col2" class="data row0 col2" >embryo</td>
#       <td id="T_e4989_row0_col3" class="data row0 col3" >perfect match</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dev_summary = library_to_add[['infoStage', 'stageId', 'stageName', 'stageAnnotationStatus']]
unique_dev = dev_summary.drop_duplicates()
display_df(unique_dev)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_33cbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33cbc_level0_col0" class="col_heading level0 col0" >infoStage</th>
#       <th id="T_33cbc_level0_col1" class="col_heading level0 col1" >stageId</th>
#       <th id="T_33cbc_level0_col2" class="col_heading level0 col2" >stageName</th>
#       <th id="T_33cbc_level0_col3" class="col_heading level0 col3" >stageAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33cbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33cbc_row0_col0" class="data row0 col0" >Stage 32 embryos</td>
#       <td id="T_33cbc_row0_col1" class="data row0 col1" >UBERON:0000068</td>
#       <td id="T_33cbc_row0_col2" class="data row0 col2" >embryo stage</td>
#       <td id="T_33cbc_row0_col3" class="data row0 col3" >missing child term</td>
#     </tr>
#     <tr>
#       <th id="T_33cbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33cbc_row1_col0" class="data row1 col0" >Stage 24-30 embryos</td>
#       <td id="T_33cbc_row1_col1" class="data row1 col1" >UBERON:0000068</td>
#       <td id="T_33cbc_row1_col2" class="data row1 col2" >embryo stage</td>
#       <td id="T_33cbc_row1_col3" class="data row1 col3" >missing child term</td>
#     </tr>
#     <tr>
#       <th id="T_33cbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33cbc_row2_col0" class="data row2 col0" >Stage 20-29 embryos</td>
#       <td id="T_33cbc_row2_col1" class="data row2 col1" >UBERON:0000068</td>
#       <td id="T_33cbc_row2_col2" class="data row2 col2" >embryo stage</td>
#       <td id="T_33cbc_row2_col3" class="data row2 col3" >missing child term</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### set variables, import packages, define functions

# %%
experiment_id = "SRP004911"

path_to_create_exp_script = "/Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py" 
experiment_type = "bulk"

path_to_output_main = "/Users/scarsana/Desktop/git/expression-annotations/Notebooks/bulk/" 
path_to_output = "{}{}/".format(path_to_output_main, experiment_id)
library_path_from_script = "{}RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_path_from_script = "{}RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
library_to_add_path = "{}complete_RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_to_add_path = "{}complete_RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
script_file = "{}.ipynb".format(experiment_id)
commit_message_exp = '"adding annotated bulk experiment {}"'.format(experiment_id)
commit_message_py = '"adding annotation files for {} to notebook folder"'.format(experiment_id)


## to add to git
path_to_git_annotations = "/Users/scarsana/Desktop/git/expression-annotations/RNA_Seq/"
git_library_path = "{}RNASeqLibrary.tsv".format(path_to_git_annotations)
git_experiment_path = "{}RNASeqExperiment.tsv".format(path_to_git_annotations)

## validation
path_to_v_script = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/validate_annotations.py'
path_to_rules = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/rules/'
val_output = "{}{}/validation.tsv".format(path_to_output_main, experiment_id)

library_cols = ['#libraryId', 'experimentId', 'platform', 'SRSId', 'anatId', 'anatName', 'stageId', 'stageName', 'url_GSM', 'infoOrgan', 'infoStage', 'anatAnnotationStatus', 'anatBiologicalStatus', 'stageAnnotationStatus', 'sex', 'strain', 'genotype', 'speciesId', 'protocol', 'protocolType', 'RNASelection', 'globin_reduction', 'replicate', 'lib_name', 'sampleName', 'sampleAge_value', 'sampleAge_unit', 'PATOid', 'PATOname','EFOid', 'EFOname','comment', 'condition', 'physiologicalStatus', 'annotatorId', 'lastModificationDate']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import os
import csv

# displays df with the scrollbar next to the DataFrame
def display_df(df):
    pd.set_option("display.max_rows", None)
    pd.set_option("display.max_columns", None)
    display(HTML("<div style='height: 300px; overflow: auto; width: fit-content'>" +
        df.style.to_html(index=False) + "</div>"))

# function that compares two columns in a dataframe and tells you which ones are not equal (case insensitive)
def compare_columns(df, col1, col2, return_col):
    compare_return = df[col1].str.lower() != df[col2].str.lower()  
    df.loc[compare_return, return_col] 
    if not any(compare_return):
        print("The two columns are equal (case insensitive)")
    else:
        print("The following rows are not equal: ")
        print(df.loc[compare_return, return_col])

# fixes formatting of file to match libreoffice settings/historic file format
def update_format(path):
    with open(path, 'r') as file:
        filedata = file.read()
    # Replace the target string
    filedata = filedata.replace("\t\"\"", "\t")
    # Write the file out again
    with open(path, 'w') as file:
        file.write(filedata)

# checks for duplicate values in a specific column and prints those values + the corresponding library id
def dup_check(df, column):
    duplicateCheck = df.duplicated(subset=[column], keep=False)
    duplicateCheck.sort_values(inplace=True)
    if duplicateCheck.unique().any() == False:
        print("no duplicate values in " + column)
    elif duplicateCheck.unique().any() == True and column != '#libraryId':
        dups = df[duplicateCheck].loc[:,['#libraryId', column]]
        df_dups = pd.DataFrame(dups)
        df_dups.sort_values(inplace=True, by=column)
        print(df_dups)
    elif duplicateCheck.unique().any() == True and column == '#libraryId':
        print(df[duplicateCheck].loc[:,['#libraryId']])

# prints all unique values in a specific column
def unique_sorted(df, column):
    unique = df[column].unique()
    unique.sort()
    print(unique)

# %% [markdown]
# ### script

# %%
! python3 $path_to_create_exp_script $experiment_id $path_to_output $experiment_type
# Out:
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:120: SyntaxWarning: invalid escape sequence '\('
#   all_protoc = [w.replace('(', '\(') for w in all_protoc]
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:121: SyntaxWarning: invalid escape sequence '\)'
#   all_protoc = [w.replace(')', '\)') for w in all_protoc]
# Be patient, it may take a few minutes.
# 10-Jun-2026 14:06:06 DEBUG utils - Directory ./ already exists. Skipping.
# 10-Jun-2026 14:06:06 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE26nnn/GSE26235/soft/GSE26235_family.soft.gz to ./GSE26235_family.soft.gz
# 100%|██████████████████████████████████████| 2.02k/2.02k [00:01<00:00, 1.25kB/s]
# 10-Jun-2026 14:06:08 DEBUG downloader - Size validation passed
# 10-Jun-2026 14:06:08 DEBUG downloader - Moving /var/folders/b5/crkp117d43q5mcndnwlrww3w0000gn/T/tmpyqmtf8ig to /Users/scarsana/Desktop/git/expression-annotations/Notebooks/bulk/SRP004911/GSE26235_family.soft.gz
# 10-Jun-2026 14:06:08 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE26nnn/GSE26235/soft/GSE26235_family.soft.gz
# 10-Jun-2026 14:06:08 INFO GEOparse - Parsing ./GSE26235_family.soft.gz:
# 10-Jun-2026 14:06:08 DEBUG GEOparse - DATABASE: GeoMiame
# 10-Jun-2026 14:06:08 DEBUG GEOparse - SERIES: GSE26235
# 10-Jun-2026 14:06:08 DEBUG GEOparse - PLATFORM: GPL11347
# 10-Jun-2026 14:06:08 DEBUG GEOparse - PLATFORM: GPL11348
# 10-Jun-2026 14:06:08 DEBUG GEOparse - PLATFORM: GPL11349
# 10-Jun-2026 14:06:08 DEBUG GEOparse - SAMPLE: GSM643957
# 10-Jun-2026 14:06:08 DEBUG GEOparse - SAMPLE: GSM643958
# 10-Jun-2026 14:06:08 DEBUG GEOparse - SAMPLE: GSM643959
# 0it [00:00, ?it/s]
# 0 samples dont have attributes, try to find them somewhere else
# 0it [00:00, ?it/s]
# 0 samples dont have attributes

# %% [markdown]
# ### library annnotations

# %%
library = pd.read_csv(library_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_9a0ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a0ed_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_9a0ed_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_9a0ed_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_9a0ed_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_9a0ed_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_9a0ed_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_9a0ed_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_9a0ed_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_9a0ed_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_9a0ed_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_9a0ed_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_9a0ed_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_9a0ed_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_9a0ed_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_9a0ed_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_9a0ed_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_9a0ed_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_9a0ed_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_9a0ed_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_9a0ed_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_9a0ed_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_9a0ed_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_9a0ed_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_9a0ed_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_9a0ed_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_9a0ed_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_9a0ed_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_9a0ed_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_9a0ed_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_9a0ed_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_9a0ed_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_9a0ed_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_9a0ed_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_9a0ed_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_9a0ed_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_9a0ed_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_9a0ed_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_9a0ed_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_9a0ed_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_9a0ed_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_9a0ed_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_9a0ed_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_9a0ed_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_9a0ed_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_9a0ed_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_9a0ed_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a0ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a0ed_row0_col0" class="data row0 col0" >SRX036538</td>
#       <td id="T_9a0ed_row0_col1" class="data row0 col1" >SRP004911</td>
#       <td id="T_9a0ed_row0_col2" class="data row0 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_9a0ed_row0_col3" class="data row0 col3" >SRS150646</td>
#       <td id="T_9a0ed_row0_col4" class="data row0 col4" ></td>
#       <td id="T_9a0ed_row0_col5" class="data row0 col5" ></td>
#       <td id="T_9a0ed_row0_col6" class="data row0 col6" ></td>
#       <td id="T_9a0ed_row0_col7" class="data row0 col7" ></td>
#       <td id="T_9a0ed_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643959</td>
#       <td id="T_9a0ed_row0_col9" class="data row0 col9" >embryo</td>
#       <td id="T_9a0ed_row0_col10" class="data row0 col10" >Stage 32 embryos</td>
#       <td id="T_9a0ed_row0_col11" class="data row0 col11" ></td>
#       <td id="T_9a0ed_row0_col12" class="data row0 col12" ></td>
#       <td id="T_9a0ed_row0_col13" class="data row0 col13" ></td>
#       <td id="T_9a0ed_row0_col14" class="data row0 col14" ></td>
#       <td id="T_9a0ed_row0_col15" class="data row0 col15" ></td>
#       <td id="T_9a0ed_row0_col16" class="data row0 col16" ></td>
#       <td id="T_9a0ed_row0_col17" class="data row0 col17" >7868</td>
#       <td id="T_9a0ed_row0_col18" class="data row0 col18" ></td>
#       <td id="T_9a0ed_row0_col19" class="data row0 col19" ></td>
#       <td id="T_9a0ed_row0_col20" class="data row0 col20" ></td>
#       <td id="T_9a0ed_row0_col21" class="data row0 col21" ></td>
#       <td id="T_9a0ed_row0_col22" class="data row0 col22" ></td>
#       <td id="T_9a0ed_row0_col23" class="data row0 col23" >Callorhinchus milii pooled Stage 32 embryos</td>
#       <td id="T_9a0ed_row0_col24" class="data row0 col24" >SAMN00188955,GSM643959</td>
#       <td id="T_9a0ed_row0_col25" class="data row0 col25" >32</td>
#       <td id="T_9a0ed_row0_col26" class="data row0 col26" >stage</td>
#       <td id="T_9a0ed_row0_col27" class="data row0 col27" ></td>
#       <td id="T_9a0ed_row0_col28" class="data row0 col28" ></td>
#       <td id="T_9a0ed_row0_col29" class="data row0 col29" ></td>
#       <td id="T_9a0ed_row0_col30" class="data row0 col30" ></td>
#       <td id="T_9a0ed_row0_col31" class="data row0 col31" ></td>
#       <td id="T_9a0ed_row0_col32" class="data row0 col32" ></td>
#       <td id="T_9a0ed_row0_col33" class="data row0 col33" ></td>
#       <td id="T_9a0ed_row0_col34" class="data row0 col34" ></td>
#       <td id="T_9a0ed_row0_col35" class="data row0 col35" >10/06/2026</td>
#       <td id="T_9a0ed_row0_col36" class="data row0 col36" >Total RNA was extracted using Tri Reagent (Ambion) from pooled tissue samples and converted into a library of template molecules using the mRNA-Seq Sample Prep Kit (Illumina) according to manufacturer's protocol.</td>
#       <td id="T_9a0ed_row0_col37" class="data row0 col37" ></td>
#       <td id="T_9a0ed_row0_col38" class="data row0 col38" >GSM643959</td>
#       <td id="T_9a0ed_row0_col39" class="data row0 col39" ></td>
#       <td id="T_9a0ed_row0_col40" class="data row0 col40" >Stage 32 embryonic</td>
#       <td id="T_9a0ed_row0_col41" class="data row0 col41" ></td>
#       <td id="T_9a0ed_row0_col42" class="data row0 col42" >Stage 32 embryos</td>
#       <td id="T_9a0ed_row0_col43" class="data row0 col43" ></td>
#       <td id="T_9a0ed_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_9a0ed_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_9a0ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a0ed_row1_col0" class="data row1 col0" >SRX036537</td>
#       <td id="T_9a0ed_row1_col1" class="data row1 col1" >SRP004911</td>
#       <td id="T_9a0ed_r

# %% [markdown]
# #### anatomical entity
# * [uberon ols](https://www.ebi.ac.uk/ols4/ontologies/uberon)

# %%
unique_sorted(library, "infoOrgan")
# Out:
# ['embryo']

# %%
# all
library.loc[:,'anatId'] = 'UBERON:0000922'
library.loc[:,'anatName'] = 'embryo'
# perfect match, missing child term, other
library.loc[:,'anatAnnotationStatus'] = 'perfect match'
# partial sampling, full sampling, not documented
library.loc[:,'anatBiologicalStatus'] = 'not documented'


# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_d4b62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4b62_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_d4b62_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_d4b62_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_d4b62_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_d4b62_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_d4b62_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_d4b62_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_d4b62_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_d4b62_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_d4b62_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_d4b62_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_d4b62_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_d4b62_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_d4b62_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_d4b62_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_d4b62_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_d4b62_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_d4b62_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_d4b62_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_d4b62_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_d4b62_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_d4b62_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_d4b62_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_d4b62_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_d4b62_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_d4b62_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_d4b62_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_d4b62_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_d4b62_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_d4b62_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_d4b62_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_d4b62_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_d4b62_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_d4b62_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_d4b62_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_d4b62_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_d4b62_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_d4b62_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_d4b62_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_d4b62_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_d4b62_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_d4b62_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_d4b62_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_d4b62_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_d4b62_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_d4b62_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4b62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4b62_row0_col0" class="data row0 col0" >SRX036538</td>
#       <td id="T_d4b62_row0_col1" class="data row0 col1" >SRP004911</td>
#       <td id="T_d4b62_row0_col2" class="data row0 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_d4b62_row0_col3" class="data row0 col3" >SRS150646</td>
#       <td id="T_d4b62_row0_col4" class="data row0 col4" >UBERON:0000922</td>
#       <td id="T_d4b62_row0_col5" class="data row0 col5" >embryo</td>
#       <td id="T_d4b62_row0_col6" class="data row0 col6" ></td>
#       <td id="T_d4b62_row0_col7" class="data row0 col7" ></td>
#       <td id="T_d4b62_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643959</td>
#       <td id="T_d4b62_row0_col9" class="data row0 col9" >embryo</td>
#       <td id="T_d4b62_row0_col10" class="data row0 col10" >Stage 32 embryos</td>
#       <td id="T_d4b62_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_d4b62_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_d4b62_row0_col13" class="data row0 col13" ></td>
#       <td id="T_d4b62_row0_col14" class="data row0 col14" ></td>
#       <td id="T_d4b62_row0_col15" class="data row0 col15" ></td>
#       <td id="T_d4b62_row0_col16" class="data row0 col16" ></td>
#       <td id="T_d4b62_row0_col17" class="data row0 col17" >7868</td>
#       <td id="T_d4b62_row0_col18" class="data row0 col18" ></td>
#       <td id="T_d4b62_row0_col19" class="data row0 col19" ></td>
#       <td id="T_d4b62_row0_col20" class="data row0 col20" ></td>
#       <td id="T_d4b62_row0_col21" class="data row0 col21" ></td>
#       <td id="T_d4b62_row0_col22" class="data row0 col22" ></td>
#       <td id="T_d4b62_row0_col23" class="data row0 col23" >Callorhinchus milii pooled Stage 32 embryos</td>
#       <td id="T_d4b62_row0_col24" class="data row0 col24" >SAMN00188955,GSM643959</td>
#       <td id="T_d4b62_row0_col25" class="data row0 col25" >32</td>
#       <td id="T_d4b62_row0_col26" class="data row0 col26" >stage</td>
#       <td id="T_d4b62_row0_col27" class="data row0 col27" ></td>
#       <td id="T_d4b62_row0_col28" class="data row0 col28" ></td>
#       <td id="T_d4b62_row0_col29" class="data row0 col29" ></td>
#       <td id="T_d4b62_row0_col30" class="data row0 col30" ></td>
#       <td id="T_d4b62_row0_col31" class="data row0 col31" ></td>
#       <td id="T_d4b62_row0_col32" class="data row0 col32" ></td>
#       <td id="T_d4b62_row0_col33" class="data row0 col33" ></td>
#       <td id="T_d4b62_row0_col34" class="data row0 col34" ></td>
#       <td id="T_d4b62_row0_col35" class="data row0 col35" >10/06/2026</td>
#       <td id="T_d4b62_row0_col36" class="data row0 col36" >Total RNA was extracted using Tri Reagent (Ambion) from pooled tissue samples and converted into a library of template molecules using the mRNA-Seq Sample Prep Kit (Illumina) according to manufacturer's protocol.</td>
#       <td id="T_d4b62_row0_col37" class="data row0 col37" ></td>
#       <td id="T_d4b62_row0_col38" class="data row0 col38" >GSM643959</td>
#       <td id="T_d4b62_row0_col39" class="data row0 col39" ></td>
#       <td id="T_d4b62_row0_col40" class="data row0 col40" >Stage 32 embryonic</td>
#       <td id="T_d4b62_row0_col41" class="data row0 col41" ></td>
#       <td id="T_d4b62_row0_col42" class="data row0 col42" >Stage 32 embryos</td>
#       <td id="T_d4b62_row0_col43" class="data row0 col43" ></td>
#       <td id="T_d4b62_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_d4b62_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_d4b62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4b62_row1_col0" class="data row1 col0" >SRX036537</td>
#       <td id="T_d4b62_row1_col1" class="data row

# %% [markdown]
# #### stage
# - [species specific developmental ontologies](https://github.com/obophenotype/developmental-stage-ontologies/tree/master/src/ontology/components)

# %%
unique_sorted(library, "infoStage")
# Out:
# ['Stage 20-29 embryos' 'Stage 24-30 embryos' 'Stage 32 embryos']

# %%
# all
library.loc[:,'stageId'] = 'UBERON:0000068'
library.loc[:,'stageName'] = 'embryo stage'
# perfect match, missing child term, other
library.loc[:,'stageAnnotationStatus'] = 'missing child term'



# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_1dce8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dce8_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_1dce8_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_1dce8_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_1dce8_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_1dce8_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_1dce8_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_1dce8_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_1dce8_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_1dce8_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_1dce8_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_1dce8_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_1dce8_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_1dce8_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_1dce8_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_1dce8_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_1dce8_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_1dce8_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_1dce8_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_1dce8_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_1dce8_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_1dce8_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_1dce8_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_1dce8_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_1dce8_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_1dce8_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_1dce8_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_1dce8_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_1dce8_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_1dce8_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_1dce8_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_1dce8_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_1dce8_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_1dce8_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_1dce8_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_1dce8_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_1dce8_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_1dce8_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_1dce8_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_1dce8_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_1dce8_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_1dce8_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_1dce8_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_1dce8_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_1dce8_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_1dce8_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_1dce8_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dce8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1dce8_row0_col0" class="data row0 col0" >SRX036538</td>
#       <td id="T_1dce8_row0_col1" class="data row0 col1" >SRP004911</td>
#       <td id="T_1dce8_row0_col2" class="data row0 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_1dce8_row0_col3" class="data row0 col3" >SRS150646</td>
#       <td id="T_1dce8_row0_col4" class="data row0 col4" >UBERON:0000922</td>
#       <td id="T_1dce8_row0_col5" class="data row0 col5" >embryo</td>
#       <td id="T_1dce8_row0_col6" class="data row0 col6" >UBERON:0000068</td>
#       <td id="T_1dce8_row0_col7" class="data row0 col7" >embryo stage</td>
#       <td id="T_1dce8_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643959</td>
#       <td id="T_1dce8_row0_col9" class="data row0 col9" >embryo</td>
#       <td id="T_1dce8_row0_col10" class="data row0 col10" >Stage 32 embryos</td>
#       <td id="T_1dce8_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_1dce8_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_1dce8_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_1dce8_row0_col14" class="data row0 col14" ></td>
#       <td id="T_1dce8_row0_col15" class="data row0 col15" ></td>
#       <td id="T_1dce8_row0_col16" class="data row0 col16" ></td>
#       <td id="T_1dce8_row0_col17" class="data row0 col17" >7868</td>
#       <td id="T_1dce8_row0_col18" class="data row0 col18" ></td>
#       <td id="T_1dce8_row0_col19" class="data row0 col19" ></td>
#       <td id="T_1dce8_row0_col20" class="data row0 col20" ></td>
#       <td id="T_1dce8_row0_col21" class="data row0 col21" ></td>
#       <td id="T_1dce8_row0_col22" class="data row0 col22" ></td>
#       <td id="T_1dce8_row0_col23" class="data row0 col23" >Callorhinchus milii pooled Stage 32 embryos</td>
#       <td id="T_1dce8_row0_col24" class="data row0 col24" >SAMN00188955,GSM643959</td>
#       <td id="T_1dce8_row0_col25" class="data row0 col25" >32</td>
#       <td id="T_1dce8_row0_col26" class="data row0 col26" >stage</td>
#       <td id="T_1dce8_row0_col27" class="data row0 col27" ></td>
#       <td id="T_1dce8_row0_col28" class="data row0 col28" ></td>
#       <td id="T_1dce8_row0_col29" class="data row0 col29" ></td>
#       <td id="T_1dce8_row0_col30" class="data row0 col30" ></td>
#       <td id="T_1dce8_row0_col31" class="data row0 col31" ></td>
#       <td id="T_1dce8_row0_col32" class="data row0 col32" ></td>
#       <td id="T_1dce8_row0_col33" class="data row0 col33" ></td>
#       <td id="T_1dce8_row0_col34" class="data row0 col34" ></td>
#       <td id="T_1dce8_row0_col35" class="data row0 col35" >10/06/2026</td>
#       <td id="T_1dce8_row0_col36" class="data row0 col36" >Total RNA was extracted using Tri Reagent (Ambion) from pooled tissue samples and converted into a library of template molecules using the mRNA-Seq Sample Prep Kit (Illumina) according to manufacturer's protocol.</td>
#       <td id="T_1dce8_row0_col37" class="data row0 col37" ></td>
#       <td id="T_1dce8_row0_col38" class="data row0 col38" >GSM643959</td>
#       <td id="T_1dce8_row0_col39" class="data row0 col39" ></td>
#       <td id="T_1dce8_row0_col40" class="data row0 col40" >Stage 32 embryonic</td>
#       <td id="T_1dce8_row0_col41" class="data row0 col41" ></td>
#       <td id="T_1dce8_row0_col42" class="data row0 col42" >Stage 32 embryos</td>
#       <td id="T_1dce8_row0_col43" class="data row0 col43" ></td>
#       <td id="T_1dce8_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_1dce8_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_1dce8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1dce8_row1_col0" class="data row1 col0" >SRX036537</td>

# %% [markdown]
# #### sex, strain, genotype, speciesId
# - uniprot [strain list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/strains)
# - uniprot [species list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/speclist)
# - bgee [strain mapping](https://gitlab.sib.swiss/Bgee/expression-annotations/-/tree/develop/Strains?ref_type=heads)

# %%
library.loc[:,'sex'] = 'NA'
#library.loc[library["sex"] == "male", "sex"] = "M"
#library.loc[library["sex"] == "female", "sex"] = "F"

#library.loc[:,'strain'] = ''

#library.loc[:,'genotype'] = ''

#library.loc[:,'speciesId'] = ''

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_80838">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80838_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_80838_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_80838_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_80838_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_80838_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_80838_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_80838_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_80838_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_80838_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_80838_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_80838_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_80838_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_80838_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_80838_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_80838_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_80838_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_80838_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_80838_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_80838_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_80838_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_80838_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_80838_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_80838_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_80838_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_80838_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_80838_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_80838_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_80838_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_80838_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_80838_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_80838_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_80838_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_80838_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_80838_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_80838_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_80838_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_80838_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_80838_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_80838_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_80838_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_80838_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_80838_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_80838_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_80838_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_80838_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_80838_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80838_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80838_row0_col0" class="data row0 col0" >SRX036538</td>
#       <td id="T_80838_row0_col1" class="data row0 col1" >SRP004911</td>
#       <td id="T_80838_row0_col2" class="data row0 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_80838_row0_col3" class="data row0 col3" >SRS150646</td>
#       <td id="T_80838_row0_col4" class="data row0 col4" >UBERON:0000922</td>
#       <td id="T_80838_row0_col5" class="data row0 col5" >embryo</td>
#       <td id="T_80838_row0_col6" class="data row0 col6" >UBERON:0000068</td>
#       <td id="T_80838_row0_col7" class="data row0 col7" >embryo stage</td>
#       <td id="T_80838_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643959</td>
#       <td id="T_80838_row0_col9" class="data row0 col9" >embryo</td>
#       <td id="T_80838_row0_col10" class="data row0 col10" >Stage 32 embryos</td>
#       <td id="T_80838_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_80838_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_80838_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_80838_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_80838_row0_col15" class="data row0 col15" ></td>
#       <td id="T_80838_row0_col16" class="data row0 col16" ></td>
#       <td id="T_80838_row0_col17" class="data row0 col17" >7868</td>
#       <td id="T_80838_row0_col18" class="data row0 col18" ></td>
#       <td id="T_80838_row0_col19" class="data row0 col19" ></td>
#       <td id="T_80838_row0_col20" class="data row0 col20" ></td>
#       <td id="T_80838_row0_col21" class="data row0 col21" ></td>
#       <td id="T_80838_row0_col22" class="data row0 col22" ></td>
#       <td id="T_80838_row0_col23" class="data row0 col23" >Callorhinchus milii pooled Stage 32 embryos</td>
#       <td id="T_80838_row0_col24" class="data row0 col24" >SAMN00188955,GSM643959</td>
#       <td id="T_80838_row0_col25" class="data row0 col25" >32</td>
#       <td id="T_80838_row0_col26" class="data row0 col26" >stage</td>
#       <td id="T_80838_row0_col27" class="data row0 col27" ></td>
#       <td id="T_80838_row0_col28" class="data row0 col28" ></td>
#       <td id="T_80838_row0_col29" class="data row0 col29" ></td>
#       <td id="T_80838_row0_col30" class="data row0 col30" ></td>
#       <td id="T_80838_row0_col31" class="data row0 col31" ></td>
#       <td id="T_80838_row0_col32" class="data row0 col32" ></td>
#       <td id="T_80838_row0_col33" class="data row0 col33" ></td>
#       <td id="T_80838_row0_col34" class="data row0 col34" ></td>
#       <td id="T_80838_row0_col35" class="data row0 col35" >10/06/2026</td>
#       <td id="T_80838_row0_col36" class="data row0 col36" >Total RNA was extracted using Tri Reagent (Ambion) from pooled tissue samples and converted into a library of template molecules using the mRNA-Seq Sample Prep Kit (Illumina) according to manufacturer's protocol.</td>
#       <td id="T_80838_row0_col37" class="data row0 col37" ></td>
#       <td id="T_80838_row0_col38" class="data row0 col38" >GSM643959</td>
#       <td id="T_80838_row0_col39" class="data row0 col39" ></td>
#       <td id="T_80838_row0_col40" class="data row0 col40" >Stage 32 embryonic</td>
#       <td id="T_80838_row0_col41" class="data row0 col41" ></td>
#       <td id="T_80838_row0_col42" class="data row0 col42" >Stage 32 embryos</td>
#       <td id="T_80838_row0_col43" class="data row0 col43" ></td>
#       <td id="T_80838_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_80838_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_80838_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80838_row1_col0" class="data row1 col0" >SRX036537</td>

# %% [markdown]
# #### protocol
# see [bulk kits](https://gitlab.sib.swiss/Bgee/scRNA-Seq/-/blob/main/scripts/bulk_kits.csv) for some common protocols

# %%
# making these variables because we use them again in the experiment file
my_protocol = 'mRNA-seq Library Prep Kit for Illumina'
# full_length or 3'
my_protocolType = 'full_length'

library.loc[:,'protocol'] = my_protocol
library.loc[:,'protocolType'] = my_protocolType
# polyA, ribo-minus, miRNA, lncRNA, circRNA
library.loc[:,'RNASelection'] = 'polyA'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_fff2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fff2c_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_fff2c_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_fff2c_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_fff2c_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_fff2c_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_fff2c_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_fff2c_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_fff2c_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_fff2c_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_fff2c_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_fff2c_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_fff2c_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_fff2c_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_fff2c_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_fff2c_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_fff2c_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_fff2c_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_fff2c_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_fff2c_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_fff2c_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_fff2c_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_fff2c_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_fff2c_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_fff2c_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_fff2c_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_fff2c_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_fff2c_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_fff2c_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_fff2c_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_fff2c_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_fff2c_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_fff2c_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_fff2c_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_fff2c_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_fff2c_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_fff2c_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_fff2c_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_fff2c_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_fff2c_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_fff2c_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_fff2c_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_fff2c_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_fff2c_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_fff2c_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_fff2c_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_fff2c_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fff2c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fff2c_row0_col0" class="data row0 col0" >SRX036538</td>
#       <td id="T_fff2c_row0_col1" class="data row0 col1" >SRP004911</td>
#       <td id="T_fff2c_row0_col2" class="data row0 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_fff2c_row0_col3" class="data row0 col3" >SRS150646</td>
#       <td id="T_fff2c_row0_col4" class="data row0 col4" >UBERON:0000922</td>
#       <td id="T_fff2c_row0_col5" class="data row0 col5" >embryo</td>
#       <td id="T_fff2c_row0_col6" class="data row0 col6" >UBERON:0000068</td>
#       <td id="T_fff2c_row0_col7" class="data row0 col7" >embryo stage</td>
#       <td id="T_fff2c_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643959</td>
#       <td id="T_fff2c_row0_col9" class="data row0 col9" >embryo</td>
#       <td id="T_fff2c_row0_col10" class="data row0 col10" >Stage 32 embryos</td>
#       <td id="T_fff2c_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_fff2c_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_fff2c_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_fff2c_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_fff2c_row0_col15" class="data row0 col15" ></td>
#       <td id="T_fff2c_row0_col16" class="data row0 col16" ></td>
#       <td id="T_fff2c_row0_col17" class="data row0 col17" >7868</td>
#       <td id="T_fff2c_row0_col18" class="data row0 col18" >mRNA-seq Library Prep Kit for Illumina</td>
#       <td id="T_fff2c_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_fff2c_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_fff2c_row0_col21" class="data row0 col21" ></td>
#       <td id="T_fff2c_row0_col22" class="data row0 col22" ></td>
#       <td id="T_fff2c_row0_col23" class="data row0 col23" >Callorhinchus milii pooled Stage 32 embryos</td>
#       <td id="T_fff2c_row0_col24" class="data row0 col24" >SAMN00188955,GSM643959</td>
#       <td id="T_fff2c_row0_col25" class="data row0 col25" >32</td>
#       <td id="T_fff2c_row0_col26" class="data row0 col26" >stage</td>
#       <td id="T_fff2c_row0_col27" class="data row0 col27" ></td>
#       <td id="T_fff2c_row0_col28" class="data row0 col28" ></td>
#       <td id="T_fff2c_row0_col29" class="data row0 col29" ></td>
#       <td id="T_fff2c_row0_col30" class="data row0 col30" ></td>
#       <td id="T_fff2c_row0_col31" class="data row0 col31" ></td>
#       <td id="T_fff2c_row0_col32" class="data row0 col32" ></td>
#       <td id="T_fff2c_row0_col33" class="data row0 col33" ></td>
#       <td id="T_fff2c_row0_col34" class="data row0 col34" ></td>
#       <td id="T_fff2c_row0_col35" class="data row0 col35" >10/06/2026</td>
#       <td id="T_fff2c_row0_col36" class="data row0 col36" >Total RNA was extracted using Tri Reagent (Ambion) from pooled tissue samples and converted into a library of template molecules using the mRNA-Seq Sample Prep Kit (Illumina) according to manufacturer's protocol.</td>
#       <td id="T_fff2c_row0_col37" class="data row0 col37" ></td>
#       <td id="T_fff2c_row0_col38" class="data row0 col38" >GSM643959</td>
#       <td id="T_fff2c_row0_col39" class="data row0 col39" ></td>
#       <td id="T_fff2c_row0_col40" class="data row0 col40" >Stage 32 embryonic</td>
#       <td id="T_fff2c_row0_col41" class="data row0 col41" ></td>
#       <td id="T_fff2c_row0_col42" class="data row0 col42" >Stage 32 embryos</td>
#       <td id="T_fff2c_row0_col43" class="data row0 col43" ></td>
#       <td id="T_fff2c_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_fff2c_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_fff2c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fff2

# %% [markdown]
# #### globin, replicates

# %%
# check for duplicate SRSId values
dup_check(library, "SRSId")
# Out:
# no duplicate values in SRSId

# %%
#library.loc[:,'globin_reduction'] = 'Y'

# replicates
#library.loc[library["#libraryId"] == "old", "replicate"] = "1"
#library.loc[library["#libraryId"].isin(["one", "two"]), "replicate"] = "1"

# view
display_df(library)

# %% [markdown]
# #### sample age, pato, physiological status
# * [PATO](https://www.ebi.ac.uk/ols4/ontologies/pato)
# * [EFO](https://www.ebi.ac.uk/ols4/ontologies/efo)

# %%
#library.loc[:,'sampleAge_value'] = ''
#library.loc[:,'sampleAge_unit'] = ''

# ex. castrated male
#library.loc[:,'PATOid'] = ''
#library.loc[:,'PATOname'] = ''

# ex. castrated, pregnant, pre-smoltification, post-smoltification, laying eggs
#library.loc[:,'physiologicalStatus'] = ''

# ex. left, right
#library.loc[:,'EFOid'] = ''
#library.loc[:,'EFOname'] = ''

# view
display_df(library)

# %% [markdown]
# #### condition

# %%
# ex. control, diet, light, reproductive capacity, time post mortem, time post feeding, 
# exercise details, menstruation, personality, litter size 
#library.loc[library["condition"] == "old", "condition"] = "new"

# view
display_df(library)

# %% [markdown]
# #### annotator id, last modification date

# %%
library.loc[:,'annotatorId'] = 'SAC'
library.loc[:,'lastModificationDate'] = '2026-06-10'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_18cac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18cac_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_18cac_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_18cac_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_18cac_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_18cac_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_18cac_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_18cac_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_18cac_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_18cac_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_18cac_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_18cac_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_18cac_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_18cac_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_18cac_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_18cac_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_18cac_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_18cac_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_18cac_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_18cac_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_18cac_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_18cac_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_18cac_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_18cac_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_18cac_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_18cac_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_18cac_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_18cac_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_18cac_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_18cac_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_18cac_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_18cac_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_18cac_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_18cac_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_18cac_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_18cac_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_18cac_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_18cac_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_18cac_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_18cac_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_18cac_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_18cac_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_18cac_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_18cac_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_18cac_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_18cac_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_18cac_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18cac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18cac_row0_col0" class="data row0 col0" >SRX036538</td>
#       <td id="T_18cac_row0_col1" class="data row0 col1" >SRP004911</td>
#       <td id="T_18cac_row0_col2" class="data row0 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_18cac_row0_col3" class="data row0 col3" >SRS150646</td>
#       <td id="T_18cac_row0_col4" class="data row0 col4" >UBERON:0000922</td>
#       <td id="T_18cac_row0_col5" class="data row0 col5" >embryo</td>
#       <td id="T_18cac_row0_col6" class="data row0 col6" >UBERON:0000068</td>
#       <td id="T_18cac_row0_col7" class="data row0 col7" >embryo stage</td>
#       <td id="T_18cac_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643959</td>
#       <td id="T_18cac_row0_col9" class="data row0 col9" >embryo</td>
#       <td id="T_18cac_row0_col10" class="data row0 col10" >Stage 32 embryos</td>
#       <td id="T_18cac_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_18cac_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_18cac_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_18cac_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_18cac_row0_col15" class="data row0 col15" ></td>
#       <td id="T_18cac_row0_col16" class="data row0 col16" ></td>
#       <td id="T_18cac_row0_col17" class="data row0 col17" >7868</td>
#       <td id="T_18cac_row0_col18" class="data row0 col18" >mRNA-seq Library Prep Kit for Illumina</td>
#       <td id="T_18cac_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_18cac_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_18cac_row0_col21" class="data row0 col21" ></td>
#       <td id="T_18cac_row0_col22" class="data row0 col22" ></td>
#       <td id="T_18cac_row0_col23" class="data row0 col23" >Callorhinchus milii pooled Stage 32 embryos</td>
#       <td id="T_18cac_row0_col24" class="data row0 col24" >SAMN00188955,GSM643959</td>
#       <td id="T_18cac_row0_col25" class="data row0 col25" >32</td>
#       <td id="T_18cac_row0_col26" class="data row0 col26" >stage</td>
#       <td id="T_18cac_row0_col27" class="data row0 col27" ></td>
#       <td id="T_18cac_row0_col28" class="data row0 col28" ></td>
#       <td id="T_18cac_row0_col29" class="data row0 col29" ></td>
#       <td id="T_18cac_row0_col30" class="data row0 col30" ></td>
#       <td id="T_18cac_row0_col31" class="data row0 col31" ></td>
#       <td id="T_18cac_row0_col32" class="data row0 col32" ></td>
#       <td id="T_18cac_row0_col33" class="data row0 col33" ></td>
#       <td id="T_18cac_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_18cac_row0_col35" class="data row0 col35" >2026-06-10</td>
#       <td id="T_18cac_row0_col36" class="data row0 col36" >Total RNA was extracted using Tri Reagent (Ambion) from pooled tissue samples and converted into a library of template molecules using the mRNA-Seq Sample Prep Kit (Illumina) according to manufacturer's protocol.</td>
#       <td id="T_18cac_row0_col37" class="data row0 col37" ></td>
#       <td id="T_18cac_row0_col38" class="data row0 col38" >GSM643959</td>
#       <td id="T_18cac_row0_col39" class="data row0 col39" ></td>
#       <td id="T_18cac_row0_col40" class="data row0 col40" >Stage 32 embryonic</td>
#       <td id="T_18cac_row0_col41" class="data row0 col41" ></td>
#       <td id="T_18cac_row0_col42" class="data row0 col42" >Stage 32 embryos</td>
#       <td id="T_18cac_row0_col43" class="data row0 col43" ></td>
#       <td id="T_18cac_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_18cac_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_18cac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1

# %% [markdown]
# #### comments

# %%
library.loc[:,'comment'] = 'PMID: 22174244'

# %% [markdown]
# #### save complete file with correct columns

# %%
library_file_complete = library[library_cols]
library_file_complete.to_csv(library_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# view
display_df(library_file_complete)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_07ef4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07ef4_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_07ef4_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_07ef4_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_07ef4_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_07ef4_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_07ef4_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_07ef4_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_07ef4_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_07ef4_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_07ef4_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_07ef4_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_07ef4_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_07ef4_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_07ef4_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_07ef4_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_07ef4_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_07ef4_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_07ef4_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_07ef4_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_07ef4_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_07ef4_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_07ef4_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_07ef4_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_07ef4_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_07ef4_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_07ef4_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_07ef4_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_07ef4_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_07ef4_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_07ef4_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_07ef4_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_07ef4_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_07ef4_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_07ef4_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_07ef4_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_07ef4_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07ef4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07ef4_row0_col0" class="data row0 col0" >SRX036538</td>
#       <td id="T_07ef4_row0_col1" class="data row0 col1" >SRP004911</td>
#       <td id="T_07ef4_row0_col2" class="data row0 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_07ef4_row0_col3" class="data row0 col3" >SRS150646</td>
#       <td id="T_07ef4_row0_col4" class="data row0 col4" >UBERON:0000922</td>
#       <td id="T_07ef4_row0_col5" class="data row0 col5" >embryo</td>
#       <td id="T_07ef4_row0_col6" class="data row0 col6" >UBERON:0000068</td>
#       <td id="T_07ef4_row0_col7" class="data row0 col7" >embryo stage</td>
#       <td id="T_07ef4_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643959</td>
#       <td id="T_07ef4_row0_col9" class="data row0 col9" >embryo</td>
#       <td id="T_07ef4_row0_col10" class="data row0 col10" >Stage 32 embryos</td>
#       <td id="T_07ef4_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_07ef4_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_07ef4_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_07ef4_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_07ef4_row0_col15" class="data row0 col15" ></td>
#       <td id="T_07ef4_row0_col16" class="data row0 col16" ></td>
#       <td id="T_07ef4_row0_col17" class="data row0 col17" >7868</td>
#       <td id="T_07ef4_row0_col18" class="data row0 col18" >mRNA-seq Library Prep Kit for Illumina</td>
#       <td id="T_07ef4_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_07ef4_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_07ef4_row0_col21" class="data row0 col21" ></td>
#       <td id="T_07ef4_row0_col22" class="data row0 col22" ></td>
#       <td id="T_07ef4_row0_col23" class="data row0 col23" >Callorhinchus milii pooled Stage 32 embryos</td>
#       <td id="T_07ef4_row0_col24" class="data row0 col24" >SAMN00188955,GSM643959</td>
#       <td id="T_07ef4_row0_col25" class="data row0 col25" >32</td>
#       <td id="T_07ef4_row0_col26" class="data row0 col26" >stage</td>
#       <td id="T_07ef4_row0_col27" class="data row0 col27" ></td>
#       <td id="T_07ef4_row0_col28" class="data row0 col28" ></td>
#       <td id="T_07ef4_row0_col29" class="data row0 col29" ></td>
#       <td id="T_07ef4_row0_col30" class="data row0 col30" ></td>
#       <td id="T_07ef4_row0_col31" class="data row0 col31" >PMID: 22174244</td>
#       <td id="T_07ef4_row0_col32" class="data row0 col32" ></td>
#       <td id="T_07ef4_row0_col33" class="data row0 col33" ></td>
#       <td id="T_07ef4_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_07ef4_row0_col35" class="data row0 col35" >2026-06-10</td>
#     </tr>
#     <tr>
#       <th id="T_07ef4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07ef4_row1_col0" class="data row1 col0" >SRX036537</td>
#       <td id="T_07ef4_row1_col1" class="data row1 col1" >SRP004911</td>
#       <td id="T_07ef4_row1_col2" class="data row1 col2" >Illumina Genome Analyzer II</td>
#       <td id="T_07ef4_row1_col3" class="data row1 col3" >SRS150645</td>
#       <td id="T_07ef4_row1_col4" class="data row1 col4" >UBERON:0000922</td>
#       <td id="T_07ef4_row1_col5" class="data row1 col5" >embryo</td>
#       <td id="T_07ef4_row1_col6" class="data row1 col6" >UBERON:0000068</td>
#       <td id="T_07ef4_row1_col7" class="data row1 col7" >embryo stage</td>
#       <td id="T_07ef4_row1_col8" class="data row1 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM643958</td>
#       <td id="T_07ef4_row1_col9" class="data row1 col9" >embryo</td>
#       <td id="T_07ef4_row1_col10" class="data row1 col10" >Stage 24-30 embryos</td>
#       <td id="T_07ef4_row1_col11" class="data row1 col11" >perfect match</td>
#       <td id="T_07ef4_row1_col12" class="data row1 col12" >not documented</td>
#       <td id="T_07ef4_row1_col13" class="data row1 col13" >missing child term</td>
#       <td id="T_07ef4_row1_col14" class="data row1 col14" >NA</td>
#       <td id="T_07ef4_row1_col15" class="data row1 col15" ></td>
#       <td id="T_07ef4_row1_col16" class="data row1 col16" ></td>
#       <td id="T_07ef4_row1_col17" class="data row1 col17" >7830</td>
#       <td id="T_07ef4_row1_col18" class="data row1 col18" >mRNA-seq Library Prep Kit for Illumina</td>
#       <td id="T_07ef4_row1_col19" class="data row1 col19" >full_length</td>
#       <td id="T_07ef4_row1_col20" class="data row1 col20" >polyA</td>
#       <td id="T_07ef4_row1_col21" class="data row1 col21" ></td>
#       <td id="T_07ef4_row1_col22" class="data row1 col22" ></td>
#       <td id="T_07ef4_row1_col23" class="data row1 co

# %% [markdown]
# ### experiment annotations

# %%
experiment = pd.read_csv(experiment_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_4428b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4428b_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_4428b_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_4428b_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_4428b_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_4428b_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_4428b_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_4428b_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_4428b_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_4428b_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_4428b_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_4428b_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_4428b_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_4428b_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_4428b_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_4428b_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_4428b_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4428b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4428b_row0_col0" class="data row0 col0" >SRP004911</td>
#       <td id="T_4428b_row0_col1" class="data row0 col1" >Late-stage embryonic gene expression in three cartilaginous fishes</td>
#       <td id="T_4428b_row0_col2" class="data row0 col2" >Gene expression profiling of pooled late stage embryos from Leucoraja erinacea, Scyliorhinus canicula and Callorhinchus milii show that HOXC cluster genes are not expressed in the two elasmobranch fishes, L. erinacea and S. canicula. This finding supports the observations that these genes are not found in whole genome shotgun sequencing of L. erinacea or genomic clones from S. canicula. Overall design: Profile gene expression in pooled late stage embryos from three species (L. erinacea, S. canicula and C. milii)</td>
#       <td id="T_4428b_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_4428b_row0_col4" class="data row0 col4" ></td>
#       <td id="T_4428b_row0_col5" class="data row0 col5" ></td>
#       <td id="T_4428b_row0_col6" class="data row0 col6" ></td>
#       <td id="T_4428b_row0_col7" class="data row0 col7" ></td>
#       <td id="T_4428b_row0_col8" class="data row0 col8" ></td>
#       <td id="T_4428b_row0_col9" class="data row0 col9" >GSE26235</td>
#       <td id="T_4428b_row0_col10" class="data row0 col10" >PRJNA135005</td>
#       <td id="T_4428b_row0_col11" class="data row0 col11" >22174244, 25309735</td>
#       <td id="T_4428b_row0_col12" class="data row0 col12" ></td>
#       <td id="T_4428b_row0_col13" class="data row0 col13" >10.1126/science.1210912,10.12688/f1000research.4996.1</td>
#       <td id="T_4428b_row0_col14" class="data row0 col14" ></td>
#       <td id="T_4428b_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### experiment and protocol details

# %%
# this will give you the number of rows in the complete library file 
# this should be the number of annotated libraries
ann_lib = len(library_file_complete.index)
len(library_file_complete.index)
# Out:
# 3

# %%
# partial or total
experiment.loc[:,'experimentStatus'] = 'total'
# Bgee 1K
experiment.loc[:,'projectTags'] = 'Bgee 1K' 
# see above cell, also can add as free text
experiment.loc[:,'numberOfAnnotatedLibraries'] = ann_lib

# these variables should already exist from above but if not can just add as free text
experiment.loc[:,'protocol'] = my_protocol
experiment.loc[:,'protocolType'] = my_protocolType

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_a507c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a507c_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_a507c_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_a507c_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_a507c_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_a507c_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_a507c_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_a507c_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_a507c_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_a507c_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_a507c_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_a507c_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_a507c_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_a507c_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_a507c_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_a507c_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_a507c_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a507c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a507c_row0_col0" class="data row0 col0" >SRP004911</td>
#       <td id="T_a507c_row0_col1" class="data row0 col1" >Late-stage embryonic gene expression in three cartilaginous fishes</td>
#       <td id="T_a507c_row0_col2" class="data row0 col2" >Gene expression profiling of pooled late stage embryos from Leucoraja erinacea, Scyliorhinus canicula and Callorhinchus milii show that HOXC cluster genes are not expressed in the two elasmobranch fishes, L. erinacea and S. canicula. This finding supports the observations that these genes are not found in whole genome shotgun sequencing of L. erinacea or genomic clones from S. canicula. Overall design: Profile gene expression in pooled late stage embryos from three species (L. erinacea, S. canicula and C. milii)</td>
#       <td id="T_a507c_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_a507c_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_a507c_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_a507c_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_a507c_row0_col7" class="data row0 col7" >mRNA-seq Library Prep Kit for Illumina</td>
#       <td id="T_a507c_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_a507c_row0_col9" class="data row0 col9" >GSE26235</td>
#       <td id="T_a507c_row0_col10" class="data row0 col10" >PRJNA135005</td>
#       <td id="T_a507c_row0_col11" class="data row0 col11" >22174244, 25309735</td>
#       <td id="T_a507c_row0_col12" class="data row0 col12" ></td>
#       <td id="T_a507c_row0_col13" class="data row0 col13" >10.1126/science.1210912,10.12688/f1000research.4996.1</td>
#       <td id="T_a507c_row0_col14" class="data row0 col14" ></td>
#       <td id="T_a507c_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### paper and xrefs

# %%
#experiment.loc[:,'GSE'] = ''
#experiment.loc[:,'Bioproject'] = '' 
experiment.loc[:,'PMID'] = '22174244'
experiment.loc[:,'reference_url'] = 'https://pmc.ncbi.nlm.nih.gov/articles/PMC3264428/'
experiment.loc[:,'DOI'] = '10.1126/science.1210912'
experiment.loc[:,'xrefs'] = '25309735[PMID]'

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_5d656">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d656_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_5d656_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_5d656_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_5d656_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_5d656_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_5d656_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_5d656_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_5d656_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_5d656_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_5d656_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_5d656_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_5d656_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_5d656_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_5d656_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_5d656_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_5d656_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d656_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d656_row0_col0" class="data row0 col0" >SRP004911</td>
#       <td id="T_5d656_row0_col1" class="data row0 col1" >Late-stage embryonic gene expression in three cartilaginous fishes</td>
#       <td id="T_5d656_row0_col2" class="data row0 col2" >Gene expression profiling of pooled late stage embryos from Leucoraja erinacea, Scyliorhinus canicula and Callorhinchus milii show that HOXC cluster genes are not expressed in the two elasmobranch fishes, L. erinacea and S. canicula. This finding supports the observations that these genes are not found in whole genome shotgun sequencing of L. erinacea or genomic clones from S. canicula. Overall design: Profile gene expression in pooled late stage embryos from three species (L. erinacea, S. canicula and C. milii)</td>
#       <td id="T_5d656_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_5d656_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_5d656_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_5d656_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_5d656_row0_col7" class="data row0 col7" >mRNA-seq Library Prep Kit for Illumina</td>
#       <td id="T_5d656_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_5d656_row0_col9" class="data row0 col9" >GSE26235</td>
#       <td id="T_5d656_row0_col10" class="data row0 col10" >PRJNA135005</td>
#       <td id="T_5d656_row0_col11" class="data row0 col11" >22174244</td>
#       <td id="T_5d656_row0_col12" class="data row0 col12" >https://pmc.ncbi.nlm.nih.gov/articles/PMC3264428/</td>
#       <td id="T_5d656_row0_col13" class="data row0 col13" >10.1126/science.1210912</td>
#       <td id="T_5d656_row0_col14" class="data row0 col14" >25309735[PMID]</td>
#       <td id="T_5d656_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### comments

# %%
#experiment.loc[:,'comment'] = ''

display_df(experiment)

# %% [markdown]
# #### save complete file

# %%
experiment.to_csv(experiment_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ### QA time

# %%
library_to_add = pd.read_csv(library_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
experiment_to_add = pd.read_csv(experiment_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# %%
! python3 $path_to_v_script --bulk-exp $experiment_to_add_path --bulk-lib $library_to_add_path --rules-dir $path_to_rules --out $val_output --strict
# Out:
# Total issues: 3
# Errors: 3
# Warnings: 0
# Top codes:
#   - BAD_VALUE: 3

# %% [markdown]
# #### check columns match

# %%
# pull from git and pull in library/experiment file
! git pull
git_library = pd.read_csv(git_library_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
git_experiment = pd.read_csv(git_experiment_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# library file
if set(library_to_add.columns) == set(git_library.columns):
    print('The columns in the library file match')
else:
    print('The columns in the library file DO NOT MATCH')

# experiment file
if set(experiment_to_add.columns) == set(git_experiment.columns):
    print('The columns in the experiment file match')
else:
    print('The columns in the experiment file DO NOT MATCH')


# maybe to make this something more like "COLUMNS GOOD - LIBRARY" and "COLUMNS BAD - EXPERIMENT"
# Out:
# Already up to date.
# The columns in the library file match
# The columns in the experiment file match

# %% [markdown]
# #### view files

# %%
library_git_plus_new = pd.concat([git_library, library_to_add], ignore_index = True, sort = False)
old_length = git_library.shape[0]
start = old_length - 2
end = old_length + 5
view_lib = library_git_plus_new.iloc[start:end]
view_lib
# Out:
#        #libraryId experimentId                     platform       SRSId  \
# 65377  SRX5252098    SRP179635          Illumina HiSeq 2000  SRS4253804
# 65378  SRX5252097    SRP179635          Illumina HiSeq 2000  SRS4253803
# 65379   SRX036538    SRP004911  Illumina Genome Analyzer II   SRS150646
# 65380   SRX036537    SRP004911  Illumina Genome Analyzer II   SRS150645
# 65381   SRX036536    SRP004911  Illumina Genome Analyzer II   SRS150644
#
#                anatId                anatName         stageId  \
# 65377  UBERON:0001134  skeletal muscle tissue  UBERON:0000113
# 65378  UBERON:0001134  skeletal muscle tissue  UBERON:0000113
# 65379  UBERON:0000922                  embryo  UBERON:0000068
# 65380  UBERON:0000922                  embryo  UBERON:0000068
# 65381  UBERON:0000922                  embryo  UBERON:0000068
#
#                        stageName  \
# 65377  post-juvenile adult stage
# 65378  post-juvenile adult stage
# 65379               embryo stage
# 65380               embryo stage
# 65381               embryo stage
#
#                                                  url_GSM        infoOrgan  \
# 65377  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Skeletal muscle
# 65378  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  Skeletal muscle
# 65379  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...           embryo
# 65380  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...           embryo
# 65381  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...           embryo
#
#                  infoStage anatAnnotationStatus anatBiologicalStatus  \
# 65377              3 years        perfect match       not documented
# 65378              3 years        perfect match       not documented
# 65379     Stage 32 embryos        perfect match       not documented
# 65380  Stage 24-30 embryos        perfect match       not documented
# 65381  Stage 20-29 embryos        perfect match       not documented
#
#       stageAnnotationStatus sex strain genotype speciesId  \
# 65377    missing child term  NA                     13489
# 65378    missing child term  NA                     13489
# 65379    missing child term  NA                      7868
# 65380    missing child term  NA                      7830
# 65381    missing child term  NA                      7782
#
#                                      protocol protocolType RNASelection  \
# 65377                    TruSeq Stranded mRNA  full_length        polyA
# 65378                    TruSeq Stranded mRNA  full_length        polyA
# 65379  mRNA-seq Library Prep Kit for Illumina  full_length        polyA
# 65380  mRNA-seq Library Prep Kit for Illumina  full_length        polyA
# 65381  mRNA-seq Library Prep Kit for Illumina  full_length        polyA
#
#       globin_reduction replicate  \
# 65377
# 65378
# 65379
# 65380
# 65381
#
#                                                lib_name  \
# 65377                             Muscle2-RNAseq-farmed
# 65378                             Muscle1-RNAseq-farmed
# 65379       Callorhinchus milii pooled Stage 32 embryos
# 65380  Scyliorhinus canicula pooled Stage 24-30 embryos
# 65381     Leucoraja erinacea pooled Stage 20-29 embryos
#
#                     sampleName sampleAge_value sampleAge_unit PATOid PATOname  \
# 65377  SAMN10752232,GSM3563872               3           year
# 65378  SAMN10752233,GSM3563871               3           year
# 65379   SAMN00188955,GSM643959              32          stage
# 65380   SAMN00188954,GSM643958           24-30          stage
# 65381   SAMN00188953,GSM643957           20-29          stage
#
#       EFOid EFOname         comment condition physiologicalStatus annotatorId  \
# 65377                PMID: 31289822    farmed                             SAC
# 65378                PMID: 31289822    farmed                             SAC
# 65379                PMID: 22174244                                       SAC
# 65380                PMID: 22174244                                       SAC
# 65381                PMID: 22174244                                       SAC
#
#       lastModificationDate
# 65377           2026-06-10
# 65378           2026-06-10
# 65379           2026-06-10
# 65380           2026-06-10
# 65381           2026-06-10

# %%
experiment_git_plus_new = pd.concat([git_experiment, experiment_to_add], ignore_index = True, sort = False)
experiment_git_plus_new.tail(n=3)
# Out:
#      #experimentId                                     experimentName  \
# 1247     SRP150499  Rattus norvegicus and Anisakis pegreffii RNAse...
# 1248     SRP179635  Epimutations in developmental genes underlie t...
# 1249     SRP004911  Late-stage embryonic gene expression in three ...
#
#                                   experimentDescription experimentSource  \
# 1247  Considered as one of the most significant emer...              SRA
# 1248  Domestication of wild animals induces a set of...              SRA
# 1249  Gene expression profiling of pooled late stage...              SRA
#
#      experimentStatus projectTags numberOfAnnotatedLibraries  \
# 1247          partial     Bgee 1K                          2
# 1248          partial     Bgee 1K                         32
# 1249            total     Bgee 1K                          3
#
#                                     protocol protocolType        GSE  \
# 1247                    TruSeq Stranded mRNA  full_length
# 1248                    TruSeq Stranded mRNA  full_length  GSE125124
# 1249  mRNA-seq Library Prep Kit for Illumina  full_length   GSE26235
#
#        Bioproject      PMID  \
# 1247  PRJNA475982  30245697
# 1248  PRJNA515290  31289822
# 1249  PRJNA135005  22174244
#
#                                           reference_url  \
# 1247  https://pmc.ncbi.nlm.nih.gov/articles/PMC6137129/
# 1248  https://pmc.ncbi.nlm.nih.gov/articles/PMC6759067/
# 1249  https://pmc.ncbi.nlm.nih.gov/articles/PMC3264428/
#
#                            DOI                          xrefs  \
# 1247  10.3389/fimmu.2018.02055  36590595[PMID],34186188[PMID]
# 1248     10.1093/molbev/msz153                 35741749[PMID]
# 1249   10.1126/science.1210912                 25309735[PMID]
#
#                                            comment
# 1247  rejected infected libraries and cell culture
# 1248       rejected Bisulfite Sequencing libraries
# 1249

# %% [markdown]
# ### add annotations to git

# %%
! git pull
# Out:
# Already up to date.

# %%
library_git_plus_new.to_csv(git_library_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
experiment_git_plus_new.to_csv(git_experiment_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
update_format(git_library_path)
update_format(git_experiment_path)

# %%
! git status

# %%
! git add $git_experiment_path $git_library_path

# %%
! git commit -m $commit_message_exp
# Out:
# [develop de70dd3] adding annotated bulk experiment SRP004911
#  2 files changed, 4 insertions(+)

# %%
! git push
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 2.40 KiB | 2.40 MiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# remote:
# remote: To create a merge request for develop, visit:
# remote:   https://gitlab.sib.swiss/Bgee/expression-annotations/-/merge_requests/new?merge_request%5Bsource_branch%5D=develop
# remote:
# To https://gitlab.sib.swiss/Bgee/expression-annotations.git/
#    ab6f022..de70dd3  develop -> develop

# %% [markdown]
# ### add annotation folder and script to git

# %%
! git pull

# %% [markdown]
# 1. run first two cells (annotation summary)
# 2. export as html

# %%
! git add $path_to_output

# %%
! git commit -m $commit_message_py

# %%
! git push
