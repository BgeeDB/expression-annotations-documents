# %% [markdown]
# ## SRP485915
#
# **paper:** [PMID: 41672499](https://www.jstage.jst.go.jp/article/ggs/advpub/0/advpub_25-00085/_pdf/-char/en) - Universality and diversity of gene expression patterns in response to cold acclimation in Drosophila albomicans, 2026
#
# **date, curator:** 2026-07-20, Sara Carsanaro
#
# **notes**
# * strains are from methods section, all isofemale lines
# * protocol, dev stage, etc. all confirmed in methods

# %% [markdown]
# ### annotation summary

# %%
anat_summary = library_to_add[['infoOrgan', 'anatId', 'anatName', 'anatAnnotationStatus']]
unique_anat = anat_summary.drop_duplicates()
display_df(unique_anat)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_cc761">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc761_level0_col0" class="col_heading level0 col0" >infoOrgan</th>
#       <th id="T_cc761_level0_col1" class="col_heading level0 col1" >anatId</th>
#       <th id="T_cc761_level0_col2" class="col_heading level0 col2" >anatName</th>
#       <th id="T_cc761_level0_col3" class="col_heading level0 col3" >anatAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc761_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc761_row0_col0" class="data row0 col0" >Whole body</td>
#       <td id="T_cc761_row0_col1" class="data row0 col1" >UBERON:0007023</td>
#       <td id="T_cc761_row0_col2" class="data row0 col2" >adult organism</td>
#       <td id="T_cc761_row0_col3" class="data row0 col3" >perfect match</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dev_summary = library_to_add[['infoStage', 'stageId', 'stageName', 'stageAnnotationStatus']]
unique_dev = dev_summary.drop_duplicates()
display_df(unique_dev)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_2c38a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c38a_level0_col0" class="col_heading level0 col0" >infoStage</th>
#       <th id="T_2c38a_level0_col1" class="col_heading level0 col1" >stageId</th>
#       <th id="T_2c38a_level0_col2" class="col_heading level0 col2" >stageName</th>
#       <th id="T_2c38a_level0_col3" class="col_heading level0 col3" >stageAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c38a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c38a_row0_col0" class="data row0 col0" >0-1 day after eclosion</td>
#       <td id="T_2c38a_row0_col1" class="data row0 col1" >UBERON:0000066</td>
#       <td id="T_2c38a_row0_col2" class="data row0 col2" >fully formed stage</td>
#       <td id="T_2c38a_row0_col3" class="data row0 col3" >perfect match</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### set variables, import packages, define functions

# %%
experiment_id = "SRP485915"

path_to_create_exp_script = "/Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py" 
experiment_type = "bulk"

path_to_output_main = "/Users/scarsana/Desktop/git/expression-annotations/Notebooks/bulk/" 
path_to_output = "{}{}/".format(path_to_output_main, experiment_id)
library_path_from_script = "{}RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_path_from_script = "{}RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
library_to_add_path = "{}complete_RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_to_add_path = "{}complete_RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
script_file = "{}.ipynb".format(experiment_id)
commit_message_exp = '"adding annotated bulk experiment {}"'.format(experiment_id)
commit_message_py = '"adding annotation files for {} to notebook folder"'.format(experiment_id)


## to add to git
path_to_git_annotations = "/Users/scarsana/Desktop/git/expression-annotations/RNA_Seq/"
git_library_path = "{}RNASeqLibrary.tsv".format(path_to_git_annotations)
git_experiment_path = "{}RNASeqExperiment.tsv".format(path_to_git_annotations)

## validation
path_to_v_script = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/validate_annotations.py'
path_to_rules = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/rules/'
val_output = "{}{}/validation.tsv".format(path_to_output_main, experiment_id)

library_cols = ['#libraryId', 'experimentId', 'platform', 'SRSId', 'anatId', 'anatName', 'stageId', 'stageName', 'url_GSM', 'infoOrgan', 'infoStage', 'anatAnnotationStatus', 'anatBiologicalStatus', 'stageAnnotationStatus', 'sex', 'strain', 'genotype', 'speciesId', 'protocol', 'protocolType', 'RNASelection', 'globin_reduction', 'replicate', 'lib_name', 'sampleName', 'sampleAge_value', 'sampleAge_unit', 'PATOid', 'PATOname','EFOid', 'EFOname','comment', 'condition', 'physiologicalStatus', 'annotatorId', 'lastModificationDate']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import os
import csv

# displays df with the scrollbar next to the DataFrame
def display_df(df):
    pd.set_option("display.max_rows", None)
    pd.set_option("display.max_columns", None)
    display(HTML("<div style='height: 300px; overflow: auto; width: fit-content'>" +
        df.style.to_html(index=False) + "</div>"))

# function that compares two columns in a dataframe and tells you which ones are not equal (case insensitive)
def compare_columns(df, col1, col2, return_col):
    compare_return = df[col1].str.lower() != df[col2].str.lower()  
    df.loc[compare_return, return_col] 
    if not any(compare_return):
        print("The two columns are equal (case insensitive)")
    else:
        print("The following rows are not equal: ")
        print(df.loc[compare_return, return_col])

# fixes formatting of file to match libreoffice settings/historic file format
def update_format(path):
    with open(path, 'r') as file:
        filedata = file.read()
    # Replace the target string
    filedata = filedata.replace("\t\"\"", "\t")
    # Write the file out again
    with open(path, 'w') as file:
        file.write(filedata)

# checks for duplicate values in a specific column and prints those values + the corresponding library id
def dup_check(df, column):
    duplicateCheck = df.duplicated(subset=[column], keep=False)
    duplicateCheck.sort_values(inplace=True)
    if duplicateCheck.unique().any() == False:
        print("no duplicate values in " + column)
    elif duplicateCheck.unique().any() == True and column != '#libraryId':
        dups = df[duplicateCheck].loc[:,['#libraryId', column]]
        df_dups = pd.DataFrame(dups)
        df_dups.sort_values(inplace=True, by=column)
        print(df_dups)
    elif duplicateCheck.unique().any() == True and column == '#libraryId':
        print(df[duplicateCheck].loc[:,['#libraryId']])

# prints all unique values in a specific column
def unique_sorted(df, column):
    unique = df[column].unique()
    unique.sort()
    print(unique)

# %% [markdown]
# ### script

# %%
! python3 $path_to_create_exp_script $experiment_id $path_to_output $experiment_type
# Out:
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:120: SyntaxWarning: invalid escape sequence '\('
#   all_protoc = [w.replace('(', '\(') for w in all_protoc]
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:121: SyntaxWarning: invalid escape sequence '\)'
#   all_protoc = [w.replace(')', '\)') for w in all_protoc]
# Be patient, it may take a few minutes.
#  86%|████████████████████████████████████▉      | 43/50 [00:45<00:06,  1.00it/s]curl: (22) The requested URL returned error: 502
# >78 ERROR: >78 curl command failed ( Mon Jul 20 16:36:45 CEST 2026 ) with: 22>78
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi -d db=SRA&id=SRX23390320&rettype=full&retmode=xml&tool=edirect&edirect=16.2&edirect_os=Darwin&email=scarsana%40SORGE42778>78
# HTTP/1.0 502 Bad Gateway
#  WARNING:  FAILURE ( Mon Jul 20 16:36:45 CEST 2026 )
# nquire -url https://eutils.ncbi.nlm.nih.gov/entrez/eutils/ efetch.fcgi -db SRA -id SRX23390320 -rettype full -retmode xml -tool edirect -edirect 16.2 -edirect_os Darwin -email scarsana@SORGE42778
# EMPTY RESULT
# SECOND ATTEMPT
# 100%|███████████████████████████████████████████| 50/50 [00:54<00:00,  1.10s/it]
# 0 samples dont have attributes, try to find them somewhere else
# 0it [00:00, ?it/s]
# 0 samples dont have attributes

# %% [markdown]
# ### library annnotations

# %%
library = pd.read_csv(library_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_a34c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a34c1_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_a34c1_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_a34c1_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_a34c1_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_a34c1_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_a34c1_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_a34c1_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_a34c1_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_a34c1_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_a34c1_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_a34c1_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_a34c1_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_a34c1_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_a34c1_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_a34c1_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_a34c1_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_a34c1_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_a34c1_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_a34c1_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_a34c1_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_a34c1_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_a34c1_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_a34c1_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_a34c1_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_a34c1_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_a34c1_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_a34c1_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_a34c1_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_a34c1_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_a34c1_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_a34c1_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_a34c1_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_a34c1_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_a34c1_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_a34c1_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_a34c1_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_a34c1_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_a34c1_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_a34c1_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_a34c1_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_a34c1_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_a34c1_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_a34c1_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_a34c1_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_a34c1_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_a34c1_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a34c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a34c1_row0_col0" class="data row0 col0" >SRX23390363</td>
#       <td id="T_a34c1_row0_col1" class="data row0 col1" >SRP485915</td>
#       <td id="T_a34c1_row0_col2" class="data row0 col2" >Illumina MiSeq</td>
#       <td id="T_a34c1_row0_col3" class="data row0 col3" >SRS20251274</td>
#       <td id="T_a34c1_row0_col4" class="data row0 col4" ></td>
#       <td id="T_a34c1_row0_col5" class="data row0 col5" ></td>
#       <td id="T_a34c1_row0_col6" class="data row0 col6" ></td>
#       <td id="T_a34c1_row0_col7" class="data row0 col7" ></td>
#       <td id="T_a34c1_row0_col8" class="data row0 col8" ></td>
#       <td id="T_a34c1_row0_col9" class="data row0 col9" >Whole body</td>
#       <td id="T_a34c1_row0_col10" class="data row0 col10" >0-1 day after eclosion</td>
#       <td id="T_a34c1_row0_col11" class="data row0 col11" ></td>
#       <td id="T_a34c1_row0_col12" class="data row0 col12" ></td>
#       <td id="T_a34c1_row0_col13" class="data row0 col13" ></td>
#       <td id="T_a34c1_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_a34c1_row0_col15" class="data row0 col15" >KKU202</td>
#       <td id="T_a34c1_row0_col16" class="data row0 col16" ></td>
#       <td id="T_a34c1_row0_col17" class="data row0 col17" >7291</td>
#       <td id="T_a34c1_row0_col18" class="data row0 col18" ></td>
#       <td id="T_a34c1_row0_col19" class="data row0 col19" ></td>
#       <td id="T_a34c1_row0_col20" class="data row0 col20" ></td>
#       <td id="T_a34c1_row0_col21" class="data row0 col21" ></td>
#       <td id="T_a34c1_row0_col22" class="data row0 col22" ></td>
#       <td id="T_a34c1_row0_col23" class="data row0 col23" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_a34c1_row0_col24" class="data row0 col24" >SAMN39595495</td>
#       <td id="T_a34c1_row0_col25" class="data row0 col25" ></td>
#       <td id="T_a34c1_row0_col26" class="data row0 col26" ></td>
#       <td id="T_a34c1_row0_col27" class="data row0 col27" ></td>
#       <td id="T_a34c1_row0_col28" class="data row0 col28" ></td>
#       <td id="T_a34c1_row0_col29" class="data row0 col29" ></td>
#       <td id="T_a34c1_row0_col30" class="data row0 col30" ></td>
#       <td id="T_a34c1_row0_col31" class="data row0 col31" ></td>
#       <td id="T_a34c1_row0_col32" class="data row0 col32" >non-acclimated control - 25C</td>
#       <td id="T_a34c1_row0_col33" class="data row0 col33" ></td>
#       <td id="T_a34c1_row0_col34" class="data row0 col34" ></td>
#       <td id="T_a34c1_row0_col35" class="data row0 col35" >20/07/2026</td>
#       <td id="T_a34c1_row0_col36" class="data row0 col36" >TruSeq mRNA Sample Preparation Kit v2</td>
#       <td id="T_a34c1_row0_col37" class="data row0 col37" ></td>
#       <td id="T_a34c1_row0_col38" class="data row0 col38" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_a34c1_row0_col39" class="data row0 col39" ></td>
#       <td id="T_a34c1_row0_col40" class="data row0 col40" ></td>
#       <td id="T_a34c1_row0_col41" class="data row0 col41" ></td>
#       <td id="T_a34c1_row0_col42" class="data row0 col42" >Adult</td>
#       <td id="T_a34c1_row0_col43" class="data row0 col43" ></td>
#       <td id="T_a34c1_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_a34c1_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_a34c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a34c1_row1_col0" class="data row1 col0" >SRX23390362</td>
#       <td id="T_a34c1_row1_col1" class="data row1 col1" >SRP485915</td>
#       <td id="T_a34c1_row1_col2" class="data row1 col2" >Illumina HiSeq X</td>
#       <td id="T_a34c1_row1_col3" class="data row1 col3" >SRS20251273</td>
#       <td id="T_a34c1_row1_col4" class="data row1 col4" ></td>
#       <td id="T_a34c1_row1_col5" cl

# %% [markdown]
# #### anatomical entity
# * [uberon ols](https://www.ebi.ac.uk/ols4/ontologies/uberon)

# %%
unique_sorted(library, "infoOrgan")
# Out:
# ['Whole body']

# %%
# all
library.loc[:,'anatId'] = 'UBERON:0007023'
library.loc[:,'anatName'] = 'adult organism'
# perfect match, missing child term, other
library.loc[:,'anatAnnotationStatus'] = 'perfect match'
# partial sampling, full sampling, not documented
library.loc[:,'anatBiologicalStatus'] = 'not documented'


# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_9bb09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bb09_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_9bb09_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_9bb09_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_9bb09_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_9bb09_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_9bb09_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_9bb09_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_9bb09_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_9bb09_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_9bb09_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_9bb09_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_9bb09_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_9bb09_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_9bb09_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_9bb09_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_9bb09_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_9bb09_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_9bb09_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_9bb09_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_9bb09_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_9bb09_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_9bb09_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_9bb09_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_9bb09_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_9bb09_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_9bb09_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_9bb09_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_9bb09_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_9bb09_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_9bb09_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_9bb09_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_9bb09_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_9bb09_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_9bb09_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_9bb09_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_9bb09_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_9bb09_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_9bb09_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_9bb09_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_9bb09_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_9bb09_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_9bb09_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_9bb09_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_9bb09_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_9bb09_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_9bb09_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bb09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bb09_row0_col0" class="data row0 col0" >SRX23390363</td>
#       <td id="T_9bb09_row0_col1" class="data row0 col1" >SRP485915</td>
#       <td id="T_9bb09_row0_col2" class="data row0 col2" >Illumina MiSeq</td>
#       <td id="T_9bb09_row0_col3" class="data row0 col3" >SRS20251274</td>
#       <td id="T_9bb09_row0_col4" class="data row0 col4" >UBERON:0007023</td>
#       <td id="T_9bb09_row0_col5" class="data row0 col5" >adult organism</td>
#       <td id="T_9bb09_row0_col6" class="data row0 col6" ></td>
#       <td id="T_9bb09_row0_col7" class="data row0 col7" ></td>
#       <td id="T_9bb09_row0_col8" class="data row0 col8" ></td>
#       <td id="T_9bb09_row0_col9" class="data row0 col9" >Whole body</td>
#       <td id="T_9bb09_row0_col10" class="data row0 col10" >0-1 day after eclosion</td>
#       <td id="T_9bb09_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_9bb09_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_9bb09_row0_col13" class="data row0 col13" ></td>
#       <td id="T_9bb09_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_9bb09_row0_col15" class="data row0 col15" >KKU202</td>
#       <td id="T_9bb09_row0_col16" class="data row0 col16" ></td>
#       <td id="T_9bb09_row0_col17" class="data row0 col17" >7291</td>
#       <td id="T_9bb09_row0_col18" class="data row0 col18" ></td>
#       <td id="T_9bb09_row0_col19" class="data row0 col19" ></td>
#       <td id="T_9bb09_row0_col20" class="data row0 col20" ></td>
#       <td id="T_9bb09_row0_col21" class="data row0 col21" ></td>
#       <td id="T_9bb09_row0_col22" class="data row0 col22" ></td>
#       <td id="T_9bb09_row0_col23" class="data row0 col23" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_9bb09_row0_col24" class="data row0 col24" >SAMN39595495</td>
#       <td id="T_9bb09_row0_col25" class="data row0 col25" ></td>
#       <td id="T_9bb09_row0_col26" class="data row0 col26" ></td>
#       <td id="T_9bb09_row0_col27" class="data row0 col27" ></td>
#       <td id="T_9bb09_row0_col28" class="data row0 col28" ></td>
#       <td id="T_9bb09_row0_col29" class="data row0 col29" ></td>
#       <td id="T_9bb09_row0_col30" class="data row0 col30" ></td>
#       <td id="T_9bb09_row0_col31" class="data row0 col31" ></td>
#       <td id="T_9bb09_row0_col32" class="data row0 col32" >non-acclimated control - 25C</td>
#       <td id="T_9bb09_row0_col33" class="data row0 col33" ></td>
#       <td id="T_9bb09_row0_col34" class="data row0 col34" ></td>
#       <td id="T_9bb09_row0_col35" class="data row0 col35" >20/07/2026</td>
#       <td id="T_9bb09_row0_col36" class="data row0 col36" >TruSeq mRNA Sample Preparation Kit v2</td>
#       <td id="T_9bb09_row0_col37" class="data row0 col37" ></td>
#       <td id="T_9bb09_row0_col38" class="data row0 col38" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_9bb09_row0_col39" class="data row0 col39" ></td>
#       <td id="T_9bb09_row0_col40" class="data row0 col40" ></td>
#       <td id="T_9bb09_row0_col41" class="data row0 col41" ></td>
#       <td id="T_9bb09_row0_col42" class="data row0 col42" >Adult</td>
#       <td id="T_9bb09_row0_col43" class="data row0 col43" ></td>
#       <td id="T_9bb09_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_9bb09_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_9bb09_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bb09_row1_col0" class="data row1 col0" >SRX23390362</td>
#       <td id="T_9bb09_row1_col1" class="data row1 col1" >SRP485915</td>
#       <td id="T_9bb09_row1_col2" class="data row1 col2" >Illumina HiSeq X</td>
#       <td id="T_9bb09_row1_col3" class="data row1 col3" >SRS20251273</td>
#       <td id="T_9bb09_row1_col4" class="dat

# %% [markdown]
# #### stage
# - [species specific developmental ontologies](https://github.com/obophenotype/developmental-stage-ontologies/tree/master/src/ontology/components)

# %%
unique_sorted(library, "infoStage")
# Out:
# ['0-1 day after eclosion']

# %%
# all
library.loc[:,'stageId'] = 'UBERON:0000066'
library.loc[:,'stageName'] = 'fully formed stage'
# perfect match, missing child term, other
library.loc[:,'stageAnnotationStatus'] = 'perfect match'


# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_a2954">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2954_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_a2954_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_a2954_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_a2954_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_a2954_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_a2954_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_a2954_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_a2954_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_a2954_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_a2954_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_a2954_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_a2954_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_a2954_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_a2954_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_a2954_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_a2954_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_a2954_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_a2954_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_a2954_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_a2954_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_a2954_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_a2954_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_a2954_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_a2954_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_a2954_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_a2954_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_a2954_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_a2954_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_a2954_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_a2954_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_a2954_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_a2954_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_a2954_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_a2954_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_a2954_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_a2954_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_a2954_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_a2954_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_a2954_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_a2954_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_a2954_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_a2954_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_a2954_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_a2954_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_a2954_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_a2954_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2954_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2954_row0_col0" class="data row0 col0" >SRX23390363</td>
#       <td id="T_a2954_row0_col1" class="data row0 col1" >SRP485915</td>
#       <td id="T_a2954_row0_col2" class="data row0 col2" >Illumina MiSeq</td>
#       <td id="T_a2954_row0_col3" class="data row0 col3" >SRS20251274</td>
#       <td id="T_a2954_row0_col4" class="data row0 col4" >UBERON:0007023</td>
#       <td id="T_a2954_row0_col5" class="data row0 col5" >adult organism</td>
#       <td id="T_a2954_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_a2954_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_a2954_row0_col8" class="data row0 col8" ></td>
#       <td id="T_a2954_row0_col9" class="data row0 col9" >Whole body</td>
#       <td id="T_a2954_row0_col10" class="data row0 col10" >0-1 day after eclosion</td>
#       <td id="T_a2954_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_a2954_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_a2954_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_a2954_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_a2954_row0_col15" class="data row0 col15" >KKU202</td>
#       <td id="T_a2954_row0_col16" class="data row0 col16" ></td>
#       <td id="T_a2954_row0_col17" class="data row0 col17" >7291</td>
#       <td id="T_a2954_row0_col18" class="data row0 col18" ></td>
#       <td id="T_a2954_row0_col19" class="data row0 col19" ></td>
#       <td id="T_a2954_row0_col20" class="data row0 col20" ></td>
#       <td id="T_a2954_row0_col21" class="data row0 col21" ></td>
#       <td id="T_a2954_row0_col22" class="data row0 col22" ></td>
#       <td id="T_a2954_row0_col23" class="data row0 col23" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_a2954_row0_col24" class="data row0 col24" >SAMN39595495</td>
#       <td id="T_a2954_row0_col25" class="data row0 col25" ></td>
#       <td id="T_a2954_row0_col26" class="data row0 col26" ></td>
#       <td id="T_a2954_row0_col27" class="data row0 col27" ></td>
#       <td id="T_a2954_row0_col28" class="data row0 col28" ></td>
#       <td id="T_a2954_row0_col29" class="data row0 col29" ></td>
#       <td id="T_a2954_row0_col30" class="data row0 col30" ></td>
#       <td id="T_a2954_row0_col31" class="data row0 col31" ></td>
#       <td id="T_a2954_row0_col32" class="data row0 col32" >non-acclimated control - 25C</td>
#       <td id="T_a2954_row0_col33" class="data row0 col33" ></td>
#       <td id="T_a2954_row0_col34" class="data row0 col34" ></td>
#       <td id="T_a2954_row0_col35" class="data row0 col35" >20/07/2026</td>
#       <td id="T_a2954_row0_col36" class="data row0 col36" >TruSeq mRNA Sample Preparation Kit v2</td>
#       <td id="T_a2954_row0_col37" class="data row0 col37" ></td>
#       <td id="T_a2954_row0_col38" class="data row0 col38" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_a2954_row0_col39" class="data row0 col39" ></td>
#       <td id="T_a2954_row0_col40" class="data row0 col40" ></td>
#       <td id="T_a2954_row0_col41" class="data row0 col41" ></td>
#       <td id="T_a2954_row0_col42" class="data row0 col42" >Adult</td>
#       <td id="T_a2954_row0_col43" class="data row0 col43" ></td>
#       <td id="T_a2954_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_a2954_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_a2954_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2954_row1_col0" class="data row1 col0" >SRX23390362</td>
#       <td id="T_a2954_row1_col1" class="data row1 col1" >SRP485915</td>
#       <td id="T_a2954_row1_col2" class="data row1 col2" >Illumina HiSeq X</td>
#       <td id="T_a2954_row1_col3" class="data row1 col3" >SRS20251273</td

# %% [markdown]
# #### sex, strain, genotype, speciesId
# - uniprot [strain list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/strains)
# - uniprot [species list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/speclist)
# - bgee [strain mapping](https://gitlab.sib.swiss/Bgee/expression-annotations/-/tree/develop/Strains?ref_type=heads)

# %%
#library.loc[:,'sex'] = 'M'
#library.loc[library["sex"] == "male", "sex"] = "M"
#library.loc[library["sex"] == "female", "sex"] = "F"

#library.loc[:,'strain'] = ''

#library.loc[:,'genotype'] = ''

#library.loc[:,'speciesId'] = ''

# view
display_df(library)

# %% [markdown]
# #### protocol
# see [bulk kits](https://gitlab.sib.swiss/Bgee/scRNA-Seq/-/blob/main/scripts/bulk_kits.csv) for some common protocols

# %%
# making these variables because we use them again in the experiment file
my_protocol = 'TruSeq RNA Sample Preparation Kit'
# full_length or 3'
my_protocolType = 'full_length'

library.loc[:,'protocol'] = my_protocol
library.loc[:,'protocolType'] = my_protocolType
# polyA, ribo-minus, miRNA, lncRNA, circRNA
library.loc[:,'RNASelection'] = 'polyA'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_ffaef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffaef_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_ffaef_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_ffaef_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_ffaef_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_ffaef_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_ffaef_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_ffaef_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_ffaef_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_ffaef_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_ffaef_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_ffaef_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_ffaef_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_ffaef_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_ffaef_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_ffaef_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_ffaef_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_ffaef_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_ffaef_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_ffaef_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_ffaef_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_ffaef_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_ffaef_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_ffaef_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_ffaef_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_ffaef_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_ffaef_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_ffaef_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_ffaef_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_ffaef_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_ffaef_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_ffaef_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_ffaef_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_ffaef_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_ffaef_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_ffaef_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_ffaef_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_ffaef_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_ffaef_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_ffaef_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_ffaef_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_ffaef_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_ffaef_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_ffaef_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_ffaef_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_ffaef_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_ffaef_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ffaef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ffaef_row0_col0" class="data row0 col0" >SRX23390363</td>
#       <td id="T_ffaef_row0_col1" class="data row0 col1" >SRP485915</td>
#       <td id="T_ffaef_row0_col2" class="data row0 col2" >Illumina MiSeq</td>
#       <td id="T_ffaef_row0_col3" class="data row0 col3" >SRS20251274</td>
#       <td id="T_ffaef_row0_col4" class="data row0 col4" >UBERON:0007023</td>
#       <td id="T_ffaef_row0_col5" class="data row0 col5" >adult organism</td>
#       <td id="T_ffaef_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_ffaef_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_ffaef_row0_col8" class="data row0 col8" ></td>
#       <td id="T_ffaef_row0_col9" class="data row0 col9" >Whole body</td>
#       <td id="T_ffaef_row0_col10" class="data row0 col10" >0-1 day after eclosion</td>
#       <td id="T_ffaef_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_ffaef_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_ffaef_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_ffaef_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_ffaef_row0_col15" class="data row0 col15" >KKU202</td>
#       <td id="T_ffaef_row0_col16" class="data row0 col16" ></td>
#       <td id="T_ffaef_row0_col17" class="data row0 col17" >7291</td>
#       <td id="T_ffaef_row0_col18" class="data row0 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_ffaef_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_ffaef_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_ffaef_row0_col21" class="data row0 col21" ></td>
#       <td id="T_ffaef_row0_col22" class="data row0 col22" ></td>
#       <td id="T_ffaef_row0_col23" class="data row0 col23" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_ffaef_row0_col24" class="data row0 col24" >SAMN39595495</td>
#       <td id="T_ffaef_row0_col25" class="data row0 col25" ></td>
#       <td id="T_ffaef_row0_col26" class="data row0 col26" ></td>
#       <td id="T_ffaef_row0_col27" class="data row0 col27" ></td>
#       <td id="T_ffaef_row0_col28" class="data row0 col28" ></td>
#       <td id="T_ffaef_row0_col29" class="data row0 col29" ></td>
#       <td id="T_ffaef_row0_col30" class="data row0 col30" ></td>
#       <td id="T_ffaef_row0_col31" class="data row0 col31" ></td>
#       <td id="T_ffaef_row0_col32" class="data row0 col32" >non-acclimated control - 25C</td>
#       <td id="T_ffaef_row0_col33" class="data row0 col33" ></td>
#       <td id="T_ffaef_row0_col34" class="data row0 col34" ></td>
#       <td id="T_ffaef_row0_col35" class="data row0 col35" >20/07/2026</td>
#       <td id="T_ffaef_row0_col36" class="data row0 col36" >TruSeq mRNA Sample Preparation Kit v2</td>
#       <td id="T_ffaef_row0_col37" class="data row0 col37" ></td>
#       <td id="T_ffaef_row0_col38" class="data row0 col38" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_ffaef_row0_col39" class="data row0 col39" ></td>
#       <td id="T_ffaef_row0_col40" class="data row0 col40" ></td>
#       <td id="T_ffaef_row0_col41" class="data row0 col41" ></td>
#       <td id="T_ffaef_row0_col42" class="data row0 col42" >Adult</td>
#       <td id="T_ffaef_row0_col43" class="data row0 col43" ></td>
#       <td id="T_ffaef_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_ffaef_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_ffaef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ffaef_row1_col0" class="data row1 col0" >SRX23390362</td>
#       <td id="T_ffaef_row1_col1" class="data row1 col1" >SRP485915</td>
#       <td id="T_ffaef_row1_col2" class="data row1 col2" >Illumina HiSeq X</td>
#       <td id="T_ffaef_r

# %% [markdown]
# #### globin, replicates

# %%
# check for duplicate SRSId values
dup_check(library, "SRSId")
# Out:
# no duplicate values in SRSId

# %%
#library.loc[:,'globin_reduction'] = 'Y'

# replicates
#library.loc[library["#libraryId"] == "old", "replicate"] = "1"
#library.loc[library["#libraryId"].isin(["one", "two"]), "replicate"] = "1"

# view
display_df(library)

# %% [markdown]
# #### sample age, pato, physiological status
# * [PATO](https://www.ebi.ac.uk/ols4/ontologies/pato)
# * [EFO](https://www.ebi.ac.uk/ols4/ontologies/efo)

# %%
library.loc[:,'sampleAge_value'] = '0-1'
library.loc[:,'sampleAge_unit'] = 'day post eclosion'

# ex. castrated male
#library.loc[:,'PATOid'] = ''
#library.loc[:,'PATOname'] = ''

# ex. castrated, pregnant, pre-smoltification, post-smoltification, laying eggs
#library.loc[:,'physiologicalStatus'] = ''

# ex. left, right
#library.loc[:,'EFOid'] = ''
#library.loc[:,'EFOname'] = ''

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_b91a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b91a6_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_b91a6_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_b91a6_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_b91a6_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_b91a6_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_b91a6_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_b91a6_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_b91a6_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_b91a6_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_b91a6_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_b91a6_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_b91a6_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_b91a6_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_b91a6_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_b91a6_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_b91a6_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_b91a6_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_b91a6_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_b91a6_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_b91a6_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_b91a6_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_b91a6_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_b91a6_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_b91a6_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_b91a6_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_b91a6_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_b91a6_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_b91a6_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_b91a6_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_b91a6_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_b91a6_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_b91a6_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_b91a6_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_b91a6_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_b91a6_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_b91a6_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_b91a6_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_b91a6_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_b91a6_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_b91a6_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_b91a6_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_b91a6_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_b91a6_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_b91a6_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_b91a6_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_b91a6_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b91a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b91a6_row0_col0" class="data row0 col0" >SRX23390363</td>
#       <td id="T_b91a6_row0_col1" class="data row0 col1" >SRP485915</td>
#       <td id="T_b91a6_row0_col2" class="data row0 col2" >Illumina MiSeq</td>
#       <td id="T_b91a6_row0_col3" class="data row0 col3" >SRS20251274</td>
#       <td id="T_b91a6_row0_col4" class="data row0 col4" >UBERON:0007023</td>
#       <td id="T_b91a6_row0_col5" class="data row0 col5" >adult organism</td>
#       <td id="T_b91a6_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_b91a6_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_b91a6_row0_col8" class="data row0 col8" ></td>
#       <td id="T_b91a6_row0_col9" class="data row0 col9" >Whole body</td>
#       <td id="T_b91a6_row0_col10" class="data row0 col10" >0-1 day after eclosion</td>
#       <td id="T_b91a6_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_b91a6_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_b91a6_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_b91a6_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_b91a6_row0_col15" class="data row0 col15" >KKU202</td>
#       <td id="T_b91a6_row0_col16" class="data row0 col16" ></td>
#       <td id="T_b91a6_row0_col17" class="data row0 col17" >7291</td>
#       <td id="T_b91a6_row0_col18" class="data row0 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_b91a6_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_b91a6_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_b91a6_row0_col21" class="data row0 col21" ></td>
#       <td id="T_b91a6_row0_col22" class="data row0 col22" ></td>
#       <td id="T_b91a6_row0_col23" class="data row0 col23" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_b91a6_row0_col24" class="data row0 col24" >SAMN39595495</td>
#       <td id="T_b91a6_row0_col25" class="data row0 col25" >0-1</td>
#       <td id="T_b91a6_row0_col26" class="data row0 col26" >day post eclosion</td>
#       <td id="T_b91a6_row0_col27" class="data row0 col27" ></td>
#       <td id="T_b91a6_row0_col28" class="data row0 col28" ></td>
#       <td id="T_b91a6_row0_col29" class="data row0 col29" ></td>
#       <td id="T_b91a6_row0_col30" class="data row0 col30" ></td>
#       <td id="T_b91a6_row0_col31" class="data row0 col31" ></td>
#       <td id="T_b91a6_row0_col32" class="data row0 col32" >non-acclimated control - 25C</td>
#       <td id="T_b91a6_row0_col33" class="data row0 col33" ></td>
#       <td id="T_b91a6_row0_col34" class="data row0 col34" ></td>
#       <td id="T_b91a6_row0_col35" class="data row0 col35" >20/07/2026</td>
#       <td id="T_b91a6_row0_col36" class="data row0 col36" >TruSeq mRNA Sample Preparation Kit v2</td>
#       <td id="T_b91a6_row0_col37" class="data row0 col37" ></td>
#       <td id="T_b91a6_row0_col38" class="data row0 col38" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_b91a6_row0_col39" class="data row0 col39" ></td>
#       <td id="T_b91a6_row0_col40" class="data row0 col40" ></td>
#       <td id="T_b91a6_row0_col41" class="data row0 col41" ></td>
#       <td id="T_b91a6_row0_col42" class="data row0 col42" >Adult</td>
#       <td id="T_b91a6_row0_col43" class="data row0 col43" ></td>
#       <td id="T_b91a6_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_b91a6_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_b91a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b91a6_row1_col0" class="data row1 col0" >SRX23390362</td>
#       <td id="T_b91a6_row1_col1" class="data row1 col1" >SRP485915</td>
#       <td id="T_b91a6_row1_col2" class="data row1 col2" >Illumina HiSeq X</td>

# %% [markdown]
# #### condition

# %%
# ex. control, diet, light, reproductive capacity, time post mortem, time post feeding, 
# exercise details, menstruation, personality, litter size 
#library.loc[library["condition"] == "old", "condition"] = "new"

# view
display_df(library)

# %% [markdown]
# #### annotator id, last modification date

# %%
library.loc[:,'annotatorId'] = 'SAC'
library.loc[:,'lastModificationDate'] = '2026-07-21'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_590fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_590fb_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_590fb_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_590fb_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_590fb_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_590fb_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_590fb_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_590fb_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_590fb_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_590fb_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_590fb_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_590fb_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_590fb_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_590fb_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_590fb_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_590fb_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_590fb_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_590fb_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_590fb_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_590fb_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_590fb_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_590fb_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_590fb_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_590fb_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_590fb_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_590fb_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_590fb_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_590fb_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_590fb_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_590fb_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_590fb_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_590fb_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_590fb_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_590fb_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_590fb_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_590fb_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_590fb_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_590fb_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_590fb_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_590fb_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_590fb_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_590fb_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_590fb_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_590fb_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_590fb_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_590fb_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_590fb_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_590fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_590fb_row0_col0" class="data row0 col0" >SRX23390363</td>
#       <td id="T_590fb_row0_col1" class="data row0 col1" >SRP485915</td>
#       <td id="T_590fb_row0_col2" class="data row0 col2" >Illumina MiSeq</td>
#       <td id="T_590fb_row0_col3" class="data row0 col3" >SRS20251274</td>
#       <td id="T_590fb_row0_col4" class="data row0 col4" >UBERON:0007023</td>
#       <td id="T_590fb_row0_col5" class="data row0 col5" >adult organism</td>
#       <td id="T_590fb_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_590fb_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_590fb_row0_col8" class="data row0 col8" ></td>
#       <td id="T_590fb_row0_col9" class="data row0 col9" >Whole body</td>
#       <td id="T_590fb_row0_col10" class="data row0 col10" >0-1 day after eclosion</td>
#       <td id="T_590fb_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_590fb_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_590fb_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_590fb_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_590fb_row0_col15" class="data row0 col15" >KKU202</td>
#       <td id="T_590fb_row0_col16" class="data row0 col16" ></td>
#       <td id="T_590fb_row0_col17" class="data row0 col17" >7291</td>
#       <td id="T_590fb_row0_col18" class="data row0 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_590fb_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_590fb_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_590fb_row0_col21" class="data row0 col21" ></td>
#       <td id="T_590fb_row0_col22" class="data row0 col22" ></td>
#       <td id="T_590fb_row0_col23" class="data row0 col23" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_590fb_row0_col24" class="data row0 col24" >SAMN39595495</td>
#       <td id="T_590fb_row0_col25" class="data row0 col25" >0-1</td>
#       <td id="T_590fb_row0_col26" class="data row0 col26" >day post eclosion</td>
#       <td id="T_590fb_row0_col27" class="data row0 col27" ></td>
#       <td id="T_590fb_row0_col28" class="data row0 col28" ></td>
#       <td id="T_590fb_row0_col29" class="data row0 col29" ></td>
#       <td id="T_590fb_row0_col30" class="data row0 col30" ></td>
#       <td id="T_590fb_row0_col31" class="data row0 col31" ></td>
#       <td id="T_590fb_row0_col32" class="data row0 col32" >non-acclimated control - 25C</td>
#       <td id="T_590fb_row0_col33" class="data row0 col33" ></td>
#       <td id="T_590fb_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_590fb_row0_col35" class="data row0 col35" >2026-07-21</td>
#       <td id="T_590fb_row0_col36" class="data row0 col36" >TruSeq mRNA Sample Preparation Kit v2</td>
#       <td id="T_590fb_row0_col37" class="data row0 col37" ></td>
#       <td id="T_590fb_row0_col38" class="data row0 col38" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_590fb_row0_col39" class="data row0 col39" ></td>
#       <td id="T_590fb_row0_col40" class="data row0 col40" ></td>
#       <td id="T_590fb_row0_col41" class="data row0 col41" ></td>
#       <td id="T_590fb_row0_col42" class="data row0 col42" >Adult</td>
#       <td id="T_590fb_row0_col43" class="data row0 col43" ></td>
#       <td id="T_590fb_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_590fb_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_590fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_590fb_row1_col0" class="data row1 col0" >SRX23390362</td>
#       <td id="T_590fb_row1_col1" class="data row1 col1" >SRP485915</td>
#       <td id="T_590fb_row1_col2" class="data row1 col2" >Illumina HiSeq X</td>

# %% [markdown]
# #### comments

# %%
library.loc[:,'comment'] = 'PMID: 41672499'

# %% [markdown]
# #### save complete file with correct columns

# %%
library_file_complete = library[library_cols]
library_file_complete.to_csv(library_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# view
display_df(library_file_complete)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_30c4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30c4f_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_30c4f_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_30c4f_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_30c4f_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_30c4f_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_30c4f_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_30c4f_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_30c4f_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_30c4f_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_30c4f_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_30c4f_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_30c4f_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_30c4f_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_30c4f_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_30c4f_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_30c4f_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_30c4f_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_30c4f_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_30c4f_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_30c4f_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_30c4f_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_30c4f_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_30c4f_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_30c4f_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_30c4f_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_30c4f_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_30c4f_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_30c4f_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_30c4f_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_30c4f_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_30c4f_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_30c4f_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_30c4f_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_30c4f_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_30c4f_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_30c4f_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30c4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30c4f_row0_col0" class="data row0 col0" >SRX23390363</td>
#       <td id="T_30c4f_row0_col1" class="data row0 col1" >SRP485915</td>
#       <td id="T_30c4f_row0_col2" class="data row0 col2" >Illumina MiSeq</td>
#       <td id="T_30c4f_row0_col3" class="data row0 col3" >SRS20251274</td>
#       <td id="T_30c4f_row0_col4" class="data row0 col4" >UBERON:0007023</td>
#       <td id="T_30c4f_row0_col5" class="data row0 col5" >adult organism</td>
#       <td id="T_30c4f_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_30c4f_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_30c4f_row0_col8" class="data row0 col8" ></td>
#       <td id="T_30c4f_row0_col9" class="data row0 col9" >Whole body</td>
#       <td id="T_30c4f_row0_col10" class="data row0 col10" >0-1 day after eclosion</td>
#       <td id="T_30c4f_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_30c4f_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_30c4f_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_30c4f_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_30c4f_row0_col15" class="data row0 col15" >KKU202</td>
#       <td id="T_30c4f_row0_col16" class="data row0 col16" ></td>
#       <td id="T_30c4f_row0_col17" class="data row0 col17" >7291</td>
#       <td id="T_30c4f_row0_col18" class="data row0 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_30c4f_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_30c4f_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_30c4f_row0_col21" class="data row0 col21" ></td>
#       <td id="T_30c4f_row0_col22" class="data row0 col22" ></td>
#       <td id="T_30c4f_row0_col23" class="data row0 col23" >KKU202_non-acclimation_Replicate5</td>
#       <td id="T_30c4f_row0_col24" class="data row0 col24" >SAMN39595495</td>
#       <td id="T_30c4f_row0_col25" class="data row0 col25" >0-1</td>
#       <td id="T_30c4f_row0_col26" class="data row0 col26" >day post eclosion</td>
#       <td id="T_30c4f_row0_col27" class="data row0 col27" ></td>
#       <td id="T_30c4f_row0_col28" class="data row0 col28" ></td>
#       <td id="T_30c4f_row0_col29" class="data row0 col29" ></td>
#       <td id="T_30c4f_row0_col30" class="data row0 col30" ></td>
#       <td id="T_30c4f_row0_col31" class="data row0 col31" >PMID: 41672499</td>
#       <td id="T_30c4f_row0_col32" class="data row0 col32" >non-acclimated control - 25C</td>
#       <td id="T_30c4f_row0_col33" class="data row0 col33" ></td>
#       <td id="T_30c4f_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_30c4f_row0_col35" class="data row0 col35" >2026-07-21</td>
#     </tr>
#     <tr>
#       <th id="T_30c4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30c4f_row1_col0" class="data row1 col0" >SRX23390362</td>
#       <td id="T_30c4f_row1_col1" class="data row1 col1" >SRP485915</td>
#       <td id="T_30c4f_row1_col2" class="data row1 col2" >Illumina HiSeq X</td>
#       <td id="T_30c4f_row1_col3" class="data row1 col3" >SRS20251273</td>
#       <td id="T_30c4f_row1_col4" class="data row1 col4" >UBERON:0007023</td>
#       <td id="T_30c4f_row1_col5" class="data row1 col5" >adult organism</td>
#       <td id="T_30c4f_row1_col6" class="data row1 col6" >UBERON:0000066</td>
#       <td id="T_30c4f_row1_col7" class="data row1 col7" >fully formed stage</td>
#       <td id="T_30c4f_row1_col8" class="data row1 col8" ></td>
#       <td id="T_30c4f_row1_col9" class="data row1 col9" >Whole body</td>
#       <td id="T_30c4f_row1_col10" class="data row1 col10" >0-1 day after eclosion</td>
#       <td id="T_30c4f_row1_col11" class="data row1 col11" >perfect match</td>
#       <td id="T_30c4f_row1_col12" class="data row1 col12" >not documented</td>
#       <td id="T_30c4f_row1_col13" class="data row1 col13" >perfect match</td>
#       <td id="T_30c4f_row1_col14" class="data row1 col14" >M</td>
#       <td id="T_30c4f_row1_col15" class="data row1 col15" >KKU202</td>
#       <td id="T_30c4f_row1_col16" class="data row1 col16" ></td>
#       <td id="T_30c4f_row1_col17" class="data row1 col17" >7291</td>
#       <td id="T_30c4f_row1_col18" class="data row1 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_30c4f_row1_col19" class="data row1 col19" >full_length</td>
#       <td id="T_30c4f_row1_col20" class="data row1 col20" >polyA</td>
#       <td id="T_30c4f_row1_col21" class="data row1 col21" ></td>
#       <td id="T_30c4f_row1_col22" class="data row1 col22" ></td>
#       <td id="T_30c4f_row1_col23" class="data row1 col23" >KKU202_non-acclimation_Replicate4</td>
#       <td id="T_30c4f_row1_col24"

# %% [markdown]
# ### experiment annotations

# %%
experiment = pd.read_csv(experiment_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_6fc57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fc57_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_6fc57_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_6fc57_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_6fc57_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_6fc57_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_6fc57_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_6fc57_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_6fc57_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_6fc57_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_6fc57_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_6fc57_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_6fc57_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_6fc57_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_6fc57_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_6fc57_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_6fc57_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fc57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fc57_row0_col0" class="data row0 col0" >SRP485915</td>
#       <td id="T_6fc57_row0_col1" class="data row0 col1" >Evolution of gene expression dynamics in response to cold in Drosophila albomicans.</td>
#       <td id="T_6fc57_row0_col2" class="data row0 col2" >The primary goal of this study is to investigate the molecular and genetic mechanisms responsible for enhancing cold tolerance in Drosophila albomicans, a tropical fruit fly species that has successfully expanded its distribution from tropical to temperate regions. Comparing transcriptomic changes via cold acclimation between several strains of Drosophila albomicans from various geographic locations within the East Asian temperate zone, we aim to identify the causative genes and pathways that underlie the species' adaptive responses to cold acclimation. Understanding these mechanisms is essential for unraveling the complex dynamics of cold adaptation and its role in driving the expansion of species into new, often colder, environments. This study's findings will not only contribute to our knowledge of the intricate interplay between gene expression and cold tolerance but also provide valuable insights into the broader context of species' responses to changing environmental conditions, with potential implications for climate change and species distribution dynamics.</td>
#       <td id="T_6fc57_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_6fc57_row0_col4" class="data row0 col4" ></td>
#       <td id="T_6fc57_row0_col5" class="data row0 col5" ></td>
#       <td id="T_6fc57_row0_col6" class="data row0 col6" ></td>
#       <td id="T_6fc57_row0_col7" class="data row0 col7" ></td>
#       <td id="T_6fc57_row0_col8" class="data row0 col8" ></td>
#       <td id="T_6fc57_row0_col9" class="data row0 col9" ></td>
#       <td id="T_6fc57_row0_col10" class="data row0 col10" >PRJNA1068552</td>
#       <td id="T_6fc57_row0_col11" class="data row0 col11" ></td>
#       <td id="T_6fc57_row0_col12" class="data row0 col12" ></td>
#       <td id="T_6fc57_row0_col13" class="data row0 col13" >E,r,r,o,r,:, ,U,n,a,b,l,e, ,t,o, ,r,e,t,r,i,e,v,e, ,d,a,t,a,,, ,S,t,a,t,u,s, ,c,o,d,e, ,4,0,4</td>
#       <td id="T_6fc57_row0_col14" class="data row0 col14" ></td>
#       <td id="T_6fc57_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### experiment and protocol details

# %%
# this will give you the number of rows in the complete library file 
# this should be the number of annotated libraries
ann_lib = len(library_file_complete.index)
len(library_file_complete.index)
# Out:
# 50

# %%
# partial or total
experiment.loc[:,'experimentStatus'] = 'total'
# Bgee 1K
experiment.loc[:,'projectTags'] = 'Bgee 1K' 
# see above cell, also can add as free text
experiment.loc[:,'numberOfAnnotatedLibraries'] = ann_lib

# these variables should already exist from above but if not can just add as free text
experiment.loc[:,'protocol'] = my_protocol
experiment.loc[:,'protocolType'] = my_protocolType

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_7c2d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c2d7_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_7c2d7_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_7c2d7_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_7c2d7_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_7c2d7_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_7c2d7_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_7c2d7_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_7c2d7_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_7c2d7_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_7c2d7_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_7c2d7_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_7c2d7_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_7c2d7_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_7c2d7_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_7c2d7_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_7c2d7_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c2d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c2d7_row0_col0" class="data row0 col0" >SRP485915</td>
#       <td id="T_7c2d7_row0_col1" class="data row0 col1" >Evolution of gene expression dynamics in response to cold in Drosophila albomicans.</td>
#       <td id="T_7c2d7_row0_col2" class="data row0 col2" >The primary goal of this study is to investigate the molecular and genetic mechanisms responsible for enhancing cold tolerance in Drosophila albomicans, a tropical fruit fly species that has successfully expanded its distribution from tropical to temperate regions. Comparing transcriptomic changes via cold acclimation between several strains of Drosophila albomicans from various geographic locations within the East Asian temperate zone, we aim to identify the causative genes and pathways that underlie the species' adaptive responses to cold acclimation. Understanding these mechanisms is essential for unraveling the complex dynamics of cold adaptation and its role in driving the expansion of species into new, often colder, environments. This study's findings will not only contribute to our knowledge of the intricate interplay between gene expression and cold tolerance but also provide valuable insights into the broader context of species' responses to changing environmental conditions, with potential implications for climate change and species distribution dynamics.</td>
#       <td id="T_7c2d7_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_7c2d7_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_7c2d7_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_7c2d7_row0_col6" class="data row0 col6" >50</td>
#       <td id="T_7c2d7_row0_col7" class="data row0 col7" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_7c2d7_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_7c2d7_row0_col9" class="data row0 col9" ></td>
#       <td id="T_7c2d7_row0_col10" class="data row0 col10" >PRJNA1068552</td>
#       <td id="T_7c2d7_row0_col11" class="data row0 col11" ></td>
#       <td id="T_7c2d7_row0_col12" class="data row0 col12" ></td>
#       <td id="T_7c2d7_row0_col13" class="data row0 col13" >E,r,r,o,r,:, ,U,n,a,b,l,e, ,t,o, ,r,e,t,r,i,e,v,e, ,d,a,t,a,,, ,S,t,a,t,u,s, ,c,o,d,e, ,4,0,4</td>
#       <td id="T_7c2d7_row0_col14" class="data row0 col14" ></td>
#       <td id="T_7c2d7_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### paper and xrefs

# %%
#experiment.loc[:,'GSE'] = ''
#experiment.loc[:,'Bioproject'] = '' 
experiment.loc[:,'PMID'] = '41672499'
experiment.loc[:,'reference_url'] = 'https://www.jstage.jst.go.jp/article/ggs/advpub/0/advpub_25-00085/_pdf/-char/en'
experiment.loc[:,'DOI'] = '10.1266/ggs.25-00085'
#experiment.loc[:,'xrefs'] = ''

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_bd9db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd9db_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_bd9db_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_bd9db_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_bd9db_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_bd9db_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_bd9db_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_bd9db_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_bd9db_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_bd9db_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_bd9db_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_bd9db_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_bd9db_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_bd9db_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_bd9db_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_bd9db_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_bd9db_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd9db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd9db_row0_col0" class="data row0 col0" >SRP485915</td>
#       <td id="T_bd9db_row0_col1" class="data row0 col1" >Evolution of gene expression dynamics in response to cold in Drosophila albomicans.</td>
#       <td id="T_bd9db_row0_col2" class="data row0 col2" >The primary goal of this study is to investigate the molecular and genetic mechanisms responsible for enhancing cold tolerance in Drosophila albomicans, a tropical fruit fly species that has successfully expanded its distribution from tropical to temperate regions. Comparing transcriptomic changes via cold acclimation between several strains of Drosophila albomicans from various geographic locations within the East Asian temperate zone, we aim to identify the causative genes and pathways that underlie the species' adaptive responses to cold acclimation. Understanding these mechanisms is essential for unraveling the complex dynamics of cold adaptation and its role in driving the expansion of species into new, often colder, environments. This study's findings will not only contribute to our knowledge of the intricate interplay between gene expression and cold tolerance but also provide valuable insights into the broader context of species' responses to changing environmental conditions, with potential implications for climate change and species distribution dynamics.</td>
#       <td id="T_bd9db_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_bd9db_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_bd9db_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_bd9db_row0_col6" class="data row0 col6" >50</td>
#       <td id="T_bd9db_row0_col7" class="data row0 col7" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_bd9db_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_bd9db_row0_col9" class="data row0 col9" ></td>
#       <td id="T_bd9db_row0_col10" class="data row0 col10" >PRJNA1068552</td>
#       <td id="T_bd9db_row0_col11" class="data row0 col11" >41672499</td>
#       <td id="T_bd9db_row0_col12" class="data row0 col12" >https://www.jstage.jst.go.jp/article/ggs/advpub/0/advpub_25-00085/_pdf/-char/en</td>
#       <td id="T_bd9db_row0_col13" class="data row0 col13" >10.1266/ggs.25-00085</td>
#       <td id="T_bd9db_row0_col14" class="data row0 col14" ></td>
#       <td id="T_bd9db_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### comments

# %%
#experiment.loc[:,'comment'] = ''

display_df(experiment)

# %% [markdown]
# #### save complete file

# %%
experiment.to_csv(experiment_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ### QA time

# %%
library_to_add = pd.read_csv(library_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
experiment_to_add = pd.read_csv(experiment_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# %%
! python3 $path_to_v_script --bulk-exp $experiment_to_add_path --bulk-lib $library_to_add_path --rules-dir $path_to_rules --out $val_output --strict
# Out:
# Total issues: 50
# Errors: 50
# Warnings: 0
# Top codes:
#   - BAD_VALUE: 50

# %% [markdown]
# #### check columns match

# %%
# pull from git and pull in library/experiment file
! git pull
git_library = pd.read_csv(git_library_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
git_experiment = pd.read_csv(git_experiment_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# library file
if set(library_to_add.columns) == set(git_library.columns):
    print('The columns in the library file match')
else:
    print('The columns in the library file DO NOT MATCH')

# experiment file
if set(experiment_to_add.columns) == set(git_experiment.columns):
    print('The columns in the experiment file match')
else:
    print('The columns in the experiment file DO NOT MATCH')


# maybe to make this something more like "COLUMNS GOOD - LIBRARY" and "COLUMNS BAD - EXPERIMENT"
# Out:
# Already up to date.
# The columns in the library file match
# The columns in the experiment file match

# %% [markdown]
# #### view files

# %%
library_git_plus_new = pd.concat([git_library, library_to_add], ignore_index = True, sort = False)
old_length = git_library.shape[0]
start = old_length - 2
end = old_length + 5
view_lib = library_git_plus_new.iloc[start:end]
view_lib
# Out:
#         #libraryId experimentId             platform        SRSId  \
# 68339   SRX2653647    SRP102138  Illumina HiSeq 2500   SRS2058804
# 68340   SRX2653646    SRP102138  Illumina HiSeq 2500   SRS2058803
# 68341  SRX23390363    SRP485915       Illumina MiSeq  SRS20251274
# 68342  SRX23390362    SRP485915     Illumina HiSeq X  SRS20251273
# 68343  SRX23390361    SRP485915     Illumina HiSeq X  SRS20251272
# 68344  SRX23390360    SRP485915     Illumina HiSeq X  SRS20251271
# 68345  SRX23390359    SRP485915     Illumina HiSeq X  SRS20251270
#
#                anatId        anatName         stageId           stageName  \
# 68339  UBERON:0002548           larva  UBERON:0000069        larval stage
# 68340  UBERON:0002548           larva  UBERON:0000069        larval stage
# 68341  UBERON:0007023  adult organism  UBERON:0000066  fully formed stage
# 68342  UBERON:0007023  adult organism  UBERON:0000066  fully formed stage
# 68343  UBERON:0007023  adult organism  UBERON:0000066  fully formed stage
# 68344  UBERON:0007023  adult organism  UBERON:0000066  fully formed stage
# 68345  UBERON:0007023  adult organism  UBERON:0000066  fully formed stage
#
#       url_GSM     infoOrgan               infoStage anatAnnotationStatus  \
# 68339          Whole larvae                 stage 8        perfect match
# 68340          Whole larvae                 stage 8        perfect match
# 68341            Whole body  0-1 day after eclosion        perfect match
# 68342            Whole body  0-1 day after eclosion        perfect match
# 68343            Whole body  0-1 day after eclosion        perfect match
# 68344            Whole body  0-1 day after eclosion        perfect match
# 68345            Whole body  0-1 day after eclosion        perfect match
#
#       anatBiologicalStatus stageAnnotationStatus sex  strain genotype  \
# 68339        full sampling    missing child term  NA      NA
# 68340        full sampling    missing child term  NA      NA
# 68341       not documented         perfect match   M  KKU202
# 68342       not documented         perfect match   M  KKU202
# 68343       not documented         perfect match   M  KKU202
# 68344       not documented         perfect match   M  KKU202
# 68345       not documented         perfect match   M  KKU202
#
#       speciesId                           protocol protocolType RNASelection  \
# 68339    283909        TruSeq RNA Library Prep Kit  full_length        polyA
# 68340    283909        TruSeq RNA Library Prep Kit  full_length        polyA
# 68341      7291  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 68342      7291  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 68343      7291  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 68344      7291  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 68345      7291  TruSeq RNA Sample Preparation Kit  full_length        polyA
#
#       globin_reduction replicate                           lib_name  \
# 68339                                               Pre-competent-3
# 68340                                               Pre-competent-4
# 68341                             KKU202_non-acclimation_Replicate5
# 68342                             KKU202_non-acclimation_Replicate4
# 68343                             KKU202_non-acclimation_Replicate3
# 68344                             KKU202_non-acclimation_Replicate2
# 68345                             KKU202_non-acclimation_Replicate1
#
#          sampleName sampleAge_value     sampleAge_unit PATOid PATOname EFOid  \
# 68339  SAMN06618369
# 68340  SAMN06618370
# 68341  SAMN39595495             0-1  day post eclosion
# 68342  SAMN39595494             0-1  day post eclosion
# 68343  SAMN39595493             0-1  day post eclosion
# 68344  SAMN39595492             0-1  day post eclosion
# 68345  SAMN39595491             0-1  day post eclosion
#
#       EFOname                                            comment  \
# 68339          PMID:28898599, Embryos develop about 8 d befor...
# 68340          PMID:28898599, Embryos develop about 8 d befor...
# 68341                                             PMID: 41672499
# 68342                                             PMID: 41672499
# 68343                                             PMID: 41672499
# 68344                                             PMID: 41672499
# 68345                                             PMID: 41672499
#
#                           condition physiologicalStatus annotatorId  \
# 68339                 Pre-competent                             ANN
# 68340                 Pre-competent                             ANN
# 68341  non-acclimated control - 25C                             SAC
# 68342  non-acclimated control - 25C                             SAC
# 68343  non-acclimated control - 25C                             SAC
# 68344  non-acclimated control - 25C                             SAC
# 68345  non-acclimated control - 25C                             SAC
#
#       lastModificationDate
# 68339           2026-07-20
# 68340           2026-07-20
# 68341           2026-07-21
# 68342           2026-07-21
# 68343           2026-07-21
# 68344           2026-07-21
# 68345           2026-07-21

# %%
experiment_git_plus_new = pd.concat([git_experiment, experiment_to_add], ignore_index = True, sort = False)
experiment_git_plus_new.tail(n=3)
# Out:
#      #experimentId                                     experimentName  \
# 1304     SRP515775                  SmallRNA sequencing of Syndermata
# 1305     SRP102138  Capitella teleta RNA sequencing of competent a...
# 1306     SRP485915  Evolution of gene expression dynamics in respo...
#
#                                   experimentDescription experimentSource  \
# 1304  smallRNA sequencing of Seisonidea and Acanthoc...              SRA
# 1305  Marine invertebrate larvae typically take hour...              SRA
# 1306  The primary goal of this study is to investiga...              SRA
#
#      experimentStatus projectTags numberOfAnnotatedLibraries  \
# 1304            total     Bgee 1K                          5
# 1305            total     Bgee 1K                          8
# 1306            total     Bgee 1K                         50
#
#                                protocol protocolType GSE    Bioproject  \
# 1304                           Illumina  full_length      PRJNA1127840
# 1305        TruSeq RNA Library Prep Kit  full_length       PRJNA379706
# 1306  TruSeq RNA Sample Preparation Kit  full_length      PRJNA1068552
#
#           PMID                                      reference_url  \
# 1304  40577491  https://pmc.ncbi.nlm.nih.gov/articles/PMC12256...
# 1305  28898599
# 1306  41672499  https://www.jstage.jst.go.jp/article/ggs/advpu...
#
#                        DOI xrefs comment
# 1304   10.1093/gbe/evaf124
# 1305        10.1086/692829
# 1306  10.1266/ggs.25-00085

# %% [markdown]
# ### add annotations to git

# %%
! git pull
# Out:
# Already up to date.

# %%
library_git_plus_new.to_csv(git_library_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
experiment_git_plus_new.to_csv(git_experiment_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
update_format(git_library_path)
update_format(git_experiment_path)

# %%
! git add $git_experiment_path $git_library_path

# %%
! git commit -m $commit_message_exp
# Out:
# [develop 929032c] adding annotated bulk experiment SRP485915
#  2 files changed, 51 insertions(+)

# %%
! git push
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 3.59 KiB | 919.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# remote:
# remote: To create a merge request for develop, visit:
# remote:   https://gitlab.sib.swiss/Bgee/expression-annotations/-/merge_requests/new?merge_request%5Bsource_branch%5D=develop
# remote:
# To https://gitlab.sib.swiss/Bgee/expression-annotations.git/
#    95159f1..929032c  develop -> develop

# %% [markdown]
# ### add annotation folder and script to git

# %%
! git pull

# %% [markdown]
# 1. run first two cells (annotation summary)
# 2. export as html

# %%
! git add $path_to_output

# %%
! git commit -m $commit_message_py

# %%
! git push
