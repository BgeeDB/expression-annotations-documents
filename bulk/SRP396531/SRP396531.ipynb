# %% [markdown]
# ## SRP396531
#
# **paper:** [PMID: 36303550](https://pmc.ncbi.nlm.nih.gov/articles/PMC9592921/) - Whole genome bisulfite sequencing reveals DNA methylation roles in the adaptive response of wildness training giant pandas to wild environment, 2022
#
# **date, curator:** 2026-04-08, Sara Carsanaro
#
# **notes**
# * pandas get weaned just before 1 year, sexual maturity is around 5 years so these are all juvenile stage

# %% [markdown]
# ### annotation summary

# %%
anat_summary = library_to_add[['infoOrgan', 'anatId', 'anatName', 'anatAnnotationStatus']]
unique_anat = anat_summary.drop_duplicates()
display_df(unique_anat)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_4c650">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c650_level0_col0" class="col_heading level0 col0" >infoOrgan</th>
#       <th id="T_4c650_level0_col1" class="col_heading level0 col1" >anatId</th>
#       <th id="T_4c650_level0_col2" class="col_heading level0 col2" >anatName</th>
#       <th id="T_4c650_level0_col3" class="col_heading level0 col3" >anatAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c650_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c650_row0_col0" class="data row0 col0" >blood</td>
#       <td id="T_4c650_row0_col1" class="data row0 col1" >UBERON:0000178</td>
#       <td id="T_4c650_row0_col2" class="data row0 col2" >blood</td>
#       <td id="T_4c650_row0_col3" class="data row0 col3" >perfect match</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dev_summary = library_to_add[['infoStage', 'stageId', 'stageName', 'stageAnnotationStatus']]
unique_dev = dev_summary.drop_duplicates()
display_df(unique_dev)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_f7d47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7d47_level0_col0" class="col_heading level0 col0" >infoStage</th>
#       <th id="T_f7d47_level0_col1" class="col_heading level0 col1" >stageId</th>
#       <th id="T_f7d47_level0_col2" class="col_heading level0 col2" >stageName</th>
#       <th id="T_f7d47_level0_col3" class="col_heading level0 col3" >stageAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7d47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7d47_row0_col0" class="data row0 col0" >2.2</td>
#       <td id="T_f7d47_row0_col1" class="data row0 col1" >UBERON:0034919</td>
#       <td id="T_f7d47_row0_col2" class="data row0 col2" >juvenile stage</td>
#       <td id="T_f7d47_row0_col3" class="data row0 col3" >missing child term</td>
#     </tr>
#     <tr>
#       <th id="T_f7d47_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_f7d47_row1_col0" class="data row1 col0" >1.5</td>
#       <td id="T_f7d47_row1_col1" class="data row1 col1" >UBERON:0034919</td>
#       <td id="T_f7d47_row1_col2" class="data row1 col2" >juvenile stage</td>
#       <td id="T_f7d47_row1_col3" class="data row1 col3" >missing child term</td>
#     </tr>
#     <tr>
#       <th id="T_f7d47_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_f7d47_row2_col0" class="data row2 col0" >2.3</td>
#       <td id="T_f7d47_row2_col1" class="data row2 col1" >UBERON:0034919</td>
#       <td id="T_f7d47_row2_col2" class="data row2 col2" >juvenile stage</td>
#       <td id="T_f7d47_row2_col3" class="data row2 col3" >missing child term</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### set variables, import packages, define functions

# %%
experiment_id = "SRP396531"

path_to_create_exp_script = "/Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py" 
experiment_type = "bulk"

path_to_output_main = "/Users/scarsana/Desktop/git/expression-annotations/Notebooks/bulk/" 
path_to_output = "{}{}/".format(path_to_output_main, experiment_id)
library_path_from_script = "{}RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_path_from_script = "{}RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
library_to_add_path = "{}complete_RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_to_add_path = "{}complete_RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
script_file = "{}.ipynb".format(experiment_id)
commit_message_exp = '"adding annotated bulk experiment {}"'.format(experiment_id)
commit_message_py = '"adding annotation files for {} to notebook folder"'.format(experiment_id)


## to add to git
path_to_git_annotations = "/Users/scarsana/Desktop/git/expression-annotations/RNA_Seq/"
git_library_path = "{}RNASeqLibrary.tsv".format(path_to_git_annotations)
git_experiment_path = "{}RNASeqExperiment.tsv".format(path_to_git_annotations)

## validation
path_to_v_script = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/validate_annotations.py'
path_to_rules = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/rules/'
val_output = "{}{}/validation.tsv".format(path_to_output_main, experiment_id)

library_cols = ['#libraryId', 'experimentId', 'platform', 'SRSId', 'anatId', 'anatName', 'stageId', 'stageName', 'url_GSM', 'infoOrgan', 'infoStage', 'anatAnnotationStatus', 'anatBiologicalStatus', 'stageAnnotationStatus', 'sex', 'strain', 'genotype', 'speciesId', 'protocol', 'protocolType', 'RNASelection', 'globin_reduction', 'replicate', 'lib_name', 'sampleName', 'sampleAge_value', 'sampleAge_unit', 'PATOid', 'PATOname','EFOid', 'EFOname','comment', 'condition', 'physiologicalStatus', 'annotatorId', 'lastModificationDate']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import os
import csv

# displays df with the scrollbar next to the DataFrame
def display_df(df):
    pd.set_option("display.max_rows", None)
    pd.set_option("display.max_columns", None)
    display(HTML("<div style='height: 300px; overflow: auto; width: fit-content'>" +
        df.style.to_html(index=False) + "</div>"))

# function that compares two columns in a dataframe and tells you which ones are not equal (case insensitive)
def compare_columns(df, col1, col2, return_col):
    compare_return = df[col1].str.lower() != df[col2].str.lower()  
    df.loc[compare_return, return_col] 
    if not any(compare_return):
        print("The two columns are equal (case insensitive)")
    else:
        print("The following rows are not equal: ")
        print(df.loc[compare_return, return_col])

# fixes formatting of file to match libreoffice settings/historic file format
def update_format(path):
    with open(path, 'r') as file:
        filedata = file.read()
    # Replace the target string
    filedata = filedata.replace("\t\"\"", "\t")
    # Write the file out again
    with open(path, 'w') as file:
        file.write(filedata)

# checks for duplicate values in a specific column and prints those values + the corresponding library id
def dup_check(df, column):
    duplicateCheck = df.duplicated(subset=[column], keep=False)
    duplicateCheck.sort_values(inplace=True)
    if duplicateCheck.unique().any() == False:
        print("no duplicate values in " + column)
    elif duplicateCheck.unique().any() == True and column != '#libraryId':
        dups = df[duplicateCheck].loc[:,['#libraryId', column]]
        df_dups = pd.DataFrame(dups)
        df_dups.sort_values(inplace=True, by=column)
        print(df_dups)
    elif duplicateCheck.unique().any() == True and column == '#libraryId':
        print(df[duplicateCheck].loc[:,['#libraryId']])

# prints all unique values in a specific column
def unique_sorted(df, column):
    unique = df[column].unique()
    unique.sort()
    print(unique)

# %% [markdown]
# ### script

# %%
! python3 $path_to_create_exp_script $experiment_id $path_to_output $experiment_type
# Out:
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:120: SyntaxWarning: invalid escape sequence '\('
#   all_protoc = [w.replace('(', '\(') for w in all_protoc]
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:121: SyntaxWarning: invalid escape sequence '\)'
#   all_protoc = [w.replace(')', '\)') for w in all_protoc]
# Be patient, it may take a few minutes.
# 100%|███████████████████████████████████████████| 12/12 [00:11<00:00,  1.01it/s]
# 0 samples dont have attributes, try to find them somewhere else
# 0it [00:00, ?it/s]
# 0 samples dont have attributes

# %% [markdown]
# ### library annnotations

# %%
library = pd.read_csv(library_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_a1814">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1814_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_a1814_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_a1814_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_a1814_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_a1814_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_a1814_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_a1814_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_a1814_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_a1814_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_a1814_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_a1814_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_a1814_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_a1814_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_a1814_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_a1814_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_a1814_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_a1814_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_a1814_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_a1814_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_a1814_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_a1814_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_a1814_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_a1814_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_a1814_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_a1814_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_a1814_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_a1814_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_a1814_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_a1814_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_a1814_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_a1814_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_a1814_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_a1814_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_a1814_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_a1814_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_a1814_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_a1814_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_a1814_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_a1814_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_a1814_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_a1814_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_a1814_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_a1814_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_a1814_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_a1814_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_a1814_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1814_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1814_row0_col0" class="data row0 col0" >SRX17520735</td>
#       <td id="T_a1814_row0_col1" class="data row0 col1" >SRP396531</td>
#       <td id="T_a1814_row0_col2" class="data row0 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_a1814_row0_col3" class="data row0 col3" >SRS15071300</td>
#       <td id="T_a1814_row0_col4" class="data row0 col4" ></td>
#       <td id="T_a1814_row0_col5" class="data row0 col5" ></td>
#       <td id="T_a1814_row0_col6" class="data row0 col6" ></td>
#       <td id="T_a1814_row0_col7" class="data row0 col7" ></td>
#       <td id="T_a1814_row0_col8" class="data row0 col8" ></td>
#       <td id="T_a1814_row0_col9" class="data row0 col9" >blood</td>
#       <td id="T_a1814_row0_col10" class="data row0 col10" >2.2</td>
#       <td id="T_a1814_row0_col11" class="data row0 col11" ></td>
#       <td id="T_a1814_row0_col12" class="data row0 col12" ></td>
#       <td id="T_a1814_row0_col13" class="data row0 col13" ></td>
#       <td id="T_a1814_row0_col14" class="data row0 col14" >F</td>
#       <td id="T_a1814_row0_col15" class="data row0 col15" ></td>
#       <td id="T_a1814_row0_col16" class="data row0 col16" ></td>
#       <td id="T_a1814_row0_col17" class="data row0 col17" >9646</td>
#       <td id="T_a1814_row0_col18" class="data row0 col18" ></td>
#       <td id="T_a1814_row0_col19" class="data row0 col19" ></td>
#       <td id="T_a1814_row0_col20" class="data row0 col20" ></td>
#       <td id="T_a1814_row0_col21" class="data row0 col21" ></td>
#       <td id="T_a1814_row0_col22" class="data row0 col22" ></td>
#       <td id="T_a1814_row0_col23" class="data row0 col23" >PN</td>
#       <td id="T_a1814_row0_col24" class="data row0 col24" >SAMN30788824</td>
#       <td id="T_a1814_row0_col25" class="data row0 col25" >2.2</td>
#       <td id="T_a1814_row0_col26" class="data row0 col26" >year</td>
#       <td id="T_a1814_row0_col27" class="data row0 col27" ></td>
#       <td id="T_a1814_row0_col28" class="data row0 col28" ></td>
#       <td id="T_a1814_row0_col29" class="data row0 col29" ></td>
#       <td id="T_a1814_row0_col30" class="data row0 col30" ></td>
#       <td id="T_a1814_row0_col31" class="data row0 col31" ></td>
#       <td id="T_a1814_row0_col32" class="data row0 col32" >Captive</td>
#       <td id="T_a1814_row0_col33" class="data row0 col33" ></td>
#       <td id="T_a1814_row0_col34" class="data row0 col34" ></td>
#       <td id="T_a1814_row0_col35" class="data row0 col35" >08/04/2026</td>
#       <td id="T_a1814_row0_col36" class="data row0 col36" >Captive_1</td>
#       <td id="T_a1814_row0_col37" class="data row0 col37" ></td>
#       <td id="T_a1814_row0_col38" class="data row0 col38" >PN</td>
#       <td id="T_a1814_row0_col39" class="data row0 col39" ></td>
#       <td id="T_a1814_row0_col40" class="data row0 col40" ></td>
#       <td id="T_a1814_row0_col41" class="data row0 col41" ></td>
#       <td id="T_a1814_row0_col42" class="data row0 col42" >sub-adult</td>
#       <td id="T_a1814_row0_col43" class="data row0 col43" ></td>
#       <td id="T_a1814_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_a1814_row0_col45" class="data row0 col45" >RANDOM PCR</td>
#     </tr>
#     <tr>
#       <th id="T_a1814_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1814_row1_col0" class="data row1 col0" >SRX17520734</td>
#       <td id="T_a1814_row1_col1" class="data row1 col1" >SRP396531</td>
#       <td id="T_a1814_row1_col2" class="data row1 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_a1814_row1_col3" class="data row1 col3" >SRS15071299</td>
#       <td id="T_a1814_row1_col4" class="data row1 col4" ></td>
#       <td id="T_a1814_row1_col5" class="data row1 col5" ></td>
#       <td id="T_a1814_row1_col6" class="data row1 col6" ></td>
#       <td id="T_a1814

# %% [markdown]
# #### anatomical entity
# * [uberon ols](https://www.ebi.ac.uk/ols4/ontologies/uberon)

# %%
unique_sorted(library, "infoOrgan")
# Out:
# ['blood']

# %%
# all
library.loc[:,'anatId'] = 'UBERON:0000178'
library.loc[:,'anatName'] = 'blood'
# perfect match, missing child term, other
library.loc[:,'anatAnnotationStatus'] = 'perfect match'
# partial sampling, full sampling, not documented
library.loc[:,'anatBiologicalStatus'] = 'not documented'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_1f1d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f1d9_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_1f1d9_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_1f1d9_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_1f1d9_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_1f1d9_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_1f1d9_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_1f1d9_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_1f1d9_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_1f1d9_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_1f1d9_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_1f1d9_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_1f1d9_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_1f1d9_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_1f1d9_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_1f1d9_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_1f1d9_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_1f1d9_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_1f1d9_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_1f1d9_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_1f1d9_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_1f1d9_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_1f1d9_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_1f1d9_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_1f1d9_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_1f1d9_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_1f1d9_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_1f1d9_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_1f1d9_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_1f1d9_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_1f1d9_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_1f1d9_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_1f1d9_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_1f1d9_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_1f1d9_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_1f1d9_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_1f1d9_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_1f1d9_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_1f1d9_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_1f1d9_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_1f1d9_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_1f1d9_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_1f1d9_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_1f1d9_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_1f1d9_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_1f1d9_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_1f1d9_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f1d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f1d9_row0_col0" class="data row0 col0" >SRX17520735</td>
#       <td id="T_1f1d9_row0_col1" class="data row0 col1" >SRP396531</td>
#       <td id="T_1f1d9_row0_col2" class="data row0 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_1f1d9_row0_col3" class="data row0 col3" >SRS15071300</td>
#       <td id="T_1f1d9_row0_col4" class="data row0 col4" >UBERON:0000178</td>
#       <td id="T_1f1d9_row0_col5" class="data row0 col5" >blood</td>
#       <td id="T_1f1d9_row0_col6" class="data row0 col6" ></td>
#       <td id="T_1f1d9_row0_col7" class="data row0 col7" ></td>
#       <td id="T_1f1d9_row0_col8" class="data row0 col8" ></td>
#       <td id="T_1f1d9_row0_col9" class="data row0 col9" >blood</td>
#       <td id="T_1f1d9_row0_col10" class="data row0 col10" >2.2</td>
#       <td id="T_1f1d9_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_1f1d9_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_1f1d9_row0_col13" class="data row0 col13" ></td>
#       <td id="T_1f1d9_row0_col14" class="data row0 col14" >F</td>
#       <td id="T_1f1d9_row0_col15" class="data row0 col15" ></td>
#       <td id="T_1f1d9_row0_col16" class="data row0 col16" ></td>
#       <td id="T_1f1d9_row0_col17" class="data row0 col17" >9646</td>
#       <td id="T_1f1d9_row0_col18" class="data row0 col18" ></td>
#       <td id="T_1f1d9_row0_col19" class="data row0 col19" ></td>
#       <td id="T_1f1d9_row0_col20" class="data row0 col20" ></td>
#       <td id="T_1f1d9_row0_col21" class="data row0 col21" ></td>
#       <td id="T_1f1d9_row0_col22" class="data row0 col22" ></td>
#       <td id="T_1f1d9_row0_col23" class="data row0 col23" >PN</td>
#       <td id="T_1f1d9_row0_col24" class="data row0 col24" >SAMN30788824</td>
#       <td id="T_1f1d9_row0_col25" class="data row0 col25" >2.2</td>
#       <td id="T_1f1d9_row0_col26" class="data row0 col26" >year</td>
#       <td id="T_1f1d9_row0_col27" class="data row0 col27" ></td>
#       <td id="T_1f1d9_row0_col28" class="data row0 col28" ></td>
#       <td id="T_1f1d9_row0_col29" class="data row0 col29" ></td>
#       <td id="T_1f1d9_row0_col30" class="data row0 col30" ></td>
#       <td id="T_1f1d9_row0_col31" class="data row0 col31" ></td>
#       <td id="T_1f1d9_row0_col32" class="data row0 col32" >Captive</td>
#       <td id="T_1f1d9_row0_col33" class="data row0 col33" ></td>
#       <td id="T_1f1d9_row0_col34" class="data row0 col34" ></td>
#       <td id="T_1f1d9_row0_col35" class="data row0 col35" >08/04/2026</td>
#       <td id="T_1f1d9_row0_col36" class="data row0 col36" >Captive_1</td>
#       <td id="T_1f1d9_row0_col37" class="data row0 col37" ></td>
#       <td id="T_1f1d9_row0_col38" class="data row0 col38" >PN</td>
#       <td id="T_1f1d9_row0_col39" class="data row0 col39" ></td>
#       <td id="T_1f1d9_row0_col40" class="data row0 col40" ></td>
#       <td id="T_1f1d9_row0_col41" class="data row0 col41" ></td>
#       <td id="T_1f1d9_row0_col42" class="data row0 col42" >sub-adult</td>
#       <td id="T_1f1d9_row0_col43" class="data row0 col43" ></td>
#       <td id="T_1f1d9_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_1f1d9_row0_col45" class="data row0 col45" >RANDOM PCR</td>
#     </tr>
#     <tr>
#       <th id="T_1f1d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f1d9_row1_col0" class="data row1 col0" >SRX17520734</td>
#       <td id="T_1f1d9_row1_col1" class="data row1 col1" >SRP396531</td>
#       <td id="T_1f1d9_row1_col2" class="data row1 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_1f1d9_row1_col3" class="data row1 col3" >SRS15071299</td>
#       <td id="T_1f1d9_row1_col4" class="data row1 col4" >UBERON:0000178</td>
#       <td id="T_1f1d9_row1_col5" class="data row1 col5" >blood</td>
#       <td id="T_1f1

# %% [markdown]
# #### stage
# - [species specific developmental ontologies](https://github.com/obophenotype/developmental-stage-ontologies/tree/master/src/ontology/components)

# %%
unique_sorted(library, "infoStage")
# Out:
# ['1.5' '2.2' '2.3']

# %%
# all
library.loc[:,'stageId'] = 'UBERON:0034919'
library.loc[:,'stageName'] = 'juvenile stage'
# perfect match, missing child term, other
library.loc[:,'stageAnnotationStatus'] = 'missing child term'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_dc2e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc2e3_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_dc2e3_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_dc2e3_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_dc2e3_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_dc2e3_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_dc2e3_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_dc2e3_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_dc2e3_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_dc2e3_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_dc2e3_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_dc2e3_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_dc2e3_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_dc2e3_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_dc2e3_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_dc2e3_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_dc2e3_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_dc2e3_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_dc2e3_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_dc2e3_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_dc2e3_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_dc2e3_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_dc2e3_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_dc2e3_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_dc2e3_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_dc2e3_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_dc2e3_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_dc2e3_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_dc2e3_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_dc2e3_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_dc2e3_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_dc2e3_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_dc2e3_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_dc2e3_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_dc2e3_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_dc2e3_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_dc2e3_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_dc2e3_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_dc2e3_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_dc2e3_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_dc2e3_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_dc2e3_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_dc2e3_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_dc2e3_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_dc2e3_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_dc2e3_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_dc2e3_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc2e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc2e3_row0_col0" class="data row0 col0" >SRX17520735</td>
#       <td id="T_dc2e3_row0_col1" class="data row0 col1" >SRP396531</td>
#       <td id="T_dc2e3_row0_col2" class="data row0 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_dc2e3_row0_col3" class="data row0 col3" >SRS15071300</td>
#       <td id="T_dc2e3_row0_col4" class="data row0 col4" >UBERON:0000178</td>
#       <td id="T_dc2e3_row0_col5" class="data row0 col5" >blood</td>
#       <td id="T_dc2e3_row0_col6" class="data row0 col6" >UBERON:0034919</td>
#       <td id="T_dc2e3_row0_col7" class="data row0 col7" >juvenile stage</td>
#       <td id="T_dc2e3_row0_col8" class="data row0 col8" ></td>
#       <td id="T_dc2e3_row0_col9" class="data row0 col9" >blood</td>
#       <td id="T_dc2e3_row0_col10" class="data row0 col10" >2.2</td>
#       <td id="T_dc2e3_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_dc2e3_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_dc2e3_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_dc2e3_row0_col14" class="data row0 col14" >F</td>
#       <td id="T_dc2e3_row0_col15" class="data row0 col15" ></td>
#       <td id="T_dc2e3_row0_col16" class="data row0 col16" ></td>
#       <td id="T_dc2e3_row0_col17" class="data row0 col17" >9646</td>
#       <td id="T_dc2e3_row0_col18" class="data row0 col18" ></td>
#       <td id="T_dc2e3_row0_col19" class="data row0 col19" ></td>
#       <td id="T_dc2e3_row0_col20" class="data row0 col20" ></td>
#       <td id="T_dc2e3_row0_col21" class="data row0 col21" ></td>
#       <td id="T_dc2e3_row0_col22" class="data row0 col22" ></td>
#       <td id="T_dc2e3_row0_col23" class="data row0 col23" >PN</td>
#       <td id="T_dc2e3_row0_col24" class="data row0 col24" >SAMN30788824</td>
#       <td id="T_dc2e3_row0_col25" class="data row0 col25" >2.2</td>
#       <td id="T_dc2e3_row0_col26" class="data row0 col26" >year</td>
#       <td id="T_dc2e3_row0_col27" class="data row0 col27" ></td>
#       <td id="T_dc2e3_row0_col28" class="data row0 col28" ></td>
#       <td id="T_dc2e3_row0_col29" class="data row0 col29" ></td>
#       <td id="T_dc2e3_row0_col30" class="data row0 col30" ></td>
#       <td id="T_dc2e3_row0_col31" class="data row0 col31" ></td>
#       <td id="T_dc2e3_row0_col32" class="data row0 col32" >Captive</td>
#       <td id="T_dc2e3_row0_col33" class="data row0 col33" ></td>
#       <td id="T_dc2e3_row0_col34" class="data row0 col34" ></td>
#       <td id="T_dc2e3_row0_col35" class="data row0 col35" >08/04/2026</td>
#       <td id="T_dc2e3_row0_col36" class="data row0 col36" >Captive_1</td>
#       <td id="T_dc2e3_row0_col37" class="data row0 col37" ></td>
#       <td id="T_dc2e3_row0_col38" class="data row0 col38" >PN</td>
#       <td id="T_dc2e3_row0_col39" class="data row0 col39" ></td>
#       <td id="T_dc2e3_row0_col40" class="data row0 col40" ></td>
#       <td id="T_dc2e3_row0_col41" class="data row0 col41" ></td>
#       <td id="T_dc2e3_row0_col42" class="data row0 col42" >sub-adult</td>
#       <td id="T_dc2e3_row0_col43" class="data row0 col43" ></td>
#       <td id="T_dc2e3_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_dc2e3_row0_col45" class="data row0 col45" >RANDOM PCR</td>
#     </tr>
#     <tr>
#       <th id="T_dc2e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc2e3_row1_col0" class="data row1 col0" >SRX17520734</td>
#       <td id="T_dc2e3_row1_col1" class="data row1 col1" >SRP396531</td>
#       <td id="T_dc2e3_row1_col2" class="data row1 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_dc2e3_row1_col3" class="data row1 col3" >SRS15071299</td>
#       <td id="T_dc2e3_row1_col4" class="data row1 col4" >UBERON:0000178</td>
#       <td id="T_dc2e3_row1_col5" class="d

# %% [markdown]
# #### sex, strain, genotype, speciesId
# - uniprot [strain list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/strains)
# - uniprot [species list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/speclist)
# - bgee [strain mapping](https://gitlab.sib.swiss/Bgee/expression-annotations/-/tree/develop/Strains?ref_type=heads)

# %%
#library.loc[:,'sex'] = ''
#library.loc[library["sex"] == "male", "sex"] = "M"
#library.loc[library["sex"] == "female", "sex"] = "F"

#library.loc[:,'strain'] = ''

#library.loc[:,'genotype'] = ''

#library.loc[:,'speciesId'] = ''

# view
display_df(library)

# %% [markdown]
# #### protocol
# see [bulk kits](https://gitlab.sib.swiss/Bgee/scRNA-Seq/-/blob/main/scripts/bulk_kits.csv) for some common protocols

# %%
# making these variables because we use them again in the experiment file
my_protocol = 'NEBNext Ultra RNA Library Prep Kit'
# full_length or 3'
my_protocolType = 'full_length'

library.loc[:,'protocol'] = my_protocol
library.loc[:,'protocolType'] = my_protocolType
# polyA, ribo-minus, miRNA, lncRNA, circRNA
library.loc[:,'RNASelection'] = 'polyA'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_80132">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80132_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_80132_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_80132_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_80132_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_80132_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_80132_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_80132_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_80132_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_80132_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_80132_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_80132_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_80132_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_80132_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_80132_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_80132_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_80132_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_80132_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_80132_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_80132_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_80132_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_80132_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_80132_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_80132_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_80132_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_80132_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_80132_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_80132_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_80132_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_80132_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_80132_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_80132_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_80132_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_80132_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_80132_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_80132_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_80132_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_80132_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_80132_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_80132_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_80132_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_80132_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_80132_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_80132_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_80132_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_80132_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_80132_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80132_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80132_row0_col0" class="data row0 col0" >SRX17520735</td>
#       <td id="T_80132_row0_col1" class="data row0 col1" >SRP396531</td>
#       <td id="T_80132_row0_col2" class="data row0 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_80132_row0_col3" class="data row0 col3" >SRS15071300</td>
#       <td id="T_80132_row0_col4" class="data row0 col4" >UBERON:0000178</td>
#       <td id="T_80132_row0_col5" class="data row0 col5" >blood</td>
#       <td id="T_80132_row0_col6" class="data row0 col6" >UBERON:0034919</td>
#       <td id="T_80132_row0_col7" class="data row0 col7" >juvenile stage</td>
#       <td id="T_80132_row0_col8" class="data row0 col8" ></td>
#       <td id="T_80132_row0_col9" class="data row0 col9" >blood</td>
#       <td id="T_80132_row0_col10" class="data row0 col10" >2.2</td>
#       <td id="T_80132_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_80132_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_80132_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_80132_row0_col14" class="data row0 col14" >F</td>
#       <td id="T_80132_row0_col15" class="data row0 col15" ></td>
#       <td id="T_80132_row0_col16" class="data row0 col16" ></td>
#       <td id="T_80132_row0_col17" class="data row0 col17" >9646</td>
#       <td id="T_80132_row0_col18" class="data row0 col18" >NEBNext Ultra RNA Library Prep Kit</td>
#       <td id="T_80132_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_80132_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_80132_row0_col21" class="data row0 col21" ></td>
#       <td id="T_80132_row0_col22" class="data row0 col22" ></td>
#       <td id="T_80132_row0_col23" class="data row0 col23" >PN</td>
#       <td id="T_80132_row0_col24" class="data row0 col24" >SAMN30788824</td>
#       <td id="T_80132_row0_col25" class="data row0 col25" >2.2</td>
#       <td id="T_80132_row0_col26" class="data row0 col26" >year</td>
#       <td id="T_80132_row0_col27" class="data row0 col27" ></td>
#       <td id="T_80132_row0_col28" class="data row0 col28" ></td>
#       <td id="T_80132_row0_col29" class="data row0 col29" ></td>
#       <td id="T_80132_row0_col30" class="data row0 col30" ></td>
#       <td id="T_80132_row0_col31" class="data row0 col31" ></td>
#       <td id="T_80132_row0_col32" class="data row0 col32" >Captive</td>
#       <td id="T_80132_row0_col33" class="data row0 col33" ></td>
#       <td id="T_80132_row0_col34" class="data row0 col34" ></td>
#       <td id="T_80132_row0_col35" class="data row0 col35" >08/04/2026</td>
#       <td id="T_80132_row0_col36" class="data row0 col36" >Captive_1</td>
#       <td id="T_80132_row0_col37" class="data row0 col37" ></td>
#       <td id="T_80132_row0_col38" class="data row0 col38" >PN</td>
#       <td id="T_80132_row0_col39" class="data row0 col39" ></td>
#       <td id="T_80132_row0_col40" class="data row0 col40" ></td>
#       <td id="T_80132_row0_col41" class="data row0 col41" ></td>
#       <td id="T_80132_row0_col42" class="data row0 col42" >sub-adult</td>
#       <td id="T_80132_row0_col43" class="data row0 col43" ></td>
#       <td id="T_80132_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_80132_row0_col45" class="data row0 col45" >RANDOM PCR</td>
#     </tr>
#     <tr>
#       <th id="T_80132_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80132_row1_col0" class="data row1 col0" >SRX17520734</td>
#       <td id="T_80132_row1_col1" class="data row1 col1" >SRP396531</td>
#       <td id="T_80132_row1_col2" class="data row1 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_80132_row1_col3" class="data row1 col3" >SRS15071299</td>
#       <td id="T_80132_row1_col4" class="data row1 col4" >UBERON:0000

# %% [markdown]
# #### globin, replicates

# %%
# check for duplicate SRSId values
dup_check(library, "SRSId")
# Out:
# no duplicate values in SRSId

# %%
#library.loc[:,'globin_reduction'] = 'Y'

# replicates
#library.loc[library["#libraryId"] == "old", "replicate"] = "1"
#library.loc[library["#libraryId"].isin(["one", "two"]), "replicate"] = "1"

# view
display_df(library)

# %% [markdown]
# #### sample age, pato, physiological status
# * [PATO](https://www.ebi.ac.uk/ols4/ontologies/pato)
# * [EFO](https://www.ebi.ac.uk/ols4/ontologies/efo)

# %%
#library.loc[:,'sampleAge_value'] = ''
#library.loc[:,'sampleAge_unit'] = ''

# ex. castrated male
#library.loc[:,'PATOid'] = ''
#library.loc[:,'PATOname'] = ''

# ex. castrated, pregnant, pre-smoltification, post-smoltification, laying eggs
#library.loc[:,'physiologicalStatus'] = ''

# ex. left, right
#library.loc[:,'EFOid'] = ''
#library.loc[:,'EFOname'] = ''

# view
display_df(library)

# %% [markdown]
# #### condition

# %%
# ex. control, diet, light, reproductive capacity, time post mortem, time post feeding, 
# exercise details, menstruation, personality, litter size 
#library.loc[library["condition"] == "old", "condition"] = "new"

# view
display_df(library)

# %% [markdown]
# #### annotator id, last modification date

# %%
library.loc[:,'annotatorId'] = 'SAC'
library.loc[:,'lastModificationDate'] = '2026-04-08'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_d7841">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7841_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_d7841_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_d7841_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_d7841_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_d7841_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_d7841_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_d7841_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_d7841_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_d7841_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_d7841_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_d7841_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_d7841_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_d7841_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_d7841_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_d7841_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_d7841_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_d7841_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_d7841_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_d7841_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_d7841_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_d7841_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_d7841_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_d7841_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_d7841_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_d7841_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_d7841_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_d7841_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_d7841_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_d7841_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_d7841_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_d7841_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_d7841_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_d7841_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_d7841_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_d7841_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_d7841_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_d7841_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_d7841_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_d7841_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_d7841_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_d7841_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_d7841_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_d7841_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_d7841_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_d7841_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_d7841_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7841_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7841_row0_col0" class="data row0 col0" >SRX17520735</td>
#       <td id="T_d7841_row0_col1" class="data row0 col1" >SRP396531</td>
#       <td id="T_d7841_row0_col2" class="data row0 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_d7841_row0_col3" class="data row0 col3" >SRS15071300</td>
#       <td id="T_d7841_row0_col4" class="data row0 col4" >UBERON:0000178</td>
#       <td id="T_d7841_row0_col5" class="data row0 col5" >blood</td>
#       <td id="T_d7841_row0_col6" class="data row0 col6" >UBERON:0034919</td>
#       <td id="T_d7841_row0_col7" class="data row0 col7" >juvenile stage</td>
#       <td id="T_d7841_row0_col8" class="data row0 col8" ></td>
#       <td id="T_d7841_row0_col9" class="data row0 col9" >blood</td>
#       <td id="T_d7841_row0_col10" class="data row0 col10" >2.2</td>
#       <td id="T_d7841_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_d7841_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_d7841_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_d7841_row0_col14" class="data row0 col14" >F</td>
#       <td id="T_d7841_row0_col15" class="data row0 col15" ></td>
#       <td id="T_d7841_row0_col16" class="data row0 col16" ></td>
#       <td id="T_d7841_row0_col17" class="data row0 col17" >9646</td>
#       <td id="T_d7841_row0_col18" class="data row0 col18" >NEBNext Ultra RNA Library Prep Kit</td>
#       <td id="T_d7841_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_d7841_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_d7841_row0_col21" class="data row0 col21" ></td>
#       <td id="T_d7841_row0_col22" class="data row0 col22" ></td>
#       <td id="T_d7841_row0_col23" class="data row0 col23" >PN</td>
#       <td id="T_d7841_row0_col24" class="data row0 col24" >SAMN30788824</td>
#       <td id="T_d7841_row0_col25" class="data row0 col25" >2.2</td>
#       <td id="T_d7841_row0_col26" class="data row0 col26" >year</td>
#       <td id="T_d7841_row0_col27" class="data row0 col27" ></td>
#       <td id="T_d7841_row0_col28" class="data row0 col28" ></td>
#       <td id="T_d7841_row0_col29" class="data row0 col29" ></td>
#       <td id="T_d7841_row0_col30" class="data row0 col30" ></td>
#       <td id="T_d7841_row0_col31" class="data row0 col31" ></td>
#       <td id="T_d7841_row0_col32" class="data row0 col32" >Captive</td>
#       <td id="T_d7841_row0_col33" class="data row0 col33" ></td>
#       <td id="T_d7841_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_d7841_row0_col35" class="data row0 col35" >2026-04-08</td>
#       <td id="T_d7841_row0_col36" class="data row0 col36" >Captive_1</td>
#       <td id="T_d7841_row0_col37" class="data row0 col37" ></td>
#       <td id="T_d7841_row0_col38" class="data row0 col38" >PN</td>
#       <td id="T_d7841_row0_col39" class="data row0 col39" ></td>
#       <td id="T_d7841_row0_col40" class="data row0 col40" ></td>
#       <td id="T_d7841_row0_col41" class="data row0 col41" ></td>
#       <td id="T_d7841_row0_col42" class="data row0 col42" >sub-adult</td>
#       <td id="T_d7841_row0_col43" class="data row0 col43" ></td>
#       <td id="T_d7841_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_d7841_row0_col45" class="data row0 col45" >RANDOM PCR</td>
#     </tr>
#     <tr>
#       <th id="T_d7841_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7841_row1_col0" class="data row1 col0" >SRX17520734</td>
#       <td id="T_d7841_row1_col1" class="data row1 col1" >SRP396531</td>
#       <td id="T_d7841_row1_col2" class="data row1 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_d7841_row1_col3" class="data row1 col3" >SRS15071299</td>
#       <td id="T_d7841_row1_col4" class="data row1 col4" >UBERON:0

# %% [markdown]
# #### comments

# %%
library.loc[:,'comment'] = 'PMID: 36303550'

# %% [markdown]
# #### save complete file with correct columns

# %%
library_file_complete = library[library_cols]
library_file_complete.to_csv(library_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# view
display_df(library_file_complete)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_43497">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43497_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_43497_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_43497_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_43497_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_43497_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_43497_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_43497_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_43497_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_43497_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_43497_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_43497_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_43497_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_43497_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_43497_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_43497_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_43497_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_43497_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_43497_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_43497_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_43497_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_43497_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_43497_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_43497_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_43497_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_43497_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_43497_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_43497_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_43497_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_43497_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_43497_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_43497_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_43497_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_43497_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_43497_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_43497_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_43497_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43497_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43497_row0_col0" class="data row0 col0" >SRX17520735</td>
#       <td id="T_43497_row0_col1" class="data row0 col1" >SRP396531</td>
#       <td id="T_43497_row0_col2" class="data row0 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_43497_row0_col3" class="data row0 col3" >SRS15071300</td>
#       <td id="T_43497_row0_col4" class="data row0 col4" >UBERON:0000178</td>
#       <td id="T_43497_row0_col5" class="data row0 col5" >blood</td>
#       <td id="T_43497_row0_col6" class="data row0 col6" >UBERON:0034919</td>
#       <td id="T_43497_row0_col7" class="data row0 col7" >juvenile stage</td>
#       <td id="T_43497_row0_col8" class="data row0 col8" ></td>
#       <td id="T_43497_row0_col9" class="data row0 col9" >blood</td>
#       <td id="T_43497_row0_col10" class="data row0 col10" >2.2</td>
#       <td id="T_43497_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_43497_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_43497_row0_col13" class="data row0 col13" >missing child term</td>
#       <td id="T_43497_row0_col14" class="data row0 col14" >F</td>
#       <td id="T_43497_row0_col15" class="data row0 col15" ></td>
#       <td id="T_43497_row0_col16" class="data row0 col16" ></td>
#       <td id="T_43497_row0_col17" class="data row0 col17" >9646</td>
#       <td id="T_43497_row0_col18" class="data row0 col18" >NEBNext Ultra RNA Library Prep Kit</td>
#       <td id="T_43497_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_43497_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_43497_row0_col21" class="data row0 col21" ></td>
#       <td id="T_43497_row0_col22" class="data row0 col22" ></td>
#       <td id="T_43497_row0_col23" class="data row0 col23" >PN</td>
#       <td id="T_43497_row0_col24" class="data row0 col24" >SAMN30788824</td>
#       <td id="T_43497_row0_col25" class="data row0 col25" >2.2</td>
#       <td id="T_43497_row0_col26" class="data row0 col26" >year</td>
#       <td id="T_43497_row0_col27" class="data row0 col27" ></td>
#       <td id="T_43497_row0_col28" class="data row0 col28" ></td>
#       <td id="T_43497_row0_col29" class="data row0 col29" ></td>
#       <td id="T_43497_row0_col30" class="data row0 col30" ></td>
#       <td id="T_43497_row0_col31" class="data row0 col31" >PMID: 36303550</td>
#       <td id="T_43497_row0_col32" class="data row0 col32" >Captive</td>
#       <td id="T_43497_row0_col33" class="data row0 col33" ></td>
#       <td id="T_43497_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_43497_row0_col35" class="data row0 col35" >2026-04-08</td>
#     </tr>
#     <tr>
#       <th id="T_43497_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43497_row1_col0" class="data row1 col0" >SRX17520734</td>
#       <td id="T_43497_row1_col1" class="data row1 col1" >SRP396531</td>
#       <td id="T_43497_row1_col2" class="data row1 col2" >Illumina NovaSeq 6000</td>
#       <td id="T_43497_row1_col3" class="data row1 col3" >SRS15071299</td>
#       <td id="T_43497_row1_col4" class="data row1 col4" >UBERON:0000178</td>
#       <td id="T_43497_row1_col5" class="data row1 col5" >blood</td>
#       <td id="T_43497_row1_col6" class="data row1 col6" >UBERON:0034919</td>
#       <td id="T_43497_row1_col7" class="data row1 col7" >juvenile stage</td>
#       <td id="T_43497_row1_col8" class="data row1 col8" ></td>
#       <td id="T_43497_row1_col9" class="data row1 col9" >blood</td>
#       <td id="T_43497_row1_col10" class="data row1 col10" >2.2</td>
#       <td id="T_43497_row1_col11" class="data row1 col11" >perfect match</td>
#       <td id="T_43497_row1_col12" class="data row1 col12" >not documented</td>
#       <td id="T_43497_row1_col13" class="data row1 col13" >missing child term</td>
#       <td id="T_43497_row1_col14" class="data row1 col14" >M</td>
#       <td id="T_43497_row1_col15" class="data row1 col15" ></td>
#       <td id="T_43497_row1_col16" class="data row1 col16" ></td>
#       <td id="T_43497_row1_col17" class="data row1 col17" >9646</td>
#       <td id="T_43497_row1_col18" class="data row1 col18" >NEBNext Ultra RNA Library Prep Kit</td>
#       <td id="T_43497_row1_col19" class="data row1 col19" >full_length</td>
#       <td id="T_43497_row1_col20" class="data row1 col20" >polyA</td>
#       <td id="T_43497_row1_col21" class="data row1 col21" ></td>
#       <td id="T_43497_row1_col22" class="data row1 col22" ></td>
#       <td id="T_43497_row1_col23" class="data row1 col23" >QL RNA-seq</td>
#       <td id="T_43497_row1_col24" class="data row1 col24" >SAMN30788823</td>
#       <td id="T_43497_row1_col25" class="data row1 col25" >2.2</td>
#       <td id="T_43497_row1_col26" clas

# %% [markdown]
# ### experiment annotations

# %%
experiment = pd.read_csv(experiment_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_61ecc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61ecc_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_61ecc_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_61ecc_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_61ecc_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_61ecc_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_61ecc_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_61ecc_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_61ecc_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_61ecc_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_61ecc_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_61ecc_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_61ecc_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_61ecc_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_61ecc_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_61ecc_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_61ecc_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61ecc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61ecc_row0_col0" class="data row0 col0" >SRP396531</td>
#       <td id="T_61ecc_row0_col1" class="data row0 col1" >Gene expression profiles of wild-trained and wild giant pandas</td>
#       <td id="T_61ecc_row0_col2" class="data row0 col2" >Gene expression profiles of wild-trained and wild giant pandas</td>
#       <td id="T_61ecc_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_61ecc_row0_col4" class="data row0 col4" ></td>
#       <td id="T_61ecc_row0_col5" class="data row0 col5" ></td>
#       <td id="T_61ecc_row0_col6" class="data row0 col6" ></td>
#       <td id="T_61ecc_row0_col7" class="data row0 col7" ></td>
#       <td id="T_61ecc_row0_col8" class="data row0 col8" ></td>
#       <td id="T_61ecc_row0_col9" class="data row0 col9" ></td>
#       <td id="T_61ecc_row0_col10" class="data row0 col10" >PRJNA878951</td>
#       <td id="T_61ecc_row0_col11" class="data row0 col11" ></td>
#       <td id="T_61ecc_row0_col12" class="data row0 col12" ></td>
#       <td id="T_61ecc_row0_col13" class="data row0 col13" >E,r,r,o,r,:, ,U,n,a,b,l,e, ,t,o, ,r,e,t,r,i,e,v,e, ,d,a,t,a,,, ,S,t,a,t,u,s, ,c,o,d,e, ,4,0,4</td>
#       <td id="T_61ecc_row0_col14" class="data row0 col14" ></td>
#       <td id="T_61ecc_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### experiment and protocol details

# %%
# this will give you the number of rows in the complete library file 
# this should be the number of annotated libraries
ann_lib = len(library_file_complete.index)
len(library_file_complete.index)
# Out:
# 12

# %%
# partial or total
experiment.loc[:,'experimentStatus'] = 'total'
# Bgee 1K
experiment.loc[:,'projectTags'] = 'Bgee 1K' 
# see above cell, also can add as free text
experiment.loc[:,'numberOfAnnotatedLibraries'] = ann_lib

# these variables should already exist from above but if not can just add as free text
experiment.loc[:,'protocol'] = my_protocol
experiment.loc[:,'protocolType'] = my_protocolType

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_cb71f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb71f_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_cb71f_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_cb71f_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_cb71f_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_cb71f_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_cb71f_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_cb71f_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_cb71f_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_cb71f_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_cb71f_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_cb71f_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_cb71f_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_cb71f_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_cb71f_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_cb71f_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_cb71f_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb71f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb71f_row0_col0" class="data row0 col0" >SRP396531</td>
#       <td id="T_cb71f_row0_col1" class="data row0 col1" >Gene expression profiles of wild-trained and wild giant pandas</td>
#       <td id="T_cb71f_row0_col2" class="data row0 col2" >Gene expression profiles of wild-trained and wild giant pandas</td>
#       <td id="T_cb71f_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_cb71f_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_cb71f_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_cb71f_row0_col6" class="data row0 col6" >12</td>
#       <td id="T_cb71f_row0_col7" class="data row0 col7" >NEBNext Ultra RNA Library Prep Kit</td>
#       <td id="T_cb71f_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_cb71f_row0_col9" class="data row0 col9" ></td>
#       <td id="T_cb71f_row0_col10" class="data row0 col10" >PRJNA878951</td>
#       <td id="T_cb71f_row0_col11" class="data row0 col11" ></td>
#       <td id="T_cb71f_row0_col12" class="data row0 col12" ></td>
#       <td id="T_cb71f_row0_col13" class="data row0 col13" >E,r,r,o,r,:, ,U,n,a,b,l,e, ,t,o, ,r,e,t,r,i,e,v,e, ,d,a,t,a,,, ,S,t,a,t,u,s, ,c,o,d,e, ,4,0,4</td>
#       <td id="T_cb71f_row0_col14" class="data row0 col14" ></td>
#       <td id="T_cb71f_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### paper and xrefs

# %%
#experiment.loc[:,'GSE'] = ''
#experiment.loc[:,'Bioproject'] = '' 
experiment.loc[:,'PMID'] = '36303550'
experiment.loc[:,'reference_url'] = 'https://pmc.ncbi.nlm.nih.gov/articles/PMC9592921/'
experiment.loc[:,'DOI'] = '10.3389/fgene.2022.995700'
experiment.loc[:,'xrefs'] = '34985592[PMID]'

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_42fac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42fac_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_42fac_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_42fac_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_42fac_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_42fac_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_42fac_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_42fac_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_42fac_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_42fac_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_42fac_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_42fac_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_42fac_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_42fac_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_42fac_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_42fac_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_42fac_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42fac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42fac_row0_col0" class="data row0 col0" >SRP396531</td>
#       <td id="T_42fac_row0_col1" class="data row0 col1" >Gene expression profiles of wild-trained and wild giant pandas</td>
#       <td id="T_42fac_row0_col2" class="data row0 col2" >Gene expression profiles of wild-trained and wild giant pandas</td>
#       <td id="T_42fac_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_42fac_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_42fac_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_42fac_row0_col6" class="data row0 col6" >12</td>
#       <td id="T_42fac_row0_col7" class="data row0 col7" >NEBNext Ultra RNA Library Prep Kit</td>
#       <td id="T_42fac_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_42fac_row0_col9" class="data row0 col9" ></td>
#       <td id="T_42fac_row0_col10" class="data row0 col10" >PRJNA878951</td>
#       <td id="T_42fac_row0_col11" class="data row0 col11" >36303550</td>
#       <td id="T_42fac_row0_col12" class="data row0 col12" >https://pmc.ncbi.nlm.nih.gov/articles/PMC9592921/</td>
#       <td id="T_42fac_row0_col13" class="data row0 col13" >10.3389/fgene.2022.995700</td>
#       <td id="T_42fac_row0_col14" class="data row0 col14" >34985592[PMID]</td>
#       <td id="T_42fac_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### comments

# %%
#experiment.loc[:,'comment'] = ''

display_df(experiment)

# %% [markdown]
# #### save complete file

# %%
experiment.to_csv(experiment_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ### QA time

# %%
library_to_add = pd.read_csv(library_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
experiment_to_add = pd.read_csv(experiment_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# %%
! python3 $path_to_v_script --bulk-exp $experiment_to_add_path --bulk-lib $library_to_add_path --rules-dir $path_to_rules --out $val_output --strict
# Out:
# Total issues: 0
# Errors: 0
# Warnings: 0
# Top codes:

# %% [markdown]
# #### check columns match

# %%
# pull from git and pull in library/experiment file
! git pull
git_library = pd.read_csv(git_library_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
git_experiment = pd.read_csv(git_experiment_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# library file
if set(library_to_add.columns) == set(git_library.columns):
    print('The columns in the library file match')
else:
    print('The columns in the library file DO NOT MATCH')

# experiment file
if set(experiment_to_add.columns) == set(git_experiment.columns):
    print('The columns in the experiment file match')
else:
    print('The columns in the experiment file DO NOT MATCH')


# maybe to make this something more like "COLUMNS GOOD - LIBRARY" and "COLUMNS BAD - EXPERIMENT"
# Out:
# Already up to date.
# The columns in the library file match
# The columns in the experiment file match

# %% [markdown]
# #### view files

# %%
library_git_plus_new = pd.concat([git_library, library_to_add], ignore_index = True, sort = False)
old_length = git_library.shape[0]
start = old_length - 2
end = old_length + 5
view_lib = library_git_plus_new.iloc[start:end]
view_lib
# Out:
#         #libraryId experimentId               platform        SRSId  \
# 58970  SRX16614830    SRP387848  Illumina NovaSeq 6000  SRS14249770
# 58971  SRX16614829    SRP387848  Illumina NovaSeq 6000  SRS14249769
# 58972  SRX17520735    SRP396531  Illumina NovaSeq 6000  SRS15071300
# 58973  SRX17520734    SRP396531  Illumina NovaSeq 6000  SRS15071299
# 58974  SRX17520733    SRP396531  Illumina NovaSeq 6000  SRS15071298
# 58975  SRX17520732    SRP396531  Illumina NovaSeq 6000  SRS15071297
# 58976  SRX17520731    SRP396531  Illumina NovaSeq 6000  SRS15071296
#
#                anatId anatName         stageId                  stageName  \
# 58970  UBERON:0000945  stomach  UBERON:0000113  post-juvenile adult stage
# 58971  UBERON:0000945  stomach  UBERON:0000113  post-juvenile adult stage
# 58972  UBERON:0000178    blood  UBERON:0034919             juvenile stage
# 58973  UBERON:0000178    blood  UBERON:0034919             juvenile stage
# 58974  UBERON:0000178    blood  UBERON:0034919             juvenile stage
# 58975  UBERON:0000178    blood  UBERON:0034919             juvenile stage
# 58976  UBERON:0000178    blood  UBERON:0034919             juvenile stage
#
#       url_GSM infoOrgan infoStage anatAnnotationStatus anatBiologicalStatus  \
# 58970           Stomach     Adult        perfect match       not documented
# 58971           Stomach     Adult        perfect match       not documented
# 58972             blood       2.2        perfect match       not documented
# 58973             blood       2.2        perfect match       not documented
# 58974             blood       2.2        perfect match       not documented
# 58975             blood       2.2        perfect match       not documented
# 58976             blood       1.5        perfect match       not documented
#
#       stageAnnotationStatus sex strain genotype speciesId  \
# 58970         perfect match   M                      9646
# 58971         perfect match   F                      9646
# 58972    missing child term   F                      9646
# 58973    missing child term   M                      9646
# 58974    missing child term   F                      9646
# 58975    missing child term   F                      9646
# 58976    missing child term   F                      9646
#
#                                  protocol protocolType RNASelection  \
# 58970  NEBNext Ultra RNA Library Prep Kit  full_length        polyA
# 58971  NEBNext Ultra RNA Library Prep Kit  full_length        polyA
# 58972  NEBNext Ultra RNA Library Prep Kit  full_length        polyA
# 58973  NEBNext Ultra RNA Library Prep Kit  full_length        polyA
# 58974  NEBNext Ultra RNA Library Prep Kit  full_length        polyA
# 58975  NEBNext Ultra RNA Library Prep Kit  full_length        polyA
# 58976  NEBNext Ultra RNA Library Prep Kit  full_length        polyA
#
#       globin_reduction replicate     lib_name    sampleName sampleAge_value  \
# 58970                                  aml_JV  SAMN29929501
# 58971                                aml_9775  SAMN29929500
# 58972                                      PN  SAMN30788824             2.2
# 58973                              QL RNA-seq  SAMN30788823             2.2
# 58974                                      QY  SAMN30788822             2.2
# 58975                                      JM  SAMN30788821             2.2
# 58976                             XHT RNA-seq  SAMN30788820             1.5
#
#       sampleAge_unit PATOid PATOname EFOid EFOname         comment  \
# 58970                                               PMID: 36011357
# 58971                                               PMID: 36011357
# 58972           year                                PMID: 36303550
# 58973           year                                PMID: 36303550
# 58974           year                                PMID: 36303550
# 58975           year                                PMID: 36303550
# 58976           year                                PMID: 36303550
#
#                condition physiologicalStatus annotatorId lastModificationDate
# 58970                                                SAC           2026-04-08
# 58971                                                SAC           2026-04-08
# 58972            Captive                             SAC           2026-04-08
# 58973            Captive                             SAC           2026-04-08
# 58974            Captive                             SAC           2026-04-08
# 58975            Captive                             SAC           2026-04-08
# 58976  Wildness training                             SAC           2026-04-08

# %%
experiment_git_plus_new = pd.concat([git_experiment, experiment_to_add], ignore_index = True, sort = False)
experiment_git_plus_new.tail(n=3)
# Out:
#      #experimentId                                     experimentName  \
# 1153     SRP358828  Ailuropoda melanoleuca hair follicle Raw seque...
# 1154     SRP387848  Comparative transcriptomics and methylomics re...
# 1155     SRP396531  Gene expression profiles of wild-trained and w...
#
#                                   experimentDescription experimentSource  \
# 1153  The aim of this study was to identify which ge...              SRA
# 1154  Both the giant panda (Ailuropoda melanoleuca) ...              SRA
# 1155  Gene expression profiles of wild-trained and w...              SRA
#
#      experimentStatus projectTags numberOfAnnotatedLibraries  \
# 1153            total     Bgee 1K                          2
# 1154          partial     Bgee 1K                         18
# 1155            total     Bgee 1K                         12
#
#                                 protocol protocolType GSE   Bioproject  \
# 1153  NEBNext Ultra RNA Library Prep Kit  full_length      PRJNA804355
# 1154  NEBNext Ultra RNA Library Prep Kit  full_length      PRJNA861855
# 1155  NEBNext Ultra RNA Library Prep Kit  full_length      PRJNA878951
#
#           PMID                                      reference_url  \
# 1153  35500067  https://onlinelibrary.wiley.com/doi/10.1111/17...
# 1154  36011357  https://pmc.ncbi.nlm.nih.gov/articles/PMC9407821/
# 1155  36303550  https://pmc.ncbi.nlm.nih.gov/articles/PMC9592921/
#
#                             DOI           xrefs  \
# 1153    10.1111/1749-4877.12652
# 1154      10.3390/genes13081446
# 1155  10.3389/fgene.2022.995700  34985592[PMID]
#
#                               comment
# 1153
# 1154  removed bisulfite seq libraries
# 1155

# %% [markdown]
# ### add annotations to git

# %%
! git pull
# Out:
# Already up to date.

# %%
library_git_plus_new.to_csv(git_library_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
experiment_git_plus_new.to_csv(git_experiment_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
update_format(git_library_path)
update_format(git_experiment_path)

# %%
! git status

# %%
! git add $git_experiment_path $git_library_path

# %%
! git commit -m $commit_message_exp
# Out:
# [develop 6c9ec12] adding annotated bulk experiment SRP396531
#  2 files changed, 13 insertions(+)

# %%
! git push
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 2.07 KiB | 2.07 MiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# remote:
# remote: To create a merge request for develop, visit:
# remote:   https://gitlab.sib.swiss/Bgee/expression-annotations/-/merge_requests/new?merge_request%5Bsource_branch%5D=develop
# remote:
# To https://gitlab.sib.swiss/Bgee/expression-annotations.git/
#    76f7f3e..6c9ec12  develop -> develop

# %% [markdown]
# ### add annotation folder and script to git

# %%
! git pull

# %% [markdown]
# 1. run first two cells (annotation summary)
# 2. export as html

# %%
! git add $path_to_output

# %%
! git commit -m $commit_message_py

# %%
! git push
