# %% [markdown]
# ## SRP254622
#
# **paper:** [no PMID](http://journal05.magtech.org.cn/Jwk_ny/EN/Y2020/V28/I11/2048#) - Analysis of the Antennal Transcriptome and Identification of Olfaction-related Genes of Trialeurodes vaporariorum, 2020
#
# **date, curator:** 2026-06-19, Sara Carsanaro
#
# **notes**
# * paper is in annotation folder (untranslated and translated)
# * methods have dev stage (adult) and confirm that RNA selection is polyA

# %% [markdown]
# ### annotation summary

# %%
anat_summary = library_to_add[['infoOrgan', 'anatId', 'anatName', 'anatAnnotationStatus']]
unique_anat = anat_summary.drop_duplicates()
display_df(unique_anat)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_e0332">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0332_level0_col0" class="col_heading level0 col0" >infoOrgan</th>
#       <th id="T_e0332_level0_col1" class="col_heading level0 col1" >anatId</th>
#       <th id="T_e0332_level0_col2" class="col_heading level0 col2" >anatName</th>
#       <th id="T_e0332_level0_col3" class="col_heading level0 col3" >anatAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0332_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0332_row0_col0" class="data row0 col0" >Antenna</td>
#       <td id="T_e0332_row0_col1" class="data row0 col1" >UBERON:0000972</td>
#       <td id="T_e0332_row0_col2" class="data row0 col2" >antenna</td>
#       <td id="T_e0332_row0_col3" class="data row0 col3" >perfect match</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dev_summary = library_to_add[['infoStage', 'stageId', 'stageName', 'stageAnnotationStatus']]
unique_dev = dev_summary.drop_duplicates()
display_df(unique_dev)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_f5607">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5607_level0_col0" class="col_heading level0 col0" >infoStage</th>
#       <th id="T_f5607_level0_col1" class="col_heading level0 col1" >stageId</th>
#       <th id="T_f5607_level0_col2" class="col_heading level0 col2" >stageName</th>
#       <th id="T_f5607_level0_col3" class="col_heading level0 col3" >stageAnnotationStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5607_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5607_row0_col0" class="data row0 col0" >adult</td>
#       <td id="T_f5607_row0_col1" class="data row0 col1" >UBERON:0000066</td>
#       <td id="T_f5607_row0_col2" class="data row0 col2" >fully formed stage</td>
#       <td id="T_f5607_row0_col3" class="data row0 col3" >perfect match</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### set variables, import packages, define functions

# %%
experiment_id = "SRP254622"

path_to_create_exp_script = "/Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py" 
experiment_type = "bulk"

path_to_output_main = "/Users/scarsana/Desktop/git/expression-annotations/Notebooks/bulk/" 
path_to_output = "{}{}/".format(path_to_output_main, experiment_id)
library_path_from_script = "{}RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_path_from_script = "{}RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
library_to_add_path = "{}complete_RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_to_add_path = "{}complete_RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
script_file = "{}.ipynb".format(experiment_id)
commit_message_exp = '"adding annotated bulk experiment {}"'.format(experiment_id)
commit_message_py = '"adding annotation files for {} to notebook folder"'.format(experiment_id)


## to add to git
path_to_git_annotations = "/Users/scarsana/Desktop/git/expression-annotations/RNA_Seq/"
git_library_path = "{}RNASeqLibrary.tsv".format(path_to_git_annotations)
git_experiment_path = "{}RNASeqExperiment.tsv".format(path_to_git_annotations)

## validation
path_to_v_script = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/validate_annotations.py'
path_to_rules = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/rules/'
val_output = "{}{}/validation.tsv".format(path_to_output_main, experiment_id)

library_cols = ['#libraryId', 'experimentId', 'platform', 'SRSId', 'anatId', 'anatName', 'stageId', 'stageName', 'url_GSM', 'infoOrgan', 'infoStage', 'anatAnnotationStatus', 'anatBiologicalStatus', 'stageAnnotationStatus', 'sex', 'strain', 'genotype', 'speciesId', 'protocol', 'protocolType', 'RNASelection', 'globin_reduction', 'replicate', 'lib_name', 'sampleName', 'sampleAge_value', 'sampleAge_unit', 'PATOid', 'PATOname','EFOid', 'EFOname','comment', 'condition', 'physiologicalStatus', 'annotatorId', 'lastModificationDate']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import os
import csv

# displays df with the scrollbar next to the DataFrame
def display_df(df):
    pd.set_option("display.max_rows", None)
    pd.set_option("display.max_columns", None)
    display(HTML("<div style='height: 300px; overflow: auto; width: fit-content'>" +
        df.style.to_html(index=False) + "</div>"))

# function that compares two columns in a dataframe and tells you which ones are not equal (case insensitive)
def compare_columns(df, col1, col2, return_col):
    compare_return = df[col1].str.lower() != df[col2].str.lower()  
    df.loc[compare_return, return_col] 
    if not any(compare_return):
        print("The two columns are equal (case insensitive)")
    else:
        print("The following rows are not equal: ")
        print(df.loc[compare_return, return_col])

# fixes formatting of file to match libreoffice settings/historic file format
def update_format(path):
    with open(path, 'r') as file:
        filedata = file.read()
    # Replace the target string
    filedata = filedata.replace("\t\"\"", "\t")
    # Write the file out again
    with open(path, 'w') as file:
        file.write(filedata)

# checks for duplicate values in a specific column and prints those values + the corresponding library id
def dup_check(df, column):
    duplicateCheck = df.duplicated(subset=[column], keep=False)
    duplicateCheck.sort_values(inplace=True)
    if duplicateCheck.unique().any() == False:
        print("no duplicate values in " + column)
    elif duplicateCheck.unique().any() == True and column != '#libraryId':
        dups = df[duplicateCheck].loc[:,['#libraryId', column]]
        df_dups = pd.DataFrame(dups)
        df_dups.sort_values(inplace=True, by=column)
        print(df_dups)
    elif duplicateCheck.unique().any() == True and column == '#libraryId':
        print(df[duplicateCheck].loc[:,['#libraryId']])

# prints all unique values in a specific column
def unique_sorted(df, column):
    unique = df[column].unique()
    unique.sort()
    print(unique)

# %% [markdown]
# ### script

# %%
! python3 $path_to_create_exp_script $experiment_id $path_to_output $experiment_type
# Out:
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:120: SyntaxWarning: invalid escape sequence '\('
#   all_protoc = [w.replace('(', '\(') for w in all_protoc]
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:121: SyntaxWarning: invalid escape sequence '\)'
#   all_protoc = [w.replace(')', '\)') for w in all_protoc]
# Be patient, it may take a few minutes.
# 100%|█████████████████████████████████████████████| 2/2 [00:02<00:00,  1.04s/it]
# 0 samples dont have attributes, try to find them somewhere else
# 0it [00:00, ?it/s]
# 0 samples dont have attributes

# %% [markdown]
# ### library annnotations

# %%
library = pd.read_csv(library_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_61986">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61986_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_61986_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_61986_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_61986_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_61986_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_61986_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_61986_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_61986_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_61986_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_61986_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_61986_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_61986_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_61986_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_61986_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_61986_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_61986_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_61986_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_61986_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_61986_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_61986_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_61986_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_61986_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_61986_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_61986_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_61986_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_61986_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_61986_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_61986_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_61986_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_61986_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_61986_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_61986_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_61986_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_61986_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_61986_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_61986_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_61986_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_61986_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_61986_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_61986_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_61986_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_61986_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_61986_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_61986_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_61986_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_61986_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61986_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61986_row0_col0" class="data row0 col0" >SRX8029762</td>
#       <td id="T_61986_row0_col1" class="data row0 col1" >SRP254622</td>
#       <td id="T_61986_row0_col2" class="data row0 col2" >Illumina HiSeq 4000</td>
#       <td id="T_61986_row0_col3" class="data row0 col3" >SRS6402118</td>
#       <td id="T_61986_row0_col4" class="data row0 col4" ></td>
#       <td id="T_61986_row0_col5" class="data row0 col5" ></td>
#       <td id="T_61986_row0_col6" class="data row0 col6" ></td>
#       <td id="T_61986_row0_col7" class="data row0 col7" ></td>
#       <td id="T_61986_row0_col8" class="data row0 col8" ></td>
#       <td id="T_61986_row0_col9" class="data row0 col9" >Antenna</td>
#       <td id="T_61986_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_61986_row0_col11" class="data row0 col11" ></td>
#       <td id="T_61986_row0_col12" class="data row0 col12" ></td>
#       <td id="T_61986_row0_col13" class="data row0 col13" ></td>
#       <td id="T_61986_row0_col14" class="data row0 col14" ></td>
#       <td id="T_61986_row0_col15" class="data row0 col15" ></td>
#       <td id="T_61986_row0_col16" class="data row0 col16" ></td>
#       <td id="T_61986_row0_col17" class="data row0 col17" >88556</td>
#       <td id="T_61986_row0_col18" class="data row0 col18" ></td>
#       <td id="T_61986_row0_col19" class="data row0 col19" ></td>
#       <td id="T_61986_row0_col20" class="data row0 col20" ></td>
#       <td id="T_61986_row0_col21" class="data row0 col21" ></td>
#       <td id="T_61986_row0_col22" class="data row0 col22" ></td>
#       <td id="T_61986_row0_col23" class="data row0 col23" >TV2</td>
#       <td id="T_61986_row0_col24" class="data row0 col24" >SAMN14489891</td>
#       <td id="T_61986_row0_col25" class="data row0 col25" ></td>
#       <td id="T_61986_row0_col26" class="data row0 col26" ></td>
#       <td id="T_61986_row0_col27" class="data row0 col27" ></td>
#       <td id="T_61986_row0_col28" class="data row0 col28" ></td>
#       <td id="T_61986_row0_col29" class="data row0 col29" ></td>
#       <td id="T_61986_row0_col30" class="data row0 col30" ></td>
#       <td id="T_61986_row0_col31" class="data row0 col31" ></td>
#       <td id="T_61986_row0_col32" class="data row0 col32" ></td>
#       <td id="T_61986_row0_col33" class="data row0 col33" ></td>
#       <td id="T_61986_row0_col34" class="data row0 col34" ></td>
#       <td id="T_61986_row0_col35" class="data row0 col35" >18/06/2026</td>
#       <td id="T_61986_row0_col36" class="data row0 col36" >Analysis of the antennal transcriptome Trialeurodes vaporariorum</td>
#       <td id="T_61986_row0_col37" class="data row0 col37" ></td>
#       <td id="T_61986_row0_col38" class="data row0 col38" >TV2</td>
#       <td id="T_61986_row0_col39" class="data row0 col39" ></td>
#       <td id="T_61986_row0_col40" class="data row0 col40" ></td>
#       <td id="T_61986_row0_col41" class="data row0 col41" ></td>
#       <td id="T_61986_row0_col42" class="data row0 col42" ></td>
#       <td id="T_61986_row0_col43" class="data row0 col43" ></td>
#       <td id="T_61986_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_61986_row0_col45" class="data row0 col45" >RT-PCR</td>
#     </tr>
#     <tr>
#       <th id="T_61986_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_61986_row1_col0" class="data row1 col0" >SRX8029761</td>
#       <td id="T_61986_row1_col1" class="data row1 col1" >SRP254622</td>
#       <td id="T_61986_row1_col2" class="data row1 col2" >Illumina HiSeq 4000</td>
#       <td id="T_61986_row1_col3" class="data row1 col3" >SRS6402117</td>
#       <td id="T_61986_row1_col4" class="data row1 col4" ></td>
#       <td id="T_61986_row1_col5" class="data row1 col5" ></td>
#       <td id="T_61986_row1_col6" class="data row1 col6" ><

# %% [markdown]
# #### anatomical entity
# * [uberon ols](https://www.ebi.ac.uk/ols4/ontologies/uberon)

# %%
unique_sorted(library, "infoOrgan")
# Out:
# ['Antenna']

# %%
# all
library.loc[:,'anatId'] = 'UBERON:0000972'
library.loc[:,'anatName'] = 'antenna'
# perfect match, missing child term, other
library.loc[:,'anatAnnotationStatus'] = 'perfect match'
# partial sampling, full sampling, not documented
library.loc[:,'anatBiologicalStatus'] = 'not documented'



# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_31fdf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31fdf_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_31fdf_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_31fdf_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_31fdf_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_31fdf_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_31fdf_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_31fdf_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_31fdf_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_31fdf_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_31fdf_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_31fdf_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_31fdf_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_31fdf_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_31fdf_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_31fdf_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_31fdf_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_31fdf_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_31fdf_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_31fdf_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_31fdf_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_31fdf_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_31fdf_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_31fdf_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_31fdf_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_31fdf_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_31fdf_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_31fdf_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_31fdf_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_31fdf_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_31fdf_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_31fdf_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_31fdf_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_31fdf_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_31fdf_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_31fdf_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_31fdf_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_31fdf_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_31fdf_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_31fdf_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_31fdf_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_31fdf_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_31fdf_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_31fdf_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_31fdf_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_31fdf_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_31fdf_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31fdf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31fdf_row0_col0" class="data row0 col0" >SRX8029762</td>
#       <td id="T_31fdf_row0_col1" class="data row0 col1" >SRP254622</td>
#       <td id="T_31fdf_row0_col2" class="data row0 col2" >Illumina HiSeq 4000</td>
#       <td id="T_31fdf_row0_col3" class="data row0 col3" >SRS6402118</td>
#       <td id="T_31fdf_row0_col4" class="data row0 col4" >UBERON:0000972</td>
#       <td id="T_31fdf_row0_col5" class="data row0 col5" >antenna</td>
#       <td id="T_31fdf_row0_col6" class="data row0 col6" ></td>
#       <td id="T_31fdf_row0_col7" class="data row0 col7" ></td>
#       <td id="T_31fdf_row0_col8" class="data row0 col8" ></td>
#       <td id="T_31fdf_row0_col9" class="data row0 col9" >Antenna</td>
#       <td id="T_31fdf_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_31fdf_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_31fdf_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_31fdf_row0_col13" class="data row0 col13" ></td>
#       <td id="T_31fdf_row0_col14" class="data row0 col14" ></td>
#       <td id="T_31fdf_row0_col15" class="data row0 col15" ></td>
#       <td id="T_31fdf_row0_col16" class="data row0 col16" ></td>
#       <td id="T_31fdf_row0_col17" class="data row0 col17" >88556</td>
#       <td id="T_31fdf_row0_col18" class="data row0 col18" ></td>
#       <td id="T_31fdf_row0_col19" class="data row0 col19" ></td>
#       <td id="T_31fdf_row0_col20" class="data row0 col20" ></td>
#       <td id="T_31fdf_row0_col21" class="data row0 col21" ></td>
#       <td id="T_31fdf_row0_col22" class="data row0 col22" ></td>
#       <td id="T_31fdf_row0_col23" class="data row0 col23" >TV2</td>
#       <td id="T_31fdf_row0_col24" class="data row0 col24" >SAMN14489891</td>
#       <td id="T_31fdf_row0_col25" class="data row0 col25" ></td>
#       <td id="T_31fdf_row0_col26" class="data row0 col26" ></td>
#       <td id="T_31fdf_row0_col27" class="data row0 col27" ></td>
#       <td id="T_31fdf_row0_col28" class="data row0 col28" ></td>
#       <td id="T_31fdf_row0_col29" class="data row0 col29" ></td>
#       <td id="T_31fdf_row0_col30" class="data row0 col30" ></td>
#       <td id="T_31fdf_row0_col31" class="data row0 col31" ></td>
#       <td id="T_31fdf_row0_col32" class="data row0 col32" ></td>
#       <td id="T_31fdf_row0_col33" class="data row0 col33" ></td>
#       <td id="T_31fdf_row0_col34" class="data row0 col34" ></td>
#       <td id="T_31fdf_row0_col35" class="data row0 col35" >18/06/2026</td>
#       <td id="T_31fdf_row0_col36" class="data row0 col36" >Analysis of the antennal transcriptome Trialeurodes vaporariorum</td>
#       <td id="T_31fdf_row0_col37" class="data row0 col37" ></td>
#       <td id="T_31fdf_row0_col38" class="data row0 col38" >TV2</td>
#       <td id="T_31fdf_row0_col39" class="data row0 col39" ></td>
#       <td id="T_31fdf_row0_col40" class="data row0 col40" ></td>
#       <td id="T_31fdf_row0_col41" class="data row0 col41" ></td>
#       <td id="T_31fdf_row0_col42" class="data row0 col42" ></td>
#       <td id="T_31fdf_row0_col43" class="data row0 col43" ></td>
#       <td id="T_31fdf_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_31fdf_row0_col45" class="data row0 col45" >RT-PCR</td>
#     </tr>
#     <tr>
#       <th id="T_31fdf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31fdf_row1_col0" class="data row1 col0" >SRX8029761</td>
#       <td id="T_31fdf_row1_col1" class="data row1 col1" >SRP254622</td>
#       <td id="T_31fdf_row1_col2" class="data row1 col2" >Illumina HiSeq 4000</td>
#       <td id="T_31fdf_row1_col3" class="data row1 col3" >SRS6402117</td>
#       <td id="T_31fdf_row1_col4" class="data row1 col4" >UBERON:0000972</td>
#       <td id="T_31fdf_row1_col5" class="data row1 col5" >an

# %% [markdown]
# #### stage
# - [species specific developmental ontologies](https://github.com/obophenotype/developmental-stage-ontologies/tree/master/src/ontology/components)

# %%
unique_sorted(library, "infoStage")
# Out:
# ['adult']

# %%
# all
library.loc[:,'stageId'] = 'UBERON:0000066'
library.loc[:,'stageName'] = 'fully formed stage'
# perfect match, missing child term, other
library.loc[:,'stageAnnotationStatus'] = 'perfect match'


# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_d536e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d536e_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_d536e_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_d536e_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_d536e_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_d536e_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_d536e_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_d536e_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_d536e_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_d536e_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_d536e_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_d536e_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_d536e_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_d536e_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_d536e_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_d536e_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_d536e_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_d536e_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_d536e_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_d536e_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_d536e_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_d536e_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_d536e_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_d536e_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_d536e_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_d536e_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_d536e_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_d536e_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_d536e_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_d536e_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_d536e_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_d536e_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_d536e_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_d536e_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_d536e_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_d536e_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_d536e_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_d536e_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_d536e_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_d536e_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_d536e_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_d536e_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_d536e_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_d536e_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_d536e_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_d536e_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_d536e_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d536e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d536e_row0_col0" class="data row0 col0" >SRX8029762</td>
#       <td id="T_d536e_row0_col1" class="data row0 col1" >SRP254622</td>
#       <td id="T_d536e_row0_col2" class="data row0 col2" >Illumina HiSeq 4000</td>
#       <td id="T_d536e_row0_col3" class="data row0 col3" >SRS6402118</td>
#       <td id="T_d536e_row0_col4" class="data row0 col4" >UBERON:0000972</td>
#       <td id="T_d536e_row0_col5" class="data row0 col5" >antenna</td>
#       <td id="T_d536e_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_d536e_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_d536e_row0_col8" class="data row0 col8" ></td>
#       <td id="T_d536e_row0_col9" class="data row0 col9" >Antenna</td>
#       <td id="T_d536e_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_d536e_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_d536e_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_d536e_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_d536e_row0_col14" class="data row0 col14" ></td>
#       <td id="T_d536e_row0_col15" class="data row0 col15" ></td>
#       <td id="T_d536e_row0_col16" class="data row0 col16" ></td>
#       <td id="T_d536e_row0_col17" class="data row0 col17" >88556</td>
#       <td id="T_d536e_row0_col18" class="data row0 col18" ></td>
#       <td id="T_d536e_row0_col19" class="data row0 col19" ></td>
#       <td id="T_d536e_row0_col20" class="data row0 col20" ></td>
#       <td id="T_d536e_row0_col21" class="data row0 col21" ></td>
#       <td id="T_d536e_row0_col22" class="data row0 col22" ></td>
#       <td id="T_d536e_row0_col23" class="data row0 col23" >TV2</td>
#       <td id="T_d536e_row0_col24" class="data row0 col24" >SAMN14489891</td>
#       <td id="T_d536e_row0_col25" class="data row0 col25" ></td>
#       <td id="T_d536e_row0_col26" class="data row0 col26" ></td>
#       <td id="T_d536e_row0_col27" class="data row0 col27" ></td>
#       <td id="T_d536e_row0_col28" class="data row0 col28" ></td>
#       <td id="T_d536e_row0_col29" class="data row0 col29" ></td>
#       <td id="T_d536e_row0_col30" class="data row0 col30" ></td>
#       <td id="T_d536e_row0_col31" class="data row0 col31" ></td>
#       <td id="T_d536e_row0_col32" class="data row0 col32" ></td>
#       <td id="T_d536e_row0_col33" class="data row0 col33" ></td>
#       <td id="T_d536e_row0_col34" class="data row0 col34" ></td>
#       <td id="T_d536e_row0_col35" class="data row0 col35" >18/06/2026</td>
#       <td id="T_d536e_row0_col36" class="data row0 col36" >Analysis of the antennal transcriptome Trialeurodes vaporariorum</td>
#       <td id="T_d536e_row0_col37" class="data row0 col37" ></td>
#       <td id="T_d536e_row0_col38" class="data row0 col38" >TV2</td>
#       <td id="T_d536e_row0_col39" class="data row0 col39" ></td>
#       <td id="T_d536e_row0_col40" class="data row0 col40" ></td>
#       <td id="T_d536e_row0_col41" class="data row0 col41" ></td>
#       <td id="T_d536e_row0_col42" class="data row0 col42" ></td>
#       <td id="T_d536e_row0_col43" class="data row0 col43" ></td>
#       <td id="T_d536e_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_d536e_row0_col45" class="data row0 col45" >RT-PCR</td>
#     </tr>
#     <tr>
#       <th id="T_d536e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d536e_row1_col0" class="data row1 col0" >SRX8029761</td>
#       <td id="T_d536e_row1_col1" class="data row1 col1" >SRP254622</td>
#       <td id="T_d536e_row1_col2" class="data row1 col2" >Illumina HiSeq 4000</td>
#       <td id="T_d536e_row1_col3" class="data row1 col3" >SRS6402117</td>
#       <td id="T_d536e_row1_col4" class="data row1 col4" >UBERON:0000972</td>
#       <td id="

# %% [markdown]
# #### sex, strain, genotype, speciesId
# - uniprot [strain list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/strains)
# - uniprot [species list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/speclist)
# - bgee [strain mapping](https://gitlab.sib.swiss/Bgee/expression-annotations/-/tree/develop/Strains?ref_type=heads)

# %%
library.loc[:,'sex'] = 'NA'
#library.loc[library["sex"] == "male", "sex"] = "M"
#library.loc[library["sex"] == "female", "sex"] = "F"

#library.loc[:,'strain'] = ''

#library.loc[:,'genotype'] = ''

#library.loc[:,'speciesId'] = ''

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_3719e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3719e_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_3719e_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_3719e_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_3719e_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_3719e_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_3719e_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_3719e_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_3719e_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_3719e_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_3719e_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_3719e_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_3719e_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_3719e_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_3719e_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_3719e_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_3719e_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_3719e_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_3719e_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_3719e_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_3719e_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_3719e_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_3719e_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_3719e_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_3719e_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_3719e_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_3719e_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_3719e_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_3719e_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_3719e_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_3719e_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_3719e_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_3719e_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_3719e_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_3719e_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_3719e_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_3719e_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_3719e_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_3719e_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_3719e_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_3719e_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_3719e_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_3719e_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_3719e_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_3719e_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_3719e_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_3719e_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3719e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3719e_row0_col0" class="data row0 col0" >SRX8029762</td>
#       <td id="T_3719e_row0_col1" class="data row0 col1" >SRP254622</td>
#       <td id="T_3719e_row0_col2" class="data row0 col2" >Illumina HiSeq 4000</td>
#       <td id="T_3719e_row0_col3" class="data row0 col3" >SRS6402118</td>
#       <td id="T_3719e_row0_col4" class="data row0 col4" >UBERON:0000972</td>
#       <td id="T_3719e_row0_col5" class="data row0 col5" >antenna</td>
#       <td id="T_3719e_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_3719e_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_3719e_row0_col8" class="data row0 col8" ></td>
#       <td id="T_3719e_row0_col9" class="data row0 col9" >Antenna</td>
#       <td id="T_3719e_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_3719e_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_3719e_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_3719e_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_3719e_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_3719e_row0_col15" class="data row0 col15" ></td>
#       <td id="T_3719e_row0_col16" class="data row0 col16" ></td>
#       <td id="T_3719e_row0_col17" class="data row0 col17" >88556</td>
#       <td id="T_3719e_row0_col18" class="data row0 col18" ></td>
#       <td id="T_3719e_row0_col19" class="data row0 col19" ></td>
#       <td id="T_3719e_row0_col20" class="data row0 col20" ></td>
#       <td id="T_3719e_row0_col21" class="data row0 col21" ></td>
#       <td id="T_3719e_row0_col22" class="data row0 col22" ></td>
#       <td id="T_3719e_row0_col23" class="data row0 col23" >TV2</td>
#       <td id="T_3719e_row0_col24" class="data row0 col24" >SAMN14489891</td>
#       <td id="T_3719e_row0_col25" class="data row0 col25" ></td>
#       <td id="T_3719e_row0_col26" class="data row0 col26" ></td>
#       <td id="T_3719e_row0_col27" class="data row0 col27" ></td>
#       <td id="T_3719e_row0_col28" class="data row0 col28" ></td>
#       <td id="T_3719e_row0_col29" class="data row0 col29" ></td>
#       <td id="T_3719e_row0_col30" class="data row0 col30" ></td>
#       <td id="T_3719e_row0_col31" class="data row0 col31" ></td>
#       <td id="T_3719e_row0_col32" class="data row0 col32" ></td>
#       <td id="T_3719e_row0_col33" class="data row0 col33" ></td>
#       <td id="T_3719e_row0_col34" class="data row0 col34" ></td>
#       <td id="T_3719e_row0_col35" class="data row0 col35" >18/06/2026</td>
#       <td id="T_3719e_row0_col36" class="data row0 col36" >Analysis of the antennal transcriptome Trialeurodes vaporariorum</td>
#       <td id="T_3719e_row0_col37" class="data row0 col37" ></td>
#       <td id="T_3719e_row0_col38" class="data row0 col38" >TV2</td>
#       <td id="T_3719e_row0_col39" class="data row0 col39" ></td>
#       <td id="T_3719e_row0_col40" class="data row0 col40" ></td>
#       <td id="T_3719e_row0_col41" class="data row0 col41" ></td>
#       <td id="T_3719e_row0_col42" class="data row0 col42" ></td>
#       <td id="T_3719e_row0_col43" class="data row0 col43" ></td>
#       <td id="T_3719e_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_3719e_row0_col45" class="data row0 col45" >RT-PCR</td>
#     </tr>
#     <tr>
#       <th id="T_3719e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3719e_row1_col0" class="data row1 col0" >SRX8029761</td>
#       <td id="T_3719e_row1_col1" class="data row1 col1" >SRP254622</td>
#       <td id="T_3719e_row1_col2" class="data row1 col2" >Illumina HiSeq 4000</td>
#       <td id="T_3719e_row1_col3" class="data row1 col3" >SRS6402117</td>
#       <td id="T_3719e_row1_col4" class="data row1 col4" >UBERON:0000972</td>
#       <td id

# %% [markdown]
# #### protocol
# see [bulk kits](https://gitlab.sib.swiss/Bgee/scRNA-Seq/-/blob/main/scripts/bulk_kits.csv) for some common protocols

# %%
# making these variables because we use them again in the experiment file
#my_protocol = ''
# full_length or 3'
#my_protocolType = ''

#library.loc[:,'protocol'] = my_protocol
#library.loc[:,'protocolType'] = my_protocolType
# polyA, ribo-minus, miRNA, lncRNA, circRNA
library.loc[:,'RNASelection'] = 'polyA'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_183d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_183d4_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_183d4_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_183d4_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_183d4_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_183d4_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_183d4_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_183d4_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_183d4_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_183d4_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_183d4_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_183d4_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_183d4_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_183d4_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_183d4_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_183d4_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_183d4_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_183d4_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_183d4_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_183d4_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_183d4_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_183d4_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_183d4_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_183d4_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_183d4_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_183d4_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_183d4_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_183d4_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_183d4_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_183d4_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_183d4_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_183d4_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_183d4_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_183d4_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_183d4_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_183d4_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_183d4_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_183d4_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_183d4_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_183d4_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_183d4_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_183d4_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_183d4_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_183d4_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_183d4_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_183d4_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_183d4_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_183d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_183d4_row0_col0" class="data row0 col0" >SRX8029762</td>
#       <td id="T_183d4_row0_col1" class="data row0 col1" >SRP254622</td>
#       <td id="T_183d4_row0_col2" class="data row0 col2" >Illumina HiSeq 4000</td>
#       <td id="T_183d4_row0_col3" class="data row0 col3" >SRS6402118</td>
#       <td id="T_183d4_row0_col4" class="data row0 col4" >UBERON:0000972</td>
#       <td id="T_183d4_row0_col5" class="data row0 col5" >antenna</td>
#       <td id="T_183d4_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_183d4_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_183d4_row0_col8" class="data row0 col8" ></td>
#       <td id="T_183d4_row0_col9" class="data row0 col9" >Antenna</td>
#       <td id="T_183d4_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_183d4_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_183d4_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_183d4_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_183d4_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_183d4_row0_col15" class="data row0 col15" ></td>
#       <td id="T_183d4_row0_col16" class="data row0 col16" ></td>
#       <td id="T_183d4_row0_col17" class="data row0 col17" >88556</td>
#       <td id="T_183d4_row0_col18" class="data row0 col18" ></td>
#       <td id="T_183d4_row0_col19" class="data row0 col19" ></td>
#       <td id="T_183d4_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_183d4_row0_col21" class="data row0 col21" ></td>
#       <td id="T_183d4_row0_col22" class="data row0 col22" ></td>
#       <td id="T_183d4_row0_col23" class="data row0 col23" >TV2</td>
#       <td id="T_183d4_row0_col24" class="data row0 col24" >SAMN14489891</td>
#       <td id="T_183d4_row0_col25" class="data row0 col25" ></td>
#       <td id="T_183d4_row0_col26" class="data row0 col26" ></td>
#       <td id="T_183d4_row0_col27" class="data row0 col27" ></td>
#       <td id="T_183d4_row0_col28" class="data row0 col28" ></td>
#       <td id="T_183d4_row0_col29" class="data row0 col29" ></td>
#       <td id="T_183d4_row0_col30" class="data row0 col30" ></td>
#       <td id="T_183d4_row0_col31" class="data row0 col31" ></td>
#       <td id="T_183d4_row0_col32" class="data row0 col32" ></td>
#       <td id="T_183d4_row0_col33" class="data row0 col33" ></td>
#       <td id="T_183d4_row0_col34" class="data row0 col34" ></td>
#       <td id="T_183d4_row0_col35" class="data row0 col35" >18/06/2026</td>
#       <td id="T_183d4_row0_col36" class="data row0 col36" >Analysis of the antennal transcriptome Trialeurodes vaporariorum</td>
#       <td id="T_183d4_row0_col37" class="data row0 col37" ></td>
#       <td id="T_183d4_row0_col38" class="data row0 col38" >TV2</td>
#       <td id="T_183d4_row0_col39" class="data row0 col39" ></td>
#       <td id="T_183d4_row0_col40" class="data row0 col40" ></td>
#       <td id="T_183d4_row0_col41" class="data row0 col41" ></td>
#       <td id="T_183d4_row0_col42" class="data row0 col42" ></td>
#       <td id="T_183d4_row0_col43" class="data row0 col43" ></td>
#       <td id="T_183d4_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_183d4_row0_col45" class="data row0 col45" >RT-PCR</td>
#     </tr>
#     <tr>
#       <th id="T_183d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_183d4_row1_col0" class="data row1 col0" >SRX8029761</td>
#       <td id="T_183d4_row1_col1" class="data row1 col1" >SRP254622</td>
#       <td id="T_183d4_row1_col2" class="data row1 col2" >Illumina HiSeq 4000</td>
#       <td id="T_183d4_row1_col3" class="data row1 col3" >SRS6402117</td>
#       <td id="T_183d4_row1_col4" class="data row1 col4" >UBERON:0000972</td>
#       <

# %% [markdown]
# #### globin, replicates

# %%
# check for duplicate SRSId values
dup_check(library, "SRSId")
# Out:
# no duplicate values in SRSId

# %%
#library.loc[:,'globin_reduction'] = 'Y'

# replicates
#library.loc[library["#libraryId"] == "old", "replicate"] = "1"
#library.loc[library["#libraryId"].isin(["one", "two"]), "replicate"] = "1"

# view
display_df(library)

# %% [markdown]
# #### sample age, pato, physiological status
# * [PATO](https://www.ebi.ac.uk/ols4/ontologies/pato)
# * [EFO](https://www.ebi.ac.uk/ols4/ontologies/efo)

# %%
#library.loc[:,'sampleAge_value'] = ''
#library.loc[:,'sampleAge_unit'] = ''

# ex. castrated male
#library.loc[:,'PATOid'] = ''
#library.loc[:,'PATOname'] = ''

# ex. castrated, pregnant, pre-smoltification, post-smoltification, laying eggs
#library.loc[:,'physiologicalStatus'] = ''

# ex. left, right
#library.loc[:,'EFOid'] = ''
#library.loc[:,'EFOname'] = ''

# view
display_df(library)

# %% [markdown]
# #### condition

# %%
# ex. control, diet, light, reproductive capacity, time post mortem, time post feeding, 
# exercise details, menstruation, personality, litter size 
#library.loc[library["condition"] == "old", "condition"] = "new"

# view
display_df(library)

# %% [markdown]
# #### annotator id, last modification date

# %%
library.loc[:,'annotatorId'] = 'SAC'
library.loc[:,'lastModificationDate'] = '2026-06-19'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_9ac4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ac4b_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_9ac4b_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_9ac4b_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_9ac4b_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_9ac4b_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_9ac4b_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_9ac4b_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_9ac4b_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_9ac4b_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_9ac4b_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_9ac4b_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_9ac4b_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_9ac4b_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_9ac4b_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_9ac4b_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_9ac4b_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_9ac4b_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_9ac4b_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_9ac4b_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_9ac4b_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_9ac4b_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_9ac4b_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_9ac4b_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_9ac4b_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_9ac4b_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_9ac4b_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_9ac4b_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_9ac4b_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_9ac4b_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_9ac4b_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_9ac4b_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_9ac4b_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_9ac4b_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_9ac4b_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_9ac4b_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_9ac4b_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_9ac4b_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_9ac4b_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_9ac4b_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_9ac4b_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_9ac4b_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_9ac4b_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_9ac4b_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_9ac4b_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_9ac4b_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_9ac4b_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ac4b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ac4b_row0_col0" class="data row0 col0" >SRX8029762</td>
#       <td id="T_9ac4b_row0_col1" class="data row0 col1" >SRP254622</td>
#       <td id="T_9ac4b_row0_col2" class="data row0 col2" >Illumina HiSeq 4000</td>
#       <td id="T_9ac4b_row0_col3" class="data row0 col3" >SRS6402118</td>
#       <td id="T_9ac4b_row0_col4" class="data row0 col4" >UBERON:0000972</td>
#       <td id="T_9ac4b_row0_col5" class="data row0 col5" >antenna</td>
#       <td id="T_9ac4b_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_9ac4b_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_9ac4b_row0_col8" class="data row0 col8" ></td>
#       <td id="T_9ac4b_row0_col9" class="data row0 col9" >Antenna</td>
#       <td id="T_9ac4b_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_9ac4b_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_9ac4b_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_9ac4b_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_9ac4b_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_9ac4b_row0_col15" class="data row0 col15" ></td>
#       <td id="T_9ac4b_row0_col16" class="data row0 col16" ></td>
#       <td id="T_9ac4b_row0_col17" class="data row0 col17" >88556</td>
#       <td id="T_9ac4b_row0_col18" class="data row0 col18" ></td>
#       <td id="T_9ac4b_row0_col19" class="data row0 col19" ></td>
#       <td id="T_9ac4b_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_9ac4b_row0_col21" class="data row0 col21" ></td>
#       <td id="T_9ac4b_row0_col22" class="data row0 col22" ></td>
#       <td id="T_9ac4b_row0_col23" class="data row0 col23" >TV2</td>
#       <td id="T_9ac4b_row0_col24" class="data row0 col24" >SAMN14489891</td>
#       <td id="T_9ac4b_row0_col25" class="data row0 col25" ></td>
#       <td id="T_9ac4b_row0_col26" class="data row0 col26" ></td>
#       <td id="T_9ac4b_row0_col27" class="data row0 col27" ></td>
#       <td id="T_9ac4b_row0_col28" class="data row0 col28" ></td>
#       <td id="T_9ac4b_row0_col29" class="data row0 col29" ></td>
#       <td id="T_9ac4b_row0_col30" class="data row0 col30" ></td>
#       <td id="T_9ac4b_row0_col31" class="data row0 col31" ></td>
#       <td id="T_9ac4b_row0_col32" class="data row0 col32" ></td>
#       <td id="T_9ac4b_row0_col33" class="data row0 col33" ></td>
#       <td id="T_9ac4b_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_9ac4b_row0_col35" class="data row0 col35" >2026-06-19</td>
#       <td id="T_9ac4b_row0_col36" class="data row0 col36" >Analysis of the antennal transcriptome Trialeurodes vaporariorum</td>
#       <td id="T_9ac4b_row0_col37" class="data row0 col37" ></td>
#       <td id="T_9ac4b_row0_col38" class="data row0 col38" >TV2</td>
#       <td id="T_9ac4b_row0_col39" class="data row0 col39" ></td>
#       <td id="T_9ac4b_row0_col40" class="data row0 col40" ></td>
#       <td id="T_9ac4b_row0_col41" class="data row0 col41" ></td>
#       <td id="T_9ac4b_row0_col42" class="data row0 col42" ></td>
#       <td id="T_9ac4b_row0_col43" class="data row0 col43" ></td>
#       <td id="T_9ac4b_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_9ac4b_row0_col45" class="data row0 col45" >RT-PCR</td>
#     </tr>
#     <tr>
#       <th id="T_9ac4b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ac4b_row1_col0" class="data row1 col0" >SRX8029761</td>
#       <td id="T_9ac4b_row1_col1" class="data row1 col1" >SRP254622</td>
#       <td id="T_9ac4b_row1_col2" class="data row1 col2" >Illumina HiSeq 4000</td>
#       <td id="T_9ac4b_row1_col3" class="data row1 col3" >SRS6402117</td>
#       <td id="T_9ac4b_row1_col4" class="data row1 col4" >UBERON:0000972</td>

# %% [markdown]
# #### comments

# %%
library.loc[:,'comment'] = 'no PMID or doi, see notebook folder for paper'

# %% [markdown]
# #### save complete file with correct columns

# %%
library_file_complete = library[library_cols]
library_file_complete.to_csv(library_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# view
display_df(library_file_complete)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_e8813">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8813_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_e8813_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_e8813_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_e8813_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_e8813_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_e8813_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_e8813_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_e8813_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_e8813_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_e8813_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_e8813_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_e8813_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_e8813_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_e8813_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_e8813_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_e8813_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_e8813_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_e8813_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_e8813_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_e8813_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_e8813_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_e8813_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_e8813_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_e8813_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_e8813_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_e8813_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_e8813_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_e8813_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_e8813_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_e8813_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_e8813_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_e8813_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_e8813_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_e8813_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_e8813_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_e8813_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8813_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8813_row0_col0" class="data row0 col0" >SRX8029762</td>
#       <td id="T_e8813_row0_col1" class="data row0 col1" >SRP254622</td>
#       <td id="T_e8813_row0_col2" class="data row0 col2" >Illumina HiSeq 4000</td>
#       <td id="T_e8813_row0_col3" class="data row0 col3" >SRS6402118</td>
#       <td id="T_e8813_row0_col4" class="data row0 col4" >UBERON:0000972</td>
#       <td id="T_e8813_row0_col5" class="data row0 col5" >antenna</td>
#       <td id="T_e8813_row0_col6" class="data row0 col6" >UBERON:0000066</td>
#       <td id="T_e8813_row0_col7" class="data row0 col7" >fully formed stage</td>
#       <td id="T_e8813_row0_col8" class="data row0 col8" ></td>
#       <td id="T_e8813_row0_col9" class="data row0 col9" >Antenna</td>
#       <td id="T_e8813_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_e8813_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_e8813_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_e8813_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_e8813_row0_col14" class="data row0 col14" >NA</td>
#       <td id="T_e8813_row0_col15" class="data row0 col15" ></td>
#       <td id="T_e8813_row0_col16" class="data row0 col16" ></td>
#       <td id="T_e8813_row0_col17" class="data row0 col17" >88556</td>
#       <td id="T_e8813_row0_col18" class="data row0 col18" ></td>
#       <td id="T_e8813_row0_col19" class="data row0 col19" ></td>
#       <td id="T_e8813_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_e8813_row0_col21" class="data row0 col21" ></td>
#       <td id="T_e8813_row0_col22" class="data row0 col22" ></td>
#       <td id="T_e8813_row0_col23" class="data row0 col23" >TV2</td>
#       <td id="T_e8813_row0_col24" class="data row0 col24" >SAMN14489891</td>
#       <td id="T_e8813_row0_col25" class="data row0 col25" ></td>
#       <td id="T_e8813_row0_col26" class="data row0 col26" ></td>
#       <td id="T_e8813_row0_col27" class="data row0 col27" ></td>
#       <td id="T_e8813_row0_col28" class="data row0 col28" ></td>
#       <td id="T_e8813_row0_col29" class="data row0 col29" ></td>
#       <td id="T_e8813_row0_col30" class="data row0 col30" ></td>
#       <td id="T_e8813_row0_col31" class="data row0 col31" >no PMID or doi, see notebook folder for paper</td>
#       <td id="T_e8813_row0_col32" class="data row0 col32" ></td>
#       <td id="T_e8813_row0_col33" class="data row0 col33" ></td>
#       <td id="T_e8813_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_e8813_row0_col35" class="data row0 col35" >2026-06-19</td>
#     </tr>
#     <tr>
#       <th id="T_e8813_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8813_row1_col0" class="data row1 col0" >SRX8029761</td>
#       <td id="T_e8813_row1_col1" class="data row1 col1" >SRP254622</td>
#       <td id="T_e8813_row1_col2" class="data row1 col2" >Illumina HiSeq 4000</td>
#       <td id="T_e8813_row1_col3" class="data row1 col3" >SRS6402117</td>
#       <td id="T_e8813_row1_col4" class="data row1 col4" >UBERON:0000972</td>
#       <td id="T_e8813_row1_col5" class="data row1 col5" >antenna</td>
#       <td id="T_e8813_row1_col6" class="data row1 col6" >UBERON:0000066</td>
#       <td id="T_e8813_row1_col7" class="data row1 col7" >fully formed stage</td>
#       <td id="T_e8813_row1_col8" class="data row1 col8" ></td>
#       <td id="T_e8813_row1_col9" class="data row1 col9" >Antenna</td>
#       <td id="T_e8813_row1_col10" class="data row1 col10" >adult</td>
#       <td id="T_e8813_row1_col11" class="data row1 col11" >perfect match</td>
#       <td id="T_e8813_row1_col12" class="data row1 col12" >not documented</td>
#       <td id="T_e8813_row1_col13" class="data row1 col13" >perfect match</td>
#       <td id="T_e8813_row1_col14" class="data row1 col14" >NA</td>
#       <td id="T_e8813_row1_col15" class="data row1 col15" ></td>
#       <td id="T_e8813_row1_col16" class="data row1 col16" ></td>
#       <td id="T_e8813_row1_col17" class="data row1 col17" >88556</td>
#       <td id="T_e8813_row1_col18" class="data row1 col18" ></td>
#       <td id="T_e8813_row1_col19" class="data row1 col19" ></td>
#       <td id="T_e8813_row1_col20" class="data row1 col20" >polyA</td>
#       <td id="T_e8813_row1_col21" class="data row1 col21" ></td>
#       <td id="T_e8813_row1_col22" class="data row1 col22" ></td>
#       <td id="T_e8813_row1_col23" class="data row1 col23" >TV1</td>
#       <td id="T_e8813_row1_col24" class="data row1 col24" >SAMN14489890</td>
#       <td id="T_e8813_row1_col25" class="data row1 col25" ></td>
#       <td id="T_e8813_row1_col26" class="data row1 col26" ></td>
#       <td id="T_e8813_row1_col27" class="data row

# %% [markdown]
# ### experiment annotations

# %%
experiment = pd.read_csv(experiment_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_89dde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89dde_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_89dde_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_89dde_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_89dde_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_89dde_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_89dde_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_89dde_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_89dde_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_89dde_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_89dde_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_89dde_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_89dde_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_89dde_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_89dde_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_89dde_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_89dde_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89dde_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89dde_row0_col0" class="data row0 col0" >SRP254622</td>
#       <td id="T_89dde_row0_col1" class="data row0 col1" >Antennal Transcriptome of Trialeurodes vaporariorum</td>
#       <td id="T_89dde_row0_col2" class="data row0 col2" >The purpose of this study is to establish a transcriptomic database of Trialeurodes vaporariorum antennaeand, and to investigate the number of genes encoding olfaction-related proteins.</td>
#       <td id="T_89dde_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_89dde_row0_col4" class="data row0 col4" ></td>
#       <td id="T_89dde_row0_col5" class="data row0 col5" ></td>
#       <td id="T_89dde_row0_col6" class="data row0 col6" ></td>
#       <td id="T_89dde_row0_col7" class="data row0 col7" ></td>
#       <td id="T_89dde_row0_col8" class="data row0 col8" ></td>
#       <td id="T_89dde_row0_col9" class="data row0 col9" ></td>
#       <td id="T_89dde_row0_col10" class="data row0 col10" >PRJNA616388</td>
#       <td id="T_89dde_row0_col11" class="data row0 col11" ></td>
#       <td id="T_89dde_row0_col12" class="data row0 col12" ></td>
#       <td id="T_89dde_row0_col13" class="data row0 col13" >E,r,r,o,r,:, ,U,n,a,b,l,e, ,t,o, ,r,e,t,r,i,e,v,e, ,d,a,t,a,,, ,S,t,a,t,u,s, ,c,o,d,e, ,4,0,4</td>
#       <td id="T_89dde_row0_col14" class="data row0 col14" ></td>
#       <td id="T_89dde_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### experiment and protocol details

# %%
# this will give you the number of rows in the complete library file 
# this should be the number of annotated libraries
ann_lib = len(library_file_complete.index)
len(library_file_complete.index)
# Out:
# 2

# %%
# partial or total
experiment.loc[:,'experimentStatus'] = 'total'
# Bgee 1K
experiment.loc[:,'projectTags'] = 'Bgee 1K' 
# see above cell, also can add as free text
experiment.loc[:,'numberOfAnnotatedLibraries'] = ann_lib

# these variables should already exist from above but if not can just add as free text
#experiment.loc[:,'protocol'] = my_protocol
#experiment.loc[:,'protocolType'] = my_protocolType

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_d7306">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7306_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_d7306_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_d7306_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_d7306_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_d7306_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_d7306_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_d7306_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_d7306_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_d7306_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_d7306_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_d7306_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_d7306_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_d7306_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_d7306_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_d7306_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_d7306_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7306_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7306_row0_col0" class="data row0 col0" >SRP254622</td>
#       <td id="T_d7306_row0_col1" class="data row0 col1" >Antennal Transcriptome of Trialeurodes vaporariorum</td>
#       <td id="T_d7306_row0_col2" class="data row0 col2" >The purpose of this study is to establish a transcriptomic database of Trialeurodes vaporariorum antennaeand, and to investigate the number of genes encoding olfaction-related proteins.</td>
#       <td id="T_d7306_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_d7306_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_d7306_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_d7306_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_d7306_row0_col7" class="data row0 col7" ></td>
#       <td id="T_d7306_row0_col8" class="data row0 col8" ></td>
#       <td id="T_d7306_row0_col9" class="data row0 col9" ></td>
#       <td id="T_d7306_row0_col10" class="data row0 col10" >PRJNA616388</td>
#       <td id="T_d7306_row0_col11" class="data row0 col11" ></td>
#       <td id="T_d7306_row0_col12" class="data row0 col12" ></td>
#       <td id="T_d7306_row0_col13" class="data row0 col13" >E,r,r,o,r,:, ,U,n,a,b,l,e, ,t,o, ,r,e,t,r,i,e,v,e, ,d,a,t,a,,, ,S,t,a,t,u,s, ,c,o,d,e, ,4,0,4</td>
#       <td id="T_d7306_row0_col14" class="data row0 col14" ></td>
#       <td id="T_d7306_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### paper and xrefs

# %%
#experiment.loc[:,'GSE'] = ''
#experiment.loc[:,'Bioproject'] = '' 
#experiment.loc[:,'PMID'] = ''
experiment.loc[:,'reference_url'] = 'http://journal05.magtech.org.cn/Jwk_ny/EN/Y2020/V28/I11/2048#'
experiment.loc[:,'DOI'] = ''
#experiment.loc[:,'xrefs'] = ''

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_01637">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01637_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_01637_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_01637_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_01637_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_01637_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_01637_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_01637_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_01637_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_01637_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_01637_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_01637_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_01637_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_01637_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_01637_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_01637_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_01637_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01637_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01637_row0_col0" class="data row0 col0" >SRP254622</td>
#       <td id="T_01637_row0_col1" class="data row0 col1" >Antennal Transcriptome of Trialeurodes vaporariorum</td>
#       <td id="T_01637_row0_col2" class="data row0 col2" >The purpose of this study is to establish a transcriptomic database of Trialeurodes vaporariorum antennaeand, and to investigate the number of genes encoding olfaction-related proteins.</td>
#       <td id="T_01637_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_01637_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_01637_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_01637_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_01637_row0_col7" class="data row0 col7" ></td>
#       <td id="T_01637_row0_col8" class="data row0 col8" ></td>
#       <td id="T_01637_row0_col9" class="data row0 col9" ></td>
#       <td id="T_01637_row0_col10" class="data row0 col10" >PRJNA616388</td>
#       <td id="T_01637_row0_col11" class="data row0 col11" ></td>
#       <td id="T_01637_row0_col12" class="data row0 col12" >http://journal05.magtech.org.cn/Jwk_ny/EN/Y2020/V28/I11/2048#</td>
#       <td id="T_01637_row0_col13" class="data row0 col13" ></td>
#       <td id="T_01637_row0_col14" class="data row0 col14" ></td>
#       <td id="T_01637_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### comments

# %%
experiment.loc[:,'comment'] = 'no PMID or DOI, paper is downloaded can be found in notebook folder'

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_e2d93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2d93_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_e2d93_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_e2d93_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_e2d93_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_e2d93_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_e2d93_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_e2d93_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_e2d93_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_e2d93_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_e2d93_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_e2d93_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_e2d93_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_e2d93_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_e2d93_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_e2d93_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_e2d93_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2d93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2d93_row0_col0" class="data row0 col0" >SRP254622</td>
#       <td id="T_e2d93_row0_col1" class="data row0 col1" >Antennal Transcriptome of Trialeurodes vaporariorum</td>
#       <td id="T_e2d93_row0_col2" class="data row0 col2" >The purpose of this study is to establish a transcriptomic database of Trialeurodes vaporariorum antennaeand, and to investigate the number of genes encoding olfaction-related proteins.</td>
#       <td id="T_e2d93_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_e2d93_row0_col4" class="data row0 col4" >total</td>
#       <td id="T_e2d93_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_e2d93_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_e2d93_row0_col7" class="data row0 col7" ></td>
#       <td id="T_e2d93_row0_col8" class="data row0 col8" ></td>
#       <td id="T_e2d93_row0_col9" class="data row0 col9" ></td>
#       <td id="T_e2d93_row0_col10" class="data row0 col10" >PRJNA616388</td>
#       <td id="T_e2d93_row0_col11" class="data row0 col11" ></td>
#       <td id="T_e2d93_row0_col12" class="data row0 col12" >http://journal05.magtech.org.cn/Jwk_ny/EN/Y2020/V28/I11/2048#</td>
#       <td id="T_e2d93_row0_col13" class="data row0 col13" ></td>
#       <td id="T_e2d93_row0_col14" class="data row0 col14" ></td>
#       <td id="T_e2d93_row0_col15" class="data row0 col15" >no PMID or DOI, paper is downloaded can be found in notebook folder</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### save complete file

# %%
experiment.to_csv(experiment_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ### QA time

# %%
library_to_add = pd.read_csv(library_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
experiment_to_add = pd.read_csv(experiment_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# %%
! python3 $path_to_v_script --bulk-exp $experiment_to_add_path --bulk-lib $library_to_add_path --rules-dir $path_to_rules --out $val_output --strict
# Out:
# Total issues: 0
# Errors: 0
# Warnings: 0
# Top codes:

# %% [markdown]
# #### check columns match

# %%
# pull from git and pull in library/experiment file
! git pull
git_library = pd.read_csv(git_library_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
git_experiment = pd.read_csv(git_experiment_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# library file
if set(library_to_add.columns) == set(git_library.columns):
    print('The columns in the library file match')
else:
    print('The columns in the library file DO NOT MATCH')

# experiment file
if set(experiment_to_add.columns) == set(git_experiment.columns):
    print('The columns in the experiment file match')
else:
    print('The columns in the experiment file DO NOT MATCH')


# maybe to make this something more like "COLUMNS GOOD - LIBRARY" and "COLUMNS BAD - EXPERIMENT"
# Out:
# Already up to date.
# The columns in the library file match
# The columns in the experiment file match

# %% [markdown]
# #### view files

# %%
library_git_plus_new = pd.concat([git_library, library_to_add], ignore_index = True, sort = False)
old_length = git_library.shape[0]
start = old_length - 2
end = old_length + 5
view_lib = library_git_plus_new.iloc[start:end]
view_lib
# Out:
#         #libraryId experimentId               platform       SRSId  \
# 65663  SRX10009699    SRP304423  Illumina NovaSeq 6000  SRS8178622
# 65664  SRX10009698    SRP304423  Illumina NovaSeq 6000  SRS8178621
# 65665   SRX8029762    SRP254622    Illumina HiSeq 4000  SRS6402118
# 65666   SRX8029761    SRP254622    Illumina HiSeq 4000  SRS6402117
#
#                anatId anatName         stageId           stageName url_GSM  \
# 65663  UBERON:0000991    gonad  UBERON:0000068        embryo stage
# 65664  UBERON:0000991    gonad  UBERON:0000068        embryo stage
# 65665  UBERON:0000972  antenna  UBERON:0000066  fully formed stage
# 65666  UBERON:0000972  antenna  UBERON:0000066  fully formed stage
#
#       infoOrgan         infoStage anatAnnotationStatus anatBiologicalStatus  \
# 65663     gonad  Whiteley stage 6                other       not documented
# 65664     gonad  Whiteley stage 6                other       not documented
# 65665   Antenna             adult        perfect match       not documented
# 65666   Antenna             adult        perfect match       not documented
#
#       stageAnnotationStatus sex strain genotype speciesId  \
# 65663                 other  NA     NA       ZZ    103695
# 65664                 other  NA     NA       ZZ    103695
# 65665         perfect match  NA                     88556
# 65666         perfect match  NA                     88556
#
#                          protocol protocolType RNASelection globin_reduction  \
# 65663  KAPA Stranded mRNA-Seq Kit  full_length        polyA
# 65664  KAPA Stranded mRNA-Seq Kit  full_length        polyA
# 65665                                                 polyA
# 65666                                                 polyA
#
#       replicate                                           lib_name  \
# 65663            Model organism or animal sample from Pogona vi...
# 65664            Model organism or animal sample from Pogona vi...
# 65665                                                          TV2
# 65666                                                          TV1
#
#          sampleName sampleAge_value        sampleAge_unit PATOid PATOname  \
# 65663  SAMN17765915               9  day-post-oviposition
# 65664  SAMN17765914               9  day-post-oviposition
# 65665  SAMN14489891
# 65666  SAMN14489890
#
#       EFOid EFOname                                            comment  \
# 65663                [Bgee curator notes: direct mails exchange wit...
# 65664                [Bgee curator notes: direct mails exchange wit...
# 65665                    no PMID or doi, see notebook folder for paper
# 65666                    no PMID or doi, see notebook folder for paper
#
#                       condition physiologicalStatus annotatorId  \
# 65663  constant temperature 36C                             ANN
# 65664  constant temperature 36C                             ANN
# 65665                                                       SAC
# 65666                                                       SAC
#
#       lastModificationDate
# 65663           2026-06-19
# 65664           2026-06-19
# 65665           2026-06-19
# 65666           2026-06-19

# %%
experiment_git_plus_new = pd.concat([git_experiment, experiment_to_add], ignore_index = True, sort = False)
experiment_git_plus_new.tail(n=3)
# Out:
#      #experimentId                                     experimentName  \
# 1260     SRP199717  Sex-biased transcriptomic study of three crypt...
# 1261     SRP304423        Embryonic Transcriptomes (Pogona vitticeps)
# 1262     SRP254622  Antennal Transcriptome of Trialeurodes vaporar...
#
#                                   experimentDescription experimentSource  \
# 1260  Combining the evolutionary study of coding seq...              SRA
# 1261  Embryonic transcriptomes of isolated gonads fr...              SRA
# 1262  The purpose of this study is to establish a tr...              SRA
#
#      experimentStatus projectTags numberOfAnnotatedLibraries  \
# 1260            total     Bgee 1K                         24
# 1261            total     Bgee 1K                        116
# 1262            total     Bgee 1K                          2
#
#                                 protocol protocolType GSE   Bioproject  \
# 1260  NEBNext Ultra RNA Library Prep Kit  full_length      PRJNA545218
# 1261          KAPA Stranded mRNA-Seq Kit  full_length      PRJNA699086
# 1262                                                       PRJNA616388
#
#           PMID                                      reference_url  \
# 1260  32466547  https://pmc.ncbi.nlm.nih.gov/articles/PMC7349267/
# 1261  35459109  https://pmc.ncbi.nlm.nih.gov/articles/PMC9034607/
# 1262            http://journal05.magtech.org.cn/Jwk_ny/EN/Y202...
#
#                              DOI                           xrefs  \
# 1260     10.3390/insects11060326
# 1261  10.1186/s12864-022-08544-2  37147622[PMID], 33857129[PMID]
# 1262
#
#                                                 comment
# 1260
# 1261  [Bgee curator notes: direct mails exchange wit...
# 1262  no PMID or DOI, paper is downloaded can be fou...

# %% [markdown]
# ### add annotations to git

# %%
! git pull
# Out:
# Already up to date.

# %%
library_git_plus_new.to_csv(git_library_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
experiment_git_plus_new.to_csv(git_experiment_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
update_format(git_library_path)
update_format(git_experiment_path)

# %%
! git status

# %%
! git add $git_experiment_path $git_library_path

# %%
! git commit -m $commit_message_exp
# Out:
# [develop a66843b] adding annotated bulk experiment SRP254622
#  2 files changed, 3 insertions(+)

# %%
! git push
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 2.06 KiB | 2.06 MiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# remote:
# remote: To create a merge request for develop, visit:
# remote:   https://gitlab.sib.swiss/Bgee/expression-annotations/-/merge_requests/new?merge_request%5Bsource_branch%5D=develop
# remote:
# To https://gitlab.sib.swiss/Bgee/expression-annotations.git/
#    723fc7f..a66843b  develop -> develop

# %% [markdown]
# ### add annotation folder and script to git

# %%
! git pull

# %% [markdown]
# 1. run first two cells (annotation summary)
# 2. export as html

# %%
! git add $path_to_output

# %%
! git commit -m $commit_message_py

# %%
! git push
