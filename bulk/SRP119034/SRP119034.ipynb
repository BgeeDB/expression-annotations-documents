# %% [markdown]
# ## SRP119034 / GSE104366
#
# **paper:** [PMID: 29958539](https://pmc.ncbi.nlm.nih.gov/articles/PMC6025724/) - Consistent inverse correlation between DNA methylation of the first intron and gene expression across tissues and species, 2018
#
# **date, curator:** 2026-06-08, Sara Carsanaro
#
# **notes**
# * per methods, all fish are adults
# * per methods used TruSeq RNA Sample Preparation Kit
# * we know testis sample are from male, not clear for muscle samples

# %% [markdown]
# ### annotation summary

# %%
anat_summary = library_to_add[['infoOrgan', 'anatId', 'anatName', 'anatAnnotationStatus']]
unique_anat = anat_summary.drop_duplicates()
display_df(unique_anat)

# %%
dev_summary = library_to_add[['infoStage', 'stageId', 'stageName', 'stageAnnotationStatus']]
unique_dev = dev_summary.drop_duplicates()
display_df(unique_dev)

# %% [markdown]
# ### set variables, import packages, define functions

# %%
experiment_id = "SRP119034"

path_to_create_exp_script = "/Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py" 
experiment_type = "bulk"

path_to_output_main = "/Users/scarsana/Desktop/git/expression-annotations/Notebooks/bulk/" 
path_to_output = "{}{}/".format(path_to_output_main, experiment_id)
library_path_from_script = "{}RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_path_from_script = "{}RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
library_to_add_path = "{}complete_RNASeqLibrary_{}.tsv".format(path_to_output, experiment_id)
experiment_to_add_path = "{}complete_RNASeqExperiment_{}.tsv".format(path_to_output, experiment_id)
script_file = "{}.ipynb".format(experiment_id)
commit_message_exp = '"adding annotated bulk experiment {}"'.format(experiment_id)
commit_message_py = '"adding annotation files for {} to notebook folder"'.format(experiment_id)


## to add to git
path_to_git_annotations = "/Users/scarsana/Desktop/git/expression-annotations/RNA_Seq/"
git_library_path = "{}RNASeqLibrary.tsv".format(path_to_git_annotations)
git_experiment_path = "{}RNASeqExperiment.tsv".format(path_to_git_annotations)

## validation
path_to_v_script = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/validate_annotations.py'
path_to_rules = '/Users/scarsana/Desktop/git/continuous_integration/validate_annotations/rules/'
val_output = "{}{}/validation.tsv".format(path_to_output_main, experiment_id)

library_cols = ['#libraryId', 'experimentId', 'platform', 'SRSId', 'anatId', 'anatName', 'stageId', 'stageName', 'url_GSM', 'infoOrgan', 'infoStage', 'anatAnnotationStatus', 'anatBiologicalStatus', 'stageAnnotationStatus', 'sex', 'strain', 'genotype', 'speciesId', 'protocol', 'protocolType', 'RNASelection', 'globin_reduction', 'replicate', 'lib_name', 'sampleName', 'sampleAge_value', 'sampleAge_unit', 'PATOid', 'PATOname','EFOid', 'EFOname','comment', 'condition', 'physiologicalStatus', 'annotatorId', 'lastModificationDate']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import os
import csv

# displays df with the scrollbar next to the DataFrame
def display_df(df):
    pd.set_option("display.max_rows", None)
    pd.set_option("display.max_columns", None)
    display(HTML("<div style='height: 300px; overflow: auto; width: fit-content'>" +
        df.style.to_html(index=False) + "</div>"))

# function that compares two columns in a dataframe and tells you which ones are not equal (case insensitive)
def compare_columns(df, col1, col2, return_col):
    compare_return = df[col1].str.lower() != df[col2].str.lower()  
    df.loc[compare_return, return_col] 
    if not any(compare_return):
        print("The two columns are equal (case insensitive)")
    else:
        print("The following rows are not equal: ")
        print(df.loc[compare_return, return_col])

# fixes formatting of file to match libreoffice settings/historic file format
def update_format(path):
    with open(path, 'r') as file:
        filedata = file.read()
    # Replace the target string
    filedata = filedata.replace("\t\"\"", "\t")
    # Write the file out again
    with open(path, 'w') as file:
        file.write(filedata)

# checks for duplicate values in a specific column and prints those values + the corresponding library id
def dup_check(df, column):
    duplicateCheck = df.duplicated(subset=[column], keep=False)
    duplicateCheck.sort_values(inplace=True)
    if duplicateCheck.unique().any() == False:
        print("no duplicate values in " + column)
    elif duplicateCheck.unique().any() == True and column != '#libraryId':
        dups = df[duplicateCheck].loc[:,['#libraryId', column]]
        df_dups = pd.DataFrame(dups)
        df_dups.sort_values(inplace=True, by=column)
        print(df_dups)
    elif duplicateCheck.unique().any() == True and column == '#libraryId':
        print(df[duplicateCheck].loc[:,['#libraryId']])

# prints all unique values in a specific column
def unique_sorted(df, column):
    unique = df[column].unique()
    unique.sort()
    print(unique)

# %% [markdown]
# ### script

# %%
! python3 $path_to_create_exp_script $experiment_id $path_to_output $experiment_type
# Out:
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:120: SyntaxWarning: invalid escape sequence '\('
#   all_protoc = [w.replace('(', '\(') for w in all_protoc]
# /Users/scarsana/Desktop/git/scRNA-Seq/scripts/Create_ExpLib_tables.py:121: SyntaxWarning: invalid escape sequence '\)'
#   all_protoc = [w.replace(')', '\)') for w in all_protoc]
# Be patient, it may take a few minutes.
# curl: (22) The requested URL returned error: 500
# >78 ERROR: >78 curl command failed ( Mon Jun  8 12:11:56 CEST 2026 ) with: 22>78
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi -d id=29958539&dbfrom=pubmed&cmd=prlinks&tool=edirect&edirect=16.2&edirect_os=Darwin&email=scarsana%40SORGE42778>78
# HTTP/1.0 500 Internal Server Error
#  WARNING:  FAILURE ( Mon Jun  8 12:11:56 CEST 2026 )
# nquire -url https://eutils.ncbi.nlm.nih.gov/entrez/eutils/ elink.fcgi -id 29958539 -dbfrom pubmed -cmd prlinks -tool edirect -edirect 16.2 -edirect_os Darwin -email scarsana@SORGE42778
# EMPTY RESULT
# SECOND ATTEMPT
# curl: (22) The requested URL returned error: 500
# >78 ERROR: >78 curl command failed ( Mon Jun  8 12:12:00 CEST 2026 ) with: 22>78
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi -d id=35741749&dbfrom=pubmed&cmd=prlinks&tool=edirect&edirect=16.2&edirect_os=Darwin&email=scarsana%40SORGE42778>78
# HTTP/1.0 500 Internal Server Error
#  WARNING:  FAILURE ( Mon Jun  8 12:11:59 CEST 2026 )
# nquire -url https://eutils.ncbi.nlm.nih.gov/entrez/eutils/ elink.fcgi -id 35741749 -dbfrom pubmed -cmd prlinks -tool edirect -edirect 16.2 -edirect_os Darwin -email scarsana@SORGE42778
# EMPTY RESULT
# SECOND ATTEMPT
# curl: (22) The requested URL returned error: 500
# >78 ERROR: >78 curl command failed ( Mon Jun  8 12:12:02 CEST 2026 ) with: 22>78
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi -d id=35741749&dbfrom=pubmed&cmd=prlinks&tool=edirect&edirect=16.2&edirect_os=Darwin&email=scarsana%40SORGE42778>78
# HTTP/1.0 500 Internal Server Error
#  WARNING:  FAILURE ( Mon Jun  8 12:12:01 CEST 2026 )
# nquire -url https://eutils.ncbi.nlm.nih.gov/entrez/eutils/ elink.fcgi -id 35741749 -dbfrom pubmed -cmd prlinks -tool edirect -edirect 16.2 -edirect_os Darwin -email scarsana@SORGE42778
# EMPTY RESULT
# LAST ATTEMPT
# 0it [00:00, ?it/s]
# 0 samples dont have attributes, try to find them somewhere else
# 0it [00:00, ?it/s]
# 0 samples dont have attributes

# %% [markdown]
# ### library annnotations

# %%
library = pd.read_csv(library_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_d419c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d419c_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_d419c_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_d419c_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_d419c_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_d419c_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_d419c_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_d419c_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_d419c_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_d419c_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_d419c_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_d419c_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_d419c_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_d419c_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_d419c_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_d419c_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_d419c_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_d419c_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_d419c_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_d419c_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_d419c_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_d419c_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_d419c_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_d419c_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_d419c_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_d419c_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_d419c_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_d419c_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_d419c_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_d419c_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_d419c_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_d419c_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_d419c_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_d419c_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_d419c_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_d419c_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_d419c_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_d419c_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_d419c_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_d419c_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_d419c_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_d419c_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_d419c_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_d419c_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_d419c_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_d419c_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_d419c_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d419c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d419c_row0_col0" class="data row0 col0" >SRX3226020</td>
#       <td id="T_d419c_row0_col1" class="data row0 col1" >SRP119034</td>
#       <td id="T_d419c_row0_col2" class="data row0 col2" >Illumina HiSeq 2000</td>
#       <td id="T_d419c_row0_col3" class="data row0 col3" >SRS2550629</td>
#       <td id="T_d419c_row0_col4" class="data row0 col4" ></td>
#       <td id="T_d419c_row0_col5" class="data row0 col5" ></td>
#       <td id="T_d419c_row0_col6" class="data row0 col6" ></td>
#       <td id="T_d419c_row0_col7" class="data row0 col7" ></td>
#       <td id="T_d419c_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2796110</td>
#       <td id="T_d419c_row0_col9" class="data row0 col9" >testis</td>
#       <td id="T_d419c_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_d419c_row0_col11" class="data row0 col11" ></td>
#       <td id="T_d419c_row0_col12" class="data row0 col12" ></td>
#       <td id="T_d419c_row0_col13" class="data row0 col13" ></td>
#       <td id="T_d419c_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_d419c_row0_col15" class="data row0 col15" ></td>
#       <td id="T_d419c_row0_col16" class="data row0 col16" ></td>
#       <td id="T_d419c_row0_col17" class="data row0 col17" >13489</td>
#       <td id="T_d419c_row0_col18" class="data row0 col18" ></td>
#       <td id="T_d419c_row0_col19" class="data row0 col19" ></td>
#       <td id="T_d419c_row0_col20" class="data row0 col20" ></td>
#       <td id="T_d419c_row0_col21" class="data row0 col21" ></td>
#       <td id="T_d419c_row0_col22" class="data row0 col22" ></td>
#       <td id="T_d419c_row0_col23" class="data row0 col23" >Testis5-RNAseq</td>
#       <td id="T_d419c_row0_col24" class="data row0 col24" >SAMN07714535,GSM2796110</td>
#       <td id="T_d419c_row0_col25" class="data row0 col25" ></td>
#       <td id="T_d419c_row0_col26" class="data row0 col26" ></td>
#       <td id="T_d419c_row0_col27" class="data row0 col27" ></td>
#       <td id="T_d419c_row0_col28" class="data row0 col28" ></td>
#       <td id="T_d419c_row0_col29" class="data row0 col29" ></td>
#       <td id="T_d419c_row0_col30" class="data row0 col30" ></td>
#       <td id="T_d419c_row0_col31" class="data row0 col31" ></td>
#       <td id="T_d419c_row0_col32" class="data row0 col32" ></td>
#       <td id="T_d419c_row0_col33" class="data row0 col33" ></td>
#       <td id="T_d419c_row0_col34" class="data row0 col34" ></td>
#       <td id="T_d419c_row0_col35" class="data row0 col35" >08/06/2026</td>
#       <td id="T_d419c_row0_col36" class="data row0 col36" >Trizol RNA extraction mRNA-Seq sample preparation kit (Illumina Inc., Cat. # RS-122-2001x2)</td>
#       <td id="T_d419c_row0_col37" class="data row0 col37" ></td>
#       <td id="T_d419c_row0_col38" class="data row0 col38" ></td>
#       <td id="T_d419c_row0_col39" class="data row0 col39" ></td>
#       <td id="T_d419c_row0_col40" class="data row0 col40" >D. labrax testis</td>
#       <td id="T_d419c_row0_col41" class="data row0 col41" ></td>
#       <td id="T_d419c_row0_col42" class="data row0 col42" ></td>
#       <td id="T_d419c_row0_col43" class="data row0 col43" ></td>
#       <td id="T_d419c_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_d419c_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_d419c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d419c_row1_col0" class="data row1 col0" >SRX3226019</td>
#       <td id="T_d419c_row1_col1" class="data row1 col1" >SRP119034</td>
#       <td id="T_d419c_row1_col2" class="data row1 col2" >Illumina HiSeq 2000</td>
#       <td id="T_d419c_row1_col3" class="data row1 col3" >SRS2550628</td>
#       <td id="T_d419c_row1_col4" class="data row1 col4" ></td>

# %% [markdown]
# #### anatomical entity
# * [uberon ols](https://www.ebi.ac.uk/ols4/ontologies/uberon)

# %%
unique_sorted(library, "infoOrgan")
# Out:
# ['muscle' 'testis']

# %%
# testis
library.loc[library["infoOrgan"] == "testis", "anatId"] = "UBERON:0000473"
library.loc[library["infoOrgan"] == "testis", "anatName"] = "testis"
# perfect match, missing child term, other
library.loc[library["infoOrgan"] == "testis", "anatAnnotationStatus"] = "perfect match"
# full sampling, partial sampling, not documented
library.loc[library["infoOrgan"] == "testis", "anatBiologicalStatus"] = "not documented"

# muscle
library.loc[library["infoOrgan"] == "muscle", "anatId"] = "UBERON:0002385"
library.loc[library["infoOrgan"] == "muscle", "anatName"] = "muscle tissue"
# perfect match, missing child term, other
library.loc[library["infoOrgan"] == "muscle", "anatAnnotationStatus"] = "perfect match"
# full sampling, partial sampling, not documented
library.loc[library["infoOrgan"] == "muscle", "anatBiologicalStatus"] = "not documented"

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_ee3c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee3c7_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_ee3c7_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_ee3c7_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_ee3c7_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_ee3c7_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_ee3c7_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_ee3c7_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_ee3c7_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_ee3c7_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_ee3c7_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_ee3c7_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_ee3c7_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_ee3c7_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_ee3c7_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_ee3c7_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_ee3c7_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_ee3c7_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_ee3c7_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_ee3c7_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_ee3c7_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_ee3c7_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_ee3c7_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_ee3c7_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_ee3c7_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_ee3c7_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_ee3c7_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_ee3c7_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_ee3c7_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_ee3c7_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_ee3c7_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_ee3c7_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_ee3c7_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_ee3c7_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_ee3c7_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_ee3c7_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_ee3c7_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_ee3c7_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_ee3c7_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_ee3c7_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_ee3c7_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_ee3c7_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_ee3c7_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_ee3c7_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_ee3c7_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_ee3c7_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_ee3c7_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee3c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee3c7_row0_col0" class="data row0 col0" >SRX3226020</td>
#       <td id="T_ee3c7_row0_col1" class="data row0 col1" >SRP119034</td>
#       <td id="T_ee3c7_row0_col2" class="data row0 col2" >Illumina HiSeq 2000</td>
#       <td id="T_ee3c7_row0_col3" class="data row0 col3" >SRS2550629</td>
#       <td id="T_ee3c7_row0_col4" class="data row0 col4" >UBERON:0000473</td>
#       <td id="T_ee3c7_row0_col5" class="data row0 col5" >testis</td>
#       <td id="T_ee3c7_row0_col6" class="data row0 col6" ></td>
#       <td id="T_ee3c7_row0_col7" class="data row0 col7" ></td>
#       <td id="T_ee3c7_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2796110</td>
#       <td id="T_ee3c7_row0_col9" class="data row0 col9" >testis</td>
#       <td id="T_ee3c7_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_ee3c7_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_ee3c7_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_ee3c7_row0_col13" class="data row0 col13" ></td>
#       <td id="T_ee3c7_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_ee3c7_row0_col15" class="data row0 col15" ></td>
#       <td id="T_ee3c7_row0_col16" class="data row0 col16" ></td>
#       <td id="T_ee3c7_row0_col17" class="data row0 col17" >13489</td>
#       <td id="T_ee3c7_row0_col18" class="data row0 col18" ></td>
#       <td id="T_ee3c7_row0_col19" class="data row0 col19" ></td>
#       <td id="T_ee3c7_row0_col20" class="data row0 col20" ></td>
#       <td id="T_ee3c7_row0_col21" class="data row0 col21" ></td>
#       <td id="T_ee3c7_row0_col22" class="data row0 col22" ></td>
#       <td id="T_ee3c7_row0_col23" class="data row0 col23" >Testis5-RNAseq</td>
#       <td id="T_ee3c7_row0_col24" class="data row0 col24" >SAMN07714535,GSM2796110</td>
#       <td id="T_ee3c7_row0_col25" class="data row0 col25" ></td>
#       <td id="T_ee3c7_row0_col26" class="data row0 col26" ></td>
#       <td id="T_ee3c7_row0_col27" class="data row0 col27" ></td>
#       <td id="T_ee3c7_row0_col28" class="data row0 col28" ></td>
#       <td id="T_ee3c7_row0_col29" class="data row0 col29" ></td>
#       <td id="T_ee3c7_row0_col30" class="data row0 col30" ></td>
#       <td id="T_ee3c7_row0_col31" class="data row0 col31" ></td>
#       <td id="T_ee3c7_row0_col32" class="data row0 col32" ></td>
#       <td id="T_ee3c7_row0_col33" class="data row0 col33" ></td>
#       <td id="T_ee3c7_row0_col34" class="data row0 col34" ></td>
#       <td id="T_ee3c7_row0_col35" class="data row0 col35" >08/06/2026</td>
#       <td id="T_ee3c7_row0_col36" class="data row0 col36" >Trizol RNA extraction mRNA-Seq sample preparation kit (Illumina Inc., Cat. # RS-122-2001x2)</td>
#       <td id="T_ee3c7_row0_col37" class="data row0 col37" ></td>
#       <td id="T_ee3c7_row0_col38" class="data row0 col38" ></td>
#       <td id="T_ee3c7_row0_col39" class="data row0 col39" ></td>
#       <td id="T_ee3c7_row0_col40" class="data row0 col40" >D. labrax testis</td>
#       <td id="T_ee3c7_row0_col41" class="data row0 col41" ></td>
#       <td id="T_ee3c7_row0_col42" class="data row0 col42" ></td>
#       <td id="T_ee3c7_row0_col43" class="data row0 col43" ></td>
#       <td id="T_ee3c7_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_ee3c7_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_ee3c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ee3c7_row1_col0" class="data row1 col0" >SRX3226019</td>
#       <td id="T_ee3c7_row1_col1" class="data row1 col1" >SRP119034</td>
#       <td id="T_ee3c7_row1_col2" class="data row1 col2" >Illumina HiSeq 2000</td>
#       <td id="T_ee3c7_row1_col3" class="data row1 col3" >SRS2550628</td>
#       <td id="T_e

# %% [markdown]
# #### stage
# - [species specific developmental ontologies](https://github.com/obophenotype/developmental-stage-ontologies/tree/master/src/ontology/components)

# %%
unique_sorted(library, "infoStage")
# Out:
# ['adult']

# %%
# all
library.loc[:,'stageId'] = 'UBERON:0000113'
library.loc[:,'stageName'] = 'post-juvenile adult stage'
# perfect match, missing child term, other
library.loc[:,'stageAnnotationStatus'] = 'perfect match'


# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_68028">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68028_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_68028_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_68028_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_68028_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_68028_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_68028_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_68028_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_68028_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_68028_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_68028_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_68028_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_68028_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_68028_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_68028_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_68028_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_68028_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_68028_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_68028_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_68028_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_68028_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_68028_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_68028_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_68028_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_68028_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_68028_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_68028_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_68028_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_68028_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_68028_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_68028_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_68028_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_68028_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_68028_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_68028_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_68028_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_68028_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_68028_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_68028_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_68028_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_68028_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_68028_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_68028_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_68028_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_68028_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_68028_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_68028_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68028_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68028_row0_col0" class="data row0 col0" >SRX3226020</td>
#       <td id="T_68028_row0_col1" class="data row0 col1" >SRP119034</td>
#       <td id="T_68028_row0_col2" class="data row0 col2" >Illumina HiSeq 2000</td>
#       <td id="T_68028_row0_col3" class="data row0 col3" >SRS2550629</td>
#       <td id="T_68028_row0_col4" class="data row0 col4" >UBERON:0000473</td>
#       <td id="T_68028_row0_col5" class="data row0 col5" >testis</td>
#       <td id="T_68028_row0_col6" class="data row0 col6" >UBERON:0000113</td>
#       <td id="T_68028_row0_col7" class="data row0 col7" >post-juvenile adult stage</td>
#       <td id="T_68028_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2796110</td>
#       <td id="T_68028_row0_col9" class="data row0 col9" >testis</td>
#       <td id="T_68028_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_68028_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_68028_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_68028_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_68028_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_68028_row0_col15" class="data row0 col15" ></td>
#       <td id="T_68028_row0_col16" class="data row0 col16" ></td>
#       <td id="T_68028_row0_col17" class="data row0 col17" >13489</td>
#       <td id="T_68028_row0_col18" class="data row0 col18" ></td>
#       <td id="T_68028_row0_col19" class="data row0 col19" ></td>
#       <td id="T_68028_row0_col20" class="data row0 col20" ></td>
#       <td id="T_68028_row0_col21" class="data row0 col21" ></td>
#       <td id="T_68028_row0_col22" class="data row0 col22" ></td>
#       <td id="T_68028_row0_col23" class="data row0 col23" >Testis5-RNAseq</td>
#       <td id="T_68028_row0_col24" class="data row0 col24" >SAMN07714535,GSM2796110</td>
#       <td id="T_68028_row0_col25" class="data row0 col25" ></td>
#       <td id="T_68028_row0_col26" class="data row0 col26" ></td>
#       <td id="T_68028_row0_col27" class="data row0 col27" ></td>
#       <td id="T_68028_row0_col28" class="data row0 col28" ></td>
#       <td id="T_68028_row0_col29" class="data row0 col29" ></td>
#       <td id="T_68028_row0_col30" class="data row0 col30" ></td>
#       <td id="T_68028_row0_col31" class="data row0 col31" ></td>
#       <td id="T_68028_row0_col32" class="data row0 col32" ></td>
#       <td id="T_68028_row0_col33" class="data row0 col33" ></td>
#       <td id="T_68028_row0_col34" class="data row0 col34" ></td>
#       <td id="T_68028_row0_col35" class="data row0 col35" >08/06/2026</td>
#       <td id="T_68028_row0_col36" class="data row0 col36" >Trizol RNA extraction mRNA-Seq sample preparation kit (Illumina Inc., Cat. # RS-122-2001x2)</td>
#       <td id="T_68028_row0_col37" class="data row0 col37" ></td>
#       <td id="T_68028_row0_col38" class="data row0 col38" ></td>
#       <td id="T_68028_row0_col39" class="data row0 col39" ></td>
#       <td id="T_68028_row0_col40" class="data row0 col40" >D. labrax testis</td>
#       <td id="T_68028_row0_col41" class="data row0 col41" ></td>
#       <td id="T_68028_row0_col42" class="data row0 col42" ></td>
#       <td id="T_68028_row0_col43" class="data row0 col43" ></td>
#       <td id="T_68028_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_68028_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_68028_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68028_row1_col0" class="data row1 col0" >SRX3226019</td>
#       <td id="T_68028_row1_col1" class="data row1 col1" >SRP119034</td>
#       <td id="T_68028_row1_col2" class="data row1 col2" >Illumina HiSeq 2000</td>
#       <td id="T_68028_row1_col3" class

# %% [markdown]
# #### sex, strain, genotype, speciesId
# - uniprot [strain list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/strains)
# - uniprot [species list](https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/docs/speclist)
# - bgee [strain mapping](https://gitlab.sib.swiss/Bgee/expression-annotations/-/tree/develop/Strains?ref_type=heads)

# %%
#library.loc[:,'sex'] = ''
#library.loc[library["sex"] == "male", "sex"] = "M"
#library.loc[library["sex"] == "female", "sex"] = "F"

#library.loc[:,'strain'] = ''

#library.loc[:,'genotype'] = ''

#library.loc[:,'speciesId'] = ''

# view
display_df(library)

# %% [markdown]
# #### protocol
# see [bulk kits](https://gitlab.sib.swiss/Bgee/scRNA-Seq/-/blob/main/scripts/bulk_kits.csv) for some common protocols

# %%
# making these variables because we use them again in the experiment file
my_protocol = 'TruSeq RNA Sample Preparation Kit'
# full_length or 3'
my_protocolType = 'full_length'

library.loc[:,'protocol'] = my_protocol
library.loc[:,'protocolType'] = my_protocolType
# polyA, ribo-minus, miRNA, lncRNA, circRNA
library.loc[:,'RNASelection'] = 'polyA'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_83e47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83e47_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_83e47_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_83e47_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_83e47_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_83e47_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_83e47_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_83e47_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_83e47_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_83e47_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_83e47_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_83e47_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_83e47_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_83e47_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_83e47_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_83e47_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_83e47_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_83e47_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_83e47_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_83e47_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_83e47_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_83e47_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_83e47_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_83e47_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_83e47_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_83e47_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_83e47_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_83e47_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_83e47_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_83e47_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_83e47_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_83e47_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_83e47_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_83e47_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_83e47_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_83e47_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_83e47_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_83e47_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_83e47_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_83e47_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_83e47_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_83e47_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_83e47_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_83e47_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_83e47_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_83e47_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_83e47_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83e47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83e47_row0_col0" class="data row0 col0" >SRX3226020</td>
#       <td id="T_83e47_row0_col1" class="data row0 col1" >SRP119034</td>
#       <td id="T_83e47_row0_col2" class="data row0 col2" >Illumina HiSeq 2000</td>
#       <td id="T_83e47_row0_col3" class="data row0 col3" >SRS2550629</td>
#       <td id="T_83e47_row0_col4" class="data row0 col4" >UBERON:0000473</td>
#       <td id="T_83e47_row0_col5" class="data row0 col5" >testis</td>
#       <td id="T_83e47_row0_col6" class="data row0 col6" >UBERON:0000113</td>
#       <td id="T_83e47_row0_col7" class="data row0 col7" >post-juvenile adult stage</td>
#       <td id="T_83e47_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2796110</td>
#       <td id="T_83e47_row0_col9" class="data row0 col9" >testis</td>
#       <td id="T_83e47_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_83e47_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_83e47_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_83e47_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_83e47_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_83e47_row0_col15" class="data row0 col15" ></td>
#       <td id="T_83e47_row0_col16" class="data row0 col16" ></td>
#       <td id="T_83e47_row0_col17" class="data row0 col17" >13489</td>
#       <td id="T_83e47_row0_col18" class="data row0 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_83e47_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_83e47_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_83e47_row0_col21" class="data row0 col21" ></td>
#       <td id="T_83e47_row0_col22" class="data row0 col22" ></td>
#       <td id="T_83e47_row0_col23" class="data row0 col23" >Testis5-RNAseq</td>
#       <td id="T_83e47_row0_col24" class="data row0 col24" >SAMN07714535,GSM2796110</td>
#       <td id="T_83e47_row0_col25" class="data row0 col25" ></td>
#       <td id="T_83e47_row0_col26" class="data row0 col26" ></td>
#       <td id="T_83e47_row0_col27" class="data row0 col27" ></td>
#       <td id="T_83e47_row0_col28" class="data row0 col28" ></td>
#       <td id="T_83e47_row0_col29" class="data row0 col29" ></td>
#       <td id="T_83e47_row0_col30" class="data row0 col30" ></td>
#       <td id="T_83e47_row0_col31" class="data row0 col31" ></td>
#       <td id="T_83e47_row0_col32" class="data row0 col32" ></td>
#       <td id="T_83e47_row0_col33" class="data row0 col33" ></td>
#       <td id="T_83e47_row0_col34" class="data row0 col34" ></td>
#       <td id="T_83e47_row0_col35" class="data row0 col35" >08/06/2026</td>
#       <td id="T_83e47_row0_col36" class="data row0 col36" >Trizol RNA extraction mRNA-Seq sample preparation kit (Illumina Inc., Cat. # RS-122-2001x2)</td>
#       <td id="T_83e47_row0_col37" class="data row0 col37" ></td>
#       <td id="T_83e47_row0_col38" class="data row0 col38" ></td>
#       <td id="T_83e47_row0_col39" class="data row0 col39" ></td>
#       <td id="T_83e47_row0_col40" class="data row0 col40" >D. labrax testis</td>
#       <td id="T_83e47_row0_col41" class="data row0 col41" ></td>
#       <td id="T_83e47_row0_col42" class="data row0 col42" ></td>
#       <td id="T_83e47_row0_col43" class="data row0 col43" ></td>
#       <td id="T_83e47_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_83e47_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_83e47_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83e47_row1_col0" class="data row1 col0" >SRX3226019</td>
#       <td id="T_83e47_row1_col1" class="data row1 col1" >SRP119034</td>
#       <td id="T_83e47_row1_col2" class="data row1 col2" >Illumina HiSeq

# %% [markdown]
# #### globin, replicates

# %%
# check for duplicate SRSId values
dup_check(library, "SRSId")
# Out:
# no duplicate values in SRSId

# %%
#library.loc[:,'globin_reduction'] = 'Y'

# replicates
#library.loc[library["#libraryId"] == "old", "replicate"] = "1"
#library.loc[library["#libraryId"].isin(["one", "two"]), "replicate"] = "1"

# view
display_df(library)

# %% [markdown]
# #### sample age, pato, physiological status
# * [PATO](https://www.ebi.ac.uk/ols4/ontologies/pato)
# * [EFO](https://www.ebi.ac.uk/ols4/ontologies/efo)

# %%
#library.loc[:,'sampleAge_value'] = ''
#library.loc[:,'sampleAge_unit'] = ''

# ex. castrated male
#library.loc[:,'PATOid'] = ''
#library.loc[:,'PATOname'] = ''

# ex. castrated, pregnant, pre-smoltification, post-smoltification, laying eggs
#library.loc[:,'physiologicalStatus'] = ''

# ex. left, right
#library.loc[:,'EFOid'] = ''
#library.loc[:,'EFOname'] = ''

# view
display_df(library)

# %% [markdown]
# #### condition

# %%
# ex. control, diet, light, reproductive capacity, time post mortem, time post feeding, 
# exercise details, menstruation, personality, litter size 
#library.loc[library["condition"] == "old", "condition"] = "new"

# view
display_df(library)

# %% [markdown]
# #### annotator id, last modification date

# %%
library.loc[:,'annotatorId'] = 'SAC'
library.loc[:,'lastModificationDate'] = '2026-06-08'

# view
display_df(library)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_236f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_236f6_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_236f6_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_236f6_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_236f6_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_236f6_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_236f6_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_236f6_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_236f6_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_236f6_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_236f6_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_236f6_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_236f6_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_236f6_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_236f6_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_236f6_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_236f6_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_236f6_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_236f6_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_236f6_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_236f6_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_236f6_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_236f6_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_236f6_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_236f6_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_236f6_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_236f6_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_236f6_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_236f6_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_236f6_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_236f6_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_236f6_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_236f6_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_236f6_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_236f6_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_236f6_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_236f6_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#       <th id="T_236f6_level0_col36" class="col_heading level0 col36" >library_contruction_protocol</th>
#       <th id="T_236f6_level0_col37" class="col_heading level0 col37" >source_qc</th>
#       <th id="T_236f6_level0_col38" class="col_heading level0 col38" >lib_name_2</th>
#       <th id="T_236f6_level0_col39" class="col_heading level0 col39" >lib_name_3</th>
#       <th id="T_236f6_level0_col40" class="col_heading level0 col40" >source_name</th>
#       <th id="T_236f6_level0_col41" class="col_heading level0 col41" >individual</th>
#       <th id="T_236f6_level0_col42" class="col_heading level0 col42" >infoStage_2</th>
#       <th id="T_236f6_level0_col43" class="col_heading level0 col43" >infoStage_3</th>
#       <th id="T_236f6_level0_col44" class="col_heading level0 col44" >Library_Source</th>
#       <th id="T_236f6_level0_col45" class="col_heading level0 col45" >Library_Selection</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_236f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_236f6_row0_col0" class="data row0 col0" >SRX3226020</td>
#       <td id="T_236f6_row0_col1" class="data row0 col1" >SRP119034</td>
#       <td id="T_236f6_row0_col2" class="data row0 col2" >Illumina HiSeq 2000</td>
#       <td id="T_236f6_row0_col3" class="data row0 col3" >SRS2550629</td>
#       <td id="T_236f6_row0_col4" class="data row0 col4" >UBERON:0000473</td>
#       <td id="T_236f6_row0_col5" class="data row0 col5" >testis</td>
#       <td id="T_236f6_row0_col6" class="data row0 col6" >UBERON:0000113</td>
#       <td id="T_236f6_row0_col7" class="data row0 col7" >post-juvenile adult stage</td>
#       <td id="T_236f6_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2796110</td>
#       <td id="T_236f6_row0_col9" class="data row0 col9" >testis</td>
#       <td id="T_236f6_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_236f6_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_236f6_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_236f6_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_236f6_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_236f6_row0_col15" class="data row0 col15" ></td>
#       <td id="T_236f6_row0_col16" class="data row0 col16" ></td>
#       <td id="T_236f6_row0_col17" class="data row0 col17" >13489</td>
#       <td id="T_236f6_row0_col18" class="data row0 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_236f6_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_236f6_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_236f6_row0_col21" class="data row0 col21" ></td>
#       <td id="T_236f6_row0_col22" class="data row0 col22" ></td>
#       <td id="T_236f6_row0_col23" class="data row0 col23" >Testis5-RNAseq</td>
#       <td id="T_236f6_row0_col24" class="data row0 col24" >SAMN07714535,GSM2796110</td>
#       <td id="T_236f6_row0_col25" class="data row0 col25" ></td>
#       <td id="T_236f6_row0_col26" class="data row0 col26" ></td>
#       <td id="T_236f6_row0_col27" class="data row0 col27" ></td>
#       <td id="T_236f6_row0_col28" class="data row0 col28" ></td>
#       <td id="T_236f6_row0_col29" class="data row0 col29" ></td>
#       <td id="T_236f6_row0_col30" class="data row0 col30" ></td>
#       <td id="T_236f6_row0_col31" class="data row0 col31" ></td>
#       <td id="T_236f6_row0_col32" class="data row0 col32" ></td>
#       <td id="T_236f6_row0_col33" class="data row0 col33" ></td>
#       <td id="T_236f6_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_236f6_row0_col35" class="data row0 col35" >2026-06-08</td>
#       <td id="T_236f6_row0_col36" class="data row0 col36" >Trizol RNA extraction mRNA-Seq sample preparation kit (Illumina Inc., Cat. # RS-122-2001x2)</td>
#       <td id="T_236f6_row0_col37" class="data row0 col37" ></td>
#       <td id="T_236f6_row0_col38" class="data row0 col38" ></td>
#       <td id="T_236f6_row0_col39" class="data row0 col39" ></td>
#       <td id="T_236f6_row0_col40" class="data row0 col40" >D. labrax testis</td>
#       <td id="T_236f6_row0_col41" class="data row0 col41" ></td>
#       <td id="T_236f6_row0_col42" class="data row0 col42" ></td>
#       <td id="T_236f6_row0_col43" class="data row0 col43" ></td>
#       <td id="T_236f6_row0_col44" class="data row0 col44" >TRANSCRIPTOMIC</td>
#       <td id="T_236f6_row0_col45" class="data row0 col45" >cDNA</td>
#     </tr>
#     <tr>
#       <th id="T_236f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_236f6_row1_col0" class="data row1 col0" >SRX3226019</td>
#       <td id="T_236f6_row1_col1" class="data row1 col1" >SRP119034</td>
#       <td id="T_236f6_row1_col2" class="data row1 col2" >Illumina Hi

# %% [markdown]
# #### comments

# %%
library.loc[:,'comment'] = 'PMID: 29958539'

# %% [markdown]
# #### save complete file with correct columns

# %%
library_file_complete = library[library_cols]
library_file_complete.to_csv(library_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# view
display_df(library_file_complete)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_e55d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e55d2_level0_col0" class="col_heading level0 col0" >#libraryId</th>
#       <th id="T_e55d2_level0_col1" class="col_heading level0 col1" >experimentId</th>
#       <th id="T_e55d2_level0_col2" class="col_heading level0 col2" >platform</th>
#       <th id="T_e55d2_level0_col3" class="col_heading level0 col3" >SRSId</th>
#       <th id="T_e55d2_level0_col4" class="col_heading level0 col4" >anatId</th>
#       <th id="T_e55d2_level0_col5" class="col_heading level0 col5" >anatName</th>
#       <th id="T_e55d2_level0_col6" class="col_heading level0 col6" >stageId</th>
#       <th id="T_e55d2_level0_col7" class="col_heading level0 col7" >stageName</th>
#       <th id="T_e55d2_level0_col8" class="col_heading level0 col8" >url_GSM</th>
#       <th id="T_e55d2_level0_col9" class="col_heading level0 col9" >infoOrgan</th>
#       <th id="T_e55d2_level0_col10" class="col_heading level0 col10" >infoStage</th>
#       <th id="T_e55d2_level0_col11" class="col_heading level0 col11" >anatAnnotationStatus</th>
#       <th id="T_e55d2_level0_col12" class="col_heading level0 col12" >anatBiologicalStatus</th>
#       <th id="T_e55d2_level0_col13" class="col_heading level0 col13" >stageAnnotationStatus</th>
#       <th id="T_e55d2_level0_col14" class="col_heading level0 col14" >sex</th>
#       <th id="T_e55d2_level0_col15" class="col_heading level0 col15" >strain</th>
#       <th id="T_e55d2_level0_col16" class="col_heading level0 col16" >genotype</th>
#       <th id="T_e55d2_level0_col17" class="col_heading level0 col17" >speciesId</th>
#       <th id="T_e55d2_level0_col18" class="col_heading level0 col18" >protocol</th>
#       <th id="T_e55d2_level0_col19" class="col_heading level0 col19" >protocolType</th>
#       <th id="T_e55d2_level0_col20" class="col_heading level0 col20" >RNASelection</th>
#       <th id="T_e55d2_level0_col21" class="col_heading level0 col21" >globin_reduction</th>
#       <th id="T_e55d2_level0_col22" class="col_heading level0 col22" >replicate</th>
#       <th id="T_e55d2_level0_col23" class="col_heading level0 col23" >lib_name</th>
#       <th id="T_e55d2_level0_col24" class="col_heading level0 col24" >sampleName</th>
#       <th id="T_e55d2_level0_col25" class="col_heading level0 col25" >sampleAge_value</th>
#       <th id="T_e55d2_level0_col26" class="col_heading level0 col26" >sampleAge_unit</th>
#       <th id="T_e55d2_level0_col27" class="col_heading level0 col27" >PATOid</th>
#       <th id="T_e55d2_level0_col28" class="col_heading level0 col28" >PATOname</th>
#       <th id="T_e55d2_level0_col29" class="col_heading level0 col29" >EFOid</th>
#       <th id="T_e55d2_level0_col30" class="col_heading level0 col30" >EFOname</th>
#       <th id="T_e55d2_level0_col31" class="col_heading level0 col31" >comment</th>
#       <th id="T_e55d2_level0_col32" class="col_heading level0 col32" >condition</th>
#       <th id="T_e55d2_level0_col33" class="col_heading level0 col33" >physiologicalStatus</th>
#       <th id="T_e55d2_level0_col34" class="col_heading level0 col34" >annotatorId</th>
#       <th id="T_e55d2_level0_col35" class="col_heading level0 col35" >lastModificationDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e55d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e55d2_row0_col0" class="data row0 col0" >SRX3226020</td>
#       <td id="T_e55d2_row0_col1" class="data row0 col1" >SRP119034</td>
#       <td id="T_e55d2_row0_col2" class="data row0 col2" >Illumina HiSeq 2000</td>
#       <td id="T_e55d2_row0_col3" class="data row0 col3" >SRS2550629</td>
#       <td id="T_e55d2_row0_col4" class="data row0 col4" >UBERON:0000473</td>
#       <td id="T_e55d2_row0_col5" class="data row0 col5" >testis</td>
#       <td id="T_e55d2_row0_col6" class="data row0 col6" >UBERON:0000113</td>
#       <td id="T_e55d2_row0_col7" class="data row0 col7" >post-juvenile adult stage</td>
#       <td id="T_e55d2_row0_col8" class="data row0 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2796110</td>
#       <td id="T_e55d2_row0_col9" class="data row0 col9" >testis</td>
#       <td id="T_e55d2_row0_col10" class="data row0 col10" >adult</td>
#       <td id="T_e55d2_row0_col11" class="data row0 col11" >perfect match</td>
#       <td id="T_e55d2_row0_col12" class="data row0 col12" >not documented</td>
#       <td id="T_e55d2_row0_col13" class="data row0 col13" >perfect match</td>
#       <td id="T_e55d2_row0_col14" class="data row0 col14" >M</td>
#       <td id="T_e55d2_row0_col15" class="data row0 col15" ></td>
#       <td id="T_e55d2_row0_col16" class="data row0 col16" ></td>
#       <td id="T_e55d2_row0_col17" class="data row0 col17" >13489</td>
#       <td id="T_e55d2_row0_col18" class="data row0 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_e55d2_row0_col19" class="data row0 col19" >full_length</td>
#       <td id="T_e55d2_row0_col20" class="data row0 col20" >polyA</td>
#       <td id="T_e55d2_row0_col21" class="data row0 col21" ></td>
#       <td id="T_e55d2_row0_col22" class="data row0 col22" ></td>
#       <td id="T_e55d2_row0_col23" class="data row0 col23" >Testis5-RNAseq</td>
#       <td id="T_e55d2_row0_col24" class="data row0 col24" >SAMN07714535,GSM2796110</td>
#       <td id="T_e55d2_row0_col25" class="data row0 col25" ></td>
#       <td id="T_e55d2_row0_col26" class="data row0 col26" ></td>
#       <td id="T_e55d2_row0_col27" class="data row0 col27" ></td>
#       <td id="T_e55d2_row0_col28" class="data row0 col28" ></td>
#       <td id="T_e55d2_row0_col29" class="data row0 col29" ></td>
#       <td id="T_e55d2_row0_col30" class="data row0 col30" ></td>
#       <td id="T_e55d2_row0_col31" class="data row0 col31" >PMID: 29958539</td>
#       <td id="T_e55d2_row0_col32" class="data row0 col32" ></td>
#       <td id="T_e55d2_row0_col33" class="data row0 col33" ></td>
#       <td id="T_e55d2_row0_col34" class="data row0 col34" >SAC</td>
#       <td id="T_e55d2_row0_col35" class="data row0 col35" >2026-06-08</td>
#     </tr>
#     <tr>
#       <th id="T_e55d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e55d2_row1_col0" class="data row1 col0" >SRX3226019</td>
#       <td id="T_e55d2_row1_col1" class="data row1 col1" >SRP119034</td>
#       <td id="T_e55d2_row1_col2" class="data row1 col2" >Illumina HiSeq 2000</td>
#       <td id="T_e55d2_row1_col3" class="data row1 col3" >SRS2550628</td>
#       <td id="T_e55d2_row1_col4" class="data row1 col4" >UBERON:0000473</td>
#       <td id="T_e55d2_row1_col5" class="data row1 col5" >testis</td>
#       <td id="T_e55d2_row1_col6" class="data row1 col6" >UBERON:0000113</td>
#       <td id="T_e55d2_row1_col7" class="data row1 col7" >post-juvenile adult stage</td>
#       <td id="T_e55d2_row1_col8" class="data row1 col8" >http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2796109</td>
#       <td id="T_e55d2_row1_col9" class="data row1 col9" >testis</td>
#       <td id="T_e55d2_row1_col10" class="data row1 col10" >adult</td>
#       <td id="T_e55d2_row1_col11" class="data row1 col11" >perfect match</td>
#       <td id="T_e55d2_row1_col12" class="data row1 col12" >not documented</td>
#       <td id="T_e55d2_row1_col13" class="data row1 col13" >perfect match</td>
#       <td id="T_e55d2_row1_col14" class="data row1 col14" >M</td>
#       <td id="T_e55d2_row1_col15" class="data row1 col15" ></td>
#       <td id="T_e55d2_row1_col16" class="data row1 col16" ></td>
#       <td id="T_e55d2_row1_col17" class="data row1 col17" >13489</td>
#       <td id="T_e55d2_row1_col18" class="data row1 col18" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_e55d2_row1_col19" class="data row1 col19" >full_length</td>
#       <td id="T_e55d2_row1_col20" class="data row1 col20" >polyA</td>
#       <td id="T_e55d2_row1_col21" class="data row1 col21" ></td>
#       <td id="T_e55d2_row1_col22" class="data row1 col22" ></td>
#       <td id="T_e55d2_row1_col23" class="data row1 col23" >Testis4-RNAseq</td>
#       <td id="T_e55d2_row1_col24" clas

# %% [markdown]
# ### experiment annotations

# %%
experiment = pd.read_csv(experiment_path_from_script, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_4b197">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b197_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_4b197_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_4b197_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_4b197_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_4b197_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_4b197_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_4b197_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_4b197_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_4b197_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_4b197_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_4b197_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_4b197_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_4b197_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_4b197_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_4b197_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_4b197_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b197_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b197_row0_col0" class="data row0 col0" >SRP119034</td>
#       <td id="T_4b197_row0_col1" class="data row0 col1" >Consistent inverse correlation between DNA methylation of the first intron and gene expression across tissues and species</td>
#       <td id="T_4b197_row0_col2" class="data row0 col2" >Background: DNA methylation is one of the main epigenetic mechanisms for the regulation of gene expression in eukaryotes. In the standard model, methylation in gene promoters has received the most attention since it is generally associated with transcriptional silencing. Nevertheless, recent studies in human tissues reveal that methylation of the region downstream of the transcription start site is highly informative of gene expression. Also, in some cell types and specific genes it has been found that methylation of the first intron, a gene feature typically rich in enhancers, is linked with gene expression. However, a genome-wide, tissue-independent, systematic comparative analysis of the relationship between DNA methylation in the first intron and gene expression across vertebrates has not been explored yet. Results: The most important findings of this study are: (1) using different tissues from a modern fish, we show a clear genome-wide, tissue-independent quasi-linear inverse relationship between DNA methylation of the first intron and gene expression. (2) This relationship is conserved across vertebrates, since it is also present in the genomes of a model pufferfish, a model frog and different human tissues. Among the gene features, tissues and species interrogated, the first intron’s negative correlation with the gene expression was most consistent. (3) We identified more tissue-specific differentially methylated regions (tDMRs) in the first intron than in any other gene feature. These tDMRs have positive or negative correlation with gene expression, indicative of distinct mechanisms of tissue-specific regulation. (4) Lastly, we identified CpGs in transcription factor binding motifs, enriched in the first intron, the methylation of which tended to increase with the distance from the first exon–first intron boundary, with a concomitant decrease in gene expression. Conclusions: Our integrative analysis clearly reveals the important and conserved role of the methylation level of the first intron and its inverse association with gene expression regardless of tissue and species. These findings not only contribute to our basic understanding of the epigenetic regulation of gene expression but also identify the first intron as an informative gene feature regarding the relationship between DNA methylation and gene expression where future studies should be focused. Overall design: Genome wide DNA methylation and gene expression in testis and muscle of wild European sea bass (Dicentrarchus labrax)</td>
#       <td id="T_4b197_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_4b197_row0_col4" class="data row0 col4" ></td>
#       <td id="T_4b197_row0_col5" class="data row0 col5" ></td>
#       <td id="T_4b197_row0_col6" class="data row0 col6" ></td>
#       <td id="T_4b197_row0_col7" class="data row0 col7" ></td>
#       <td id="T_4b197_row0_col8" class="data row0 col8" ></td>
#       <td id="T_4b197_row0_col9" class="data row0 col9" >GSE104366</td>
#       <td id="T_4b197_row0_col10" class="data row0 col10" >PRJNA412454</td>
#       <td id="T_4b197_row0_col11" class="data row0 col11" >35741749, 29958539</td>
#       <td id="T_4b197_row0_col12" class="data row0 col12" ></td>
#       <td id="T_4b197_row0_col13" class="data row0 col13" >10.1186/s13072-018-0205-1,10.3390/genes13060987</td>
#       <td id="T_4b197_row0_col14" class="data row0 col14" ></td>
#       <td id="T_4b197_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### experiment and protocol details

# %%
# this will give you the number of rows in the complete library file 
# this should be the number of annotated libraries
ann_lib = len(library_file_complete.index)
len(library_file_complete.index)
# Out:
# 10

# %%
# partial or total
experiment.loc[:,'experimentStatus'] = 'partial'
# Bgee 1K
experiment.loc[:,'projectTags'] = 'Bgee 1K' 
# see above cell, also can add as free text
experiment.loc[:,'numberOfAnnotatedLibraries'] = ann_lib

# these variables should already exist from above but if not can just add as free text
experiment.loc[:,'protocol'] = my_protocol
experiment.loc[:,'protocolType'] = my_protocolType

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_35784">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35784_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_35784_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_35784_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_35784_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_35784_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_35784_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_35784_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_35784_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_35784_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_35784_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_35784_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_35784_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_35784_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_35784_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_35784_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_35784_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35784_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35784_row0_col0" class="data row0 col0" >SRP119034</td>
#       <td id="T_35784_row0_col1" class="data row0 col1" >Consistent inverse correlation between DNA methylation of the first intron and gene expression across tissues and species</td>
#       <td id="T_35784_row0_col2" class="data row0 col2" >Background: DNA methylation is one of the main epigenetic mechanisms for the regulation of gene expression in eukaryotes. In the standard model, methylation in gene promoters has received the most attention since it is generally associated with transcriptional silencing. Nevertheless, recent studies in human tissues reveal that methylation of the region downstream of the transcription start site is highly informative of gene expression. Also, in some cell types and specific genes it has been found that methylation of the first intron, a gene feature typically rich in enhancers, is linked with gene expression. However, a genome-wide, tissue-independent, systematic comparative analysis of the relationship between DNA methylation in the first intron and gene expression across vertebrates has not been explored yet. Results: The most important findings of this study are: (1) using different tissues from a modern fish, we show a clear genome-wide, tissue-independent quasi-linear inverse relationship between DNA methylation of the first intron and gene expression. (2) This relationship is conserved across vertebrates, since it is also present in the genomes of a model pufferfish, a model frog and different human tissues. Among the gene features, tissues and species interrogated, the first intron’s negative correlation with the gene expression was most consistent. (3) We identified more tissue-specific differentially methylated regions (tDMRs) in the first intron than in any other gene feature. These tDMRs have positive or negative correlation with gene expression, indicative of distinct mechanisms of tissue-specific regulation. (4) Lastly, we identified CpGs in transcription factor binding motifs, enriched in the first intron, the methylation of which tended to increase with the distance from the first exon–first intron boundary, with a concomitant decrease in gene expression. Conclusions: Our integrative analysis clearly reveals the important and conserved role of the methylation level of the first intron and its inverse association with gene expression regardless of tissue and species. These findings not only contribute to our basic understanding of the epigenetic regulation of gene expression but also identify the first intron as an informative gene feature regarding the relationship between DNA methylation and gene expression where future studies should be focused. Overall design: Genome wide DNA methylation and gene expression in testis and muscle of wild European sea bass (Dicentrarchus labrax)</td>
#       <td id="T_35784_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_35784_row0_col4" class="data row0 col4" >partial</td>
#       <td id="T_35784_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_35784_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_35784_row0_col7" class="data row0 col7" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_35784_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_35784_row0_col9" class="data row0 col9" >GSE104366</td>
#       <td id="T_35784_row0_col10" class="data row0 col10" >PRJNA412454</td>
#       <td id="T_35784_row0_col11" class="data row0 col11" >35741749, 29958539</td>
#       <td id="T_35784_row0_col12" class="data row0 col12" ></td>
#       <td id="T_35784_row0_col13" class="data row0 col13" >10.1186/s13072-018-0205-1,10.3390/genes13060987</td>
#       <td id="T_35784_row0_col14" class="data row0 col14" ></td>
#       <td id="T_35784_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### paper and xrefs

# %%
#experiment.loc[:,'GSE'] = ''
#experiment.loc[:,'Bioproject'] = '' 
experiment.loc[:,'PMID'] = '29958539'
experiment.loc[:,'reference_url'] = 'https://pmc.ncbi.nlm.nih.gov/articles/PMC6025724/'
experiment.loc[:,'DOI'] = '10.1186/s13072-018-0205-1'
experiment.loc[:,'xrefs'] = '35741749[PMID]'

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_da924">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da924_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_da924_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_da924_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_da924_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_da924_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_da924_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_da924_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_da924_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_da924_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_da924_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_da924_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_da924_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_da924_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_da924_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_da924_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_da924_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da924_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da924_row0_col0" class="data row0 col0" >SRP119034</td>
#       <td id="T_da924_row0_col1" class="data row0 col1" >Consistent inverse correlation between DNA methylation of the first intron and gene expression across tissues and species</td>
#       <td id="T_da924_row0_col2" class="data row0 col2" >Background: DNA methylation is one of the main epigenetic mechanisms for the regulation of gene expression in eukaryotes. In the standard model, methylation in gene promoters has received the most attention since it is generally associated with transcriptional silencing. Nevertheless, recent studies in human tissues reveal that methylation of the region downstream of the transcription start site is highly informative of gene expression. Also, in some cell types and specific genes it has been found that methylation of the first intron, a gene feature typically rich in enhancers, is linked with gene expression. However, a genome-wide, tissue-independent, systematic comparative analysis of the relationship between DNA methylation in the first intron and gene expression across vertebrates has not been explored yet. Results: The most important findings of this study are: (1) using different tissues from a modern fish, we show a clear genome-wide, tissue-independent quasi-linear inverse relationship between DNA methylation of the first intron and gene expression. (2) This relationship is conserved across vertebrates, since it is also present in the genomes of a model pufferfish, a model frog and different human tissues. Among the gene features, tissues and species interrogated, the first intron’s negative correlation with the gene expression was most consistent. (3) We identified more tissue-specific differentially methylated regions (tDMRs) in the first intron than in any other gene feature. These tDMRs have positive or negative correlation with gene expression, indicative of distinct mechanisms of tissue-specific regulation. (4) Lastly, we identified CpGs in transcription factor binding motifs, enriched in the first intron, the methylation of which tended to increase with the distance from the first exon–first intron boundary, with a concomitant decrease in gene expression. Conclusions: Our integrative analysis clearly reveals the important and conserved role of the methylation level of the first intron and its inverse association with gene expression regardless of tissue and species. These findings not only contribute to our basic understanding of the epigenetic regulation of gene expression but also identify the first intron as an informative gene feature regarding the relationship between DNA methylation and gene expression where future studies should be focused. Overall design: Genome wide DNA methylation and gene expression in testis and muscle of wild European sea bass (Dicentrarchus labrax)</td>
#       <td id="T_da924_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_da924_row0_col4" class="data row0 col4" >partial</td>
#       <td id="T_da924_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_da924_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_da924_row0_col7" class="data row0 col7" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_da924_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_da924_row0_col9" class="data row0 col9" >GSE104366</td>
#       <td id="T_da924_row0_col10" class="data row0 col10" >PRJNA412454</td>
#       <td id="T_da924_row0_col11" class="data row0 col11" >29958539</td>
#       <td id="T_da924_row0_col12" class="data row0 col12" >https://pmc.ncbi.nlm.nih.gov/articles/PMC6025724/</td>
#       <td id="T_da924_row0_col13" class="data row0 col13" >10.1186/s13072-018-0205-1</td>
#       <td id="T_da924_row0_col14" class="data row0 col14" >35741749[PMID]</td>
#       <td id="T_da924_row0_col15" class="data row0 col15" ></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### comments

# %%
experiment.loc[:,'comment'] = 'partial because bisulfite seq libaries were rejected'

display_df(experiment)
# Out:
# <div style='height: 300px; overflow: auto; width: fit-content'><style type="text/css">
# </style>
# <table id="T_996b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_996b9_level0_col0" class="col_heading level0 col0" >#experimentId</th>
#       <th id="T_996b9_level0_col1" class="col_heading level0 col1" >experimentName</th>
#       <th id="T_996b9_level0_col2" class="col_heading level0 col2" >experimentDescription</th>
#       <th id="T_996b9_level0_col3" class="col_heading level0 col3" >experimentSource</th>
#       <th id="T_996b9_level0_col4" class="col_heading level0 col4" >experimentStatus</th>
#       <th id="T_996b9_level0_col5" class="col_heading level0 col5" >projectTags</th>
#       <th id="T_996b9_level0_col6" class="col_heading level0 col6" >numberOfAnnotatedLibraries</th>
#       <th id="T_996b9_level0_col7" class="col_heading level0 col7" >protocol</th>
#       <th id="T_996b9_level0_col8" class="col_heading level0 col8" >protocolType</th>
#       <th id="T_996b9_level0_col9" class="col_heading level0 col9" >GSE</th>
#       <th id="T_996b9_level0_col10" class="col_heading level0 col10" >Bioproject</th>
#       <th id="T_996b9_level0_col11" class="col_heading level0 col11" >PMID</th>
#       <th id="T_996b9_level0_col12" class="col_heading level0 col12" >reference_url</th>
#       <th id="T_996b9_level0_col13" class="col_heading level0 col13" >DOI</th>
#       <th id="T_996b9_level0_col14" class="col_heading level0 col14" >xrefs</th>
#       <th id="T_996b9_level0_col15" class="col_heading level0 col15" >comment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_996b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_996b9_row0_col0" class="data row0 col0" >SRP119034</td>
#       <td id="T_996b9_row0_col1" class="data row0 col1" >Consistent inverse correlation between DNA methylation of the first intron and gene expression across tissues and species</td>
#       <td id="T_996b9_row0_col2" class="data row0 col2" >Background: DNA methylation is one of the main epigenetic mechanisms for the regulation of gene expression in eukaryotes. In the standard model, methylation in gene promoters has received the most attention since it is generally associated with transcriptional silencing. Nevertheless, recent studies in human tissues reveal that methylation of the region downstream of the transcription start site is highly informative of gene expression. Also, in some cell types and specific genes it has been found that methylation of the first intron, a gene feature typically rich in enhancers, is linked with gene expression. However, a genome-wide, tissue-independent, systematic comparative analysis of the relationship between DNA methylation in the first intron and gene expression across vertebrates has not been explored yet. Results: The most important findings of this study are: (1) using different tissues from a modern fish, we show a clear genome-wide, tissue-independent quasi-linear inverse relationship between DNA methylation of the first intron and gene expression. (2) This relationship is conserved across vertebrates, since it is also present in the genomes of a model pufferfish, a model frog and different human tissues. Among the gene features, tissues and species interrogated, the first intron’s negative correlation with the gene expression was most consistent. (3) We identified more tissue-specific differentially methylated regions (tDMRs) in the first intron than in any other gene feature. These tDMRs have positive or negative correlation with gene expression, indicative of distinct mechanisms of tissue-specific regulation. (4) Lastly, we identified CpGs in transcription factor binding motifs, enriched in the first intron, the methylation of which tended to increase with the distance from the first exon–first intron boundary, with a concomitant decrease in gene expression. Conclusions: Our integrative analysis clearly reveals the important and conserved role of the methylation level of the first intron and its inverse association with gene expression regardless of tissue and species. These findings not only contribute to our basic understanding of the epigenetic regulation of gene expression but also identify the first intron as an informative gene feature regarding the relationship between DNA methylation and gene expression where future studies should be focused. Overall design: Genome wide DNA methylation and gene expression in testis and muscle of wild European sea bass (Dicentrarchus labrax)</td>
#       <td id="T_996b9_row0_col3" class="data row0 col3" >SRA</td>
#       <td id="T_996b9_row0_col4" class="data row0 col4" >partial</td>
#       <td id="T_996b9_row0_col5" class="data row0 col5" >Bgee 1K</td>
#       <td id="T_996b9_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_996b9_row0_col7" class="data row0 col7" >TruSeq RNA Sample Preparation Kit</td>
#       <td id="T_996b9_row0_col8" class="data row0 col8" >full_length</td>
#       <td id="T_996b9_row0_col9" class="data row0 col9" >GSE104366</td>
#       <td id="T_996b9_row0_col10" class="data row0 col10" >PRJNA412454</td>
#       <td id="T_996b9_row0_col11" class="data row0 col11" >29958539</td>
#       <td id="T_996b9_row0_col12" class="data row0 col12" >https://pmc.ncbi.nlm.nih.gov/articles/PMC6025724/</td>
#       <td id="T_996b9_row0_col13" class="data row0 col13" >10.1186/s13072-018-0205-1</td>
#       <td id="T_996b9_row0_col14" class="data row0 col14" >35741749[PMID]</td>
#       <td id="T_996b9_row0_col15" class="data row0 col15" >partial because bisulfite seq libaries were rejected</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### save complete file

# %%
experiment.to_csv(experiment_to_add_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)

# %% [markdown]
# ### QA time

# %%
library_to_add = pd.read_csv(library_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
experiment_to_add = pd.read_csv(experiment_to_add_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# %%
! python3 $path_to_v_script --bulk-exp $experiment_to_add_path --bulk-lib $library_to_add_path --rules-dir $path_to_rules --out $val_output --strict
# Out:
# Total issues: 0
# Errors: 0
# Warnings: 0
# Top codes:

# %% [markdown]
# #### check columns match

# %%
# pull from git and pull in library/experiment file
! git pull
git_library = pd.read_csv(git_library_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)
git_experiment = pd.read_csv(git_experiment_path, sep='\t', index_col=False, keep_default_na=False, na_values=['NULL','null', 'nan','NaN'], dtype=object)

# library file
if set(library_to_add.columns) == set(git_library.columns):
    print('The columns in the library file match')
else:
    print('The columns in the library file DO NOT MATCH')

# experiment file
if set(experiment_to_add.columns) == set(git_experiment.columns):
    print('The columns in the experiment file match')
else:
    print('The columns in the experiment file DO NOT MATCH')


# maybe to make this something more like "COLUMNS GOOD - LIBRARY" and "COLUMNS BAD - EXPERIMENT"
# Out:
# Already up to date.
# The columns in the library file match
# The columns in the experiment file match

# %% [markdown]
# #### view files

# %%
library_git_plus_new = pd.concat([git_library, library_to_add], ignore_index = True, sort = False)
old_length = git_library.shape[0]
start = old_length - 2
end = old_length + 5
view_lib = library_git_plus_new.iloc[start:end]
view_lib
# Out:
#        #libraryId experimentId             platform       SRSId  \
# 65148  SRX2504443    SRP097118  Illumina HiSeq 2500  SRS1929278
# 65149  SRX2504442    SRP097118  Illumina HiSeq 2500  SRS1929277
# 65150  SRX3226020    SRP119034  Illumina HiSeq 2000  SRS2550629
# 65151  SRX3226019    SRP119034  Illumina HiSeq 2000  SRS2550628
# 65152  SRX3226018    SRP119034  Illumina HiSeq 2000  SRS2550626
# 65153  SRX3226017    SRP119034  Illumina HiSeq 2000  SRS2550627
# 65154  SRX3226016    SRP119034  Illumina HiSeq 2000  SRS2550625
#
#                anatId        anatName         stageId  \
# 65148  UBERON:0002264  olfactory bulb  UBERON:0034919
# 65149  UBERON:0002264  olfactory bulb  UBERON:0034919
# 65150  UBERON:0000473          testis  UBERON:0000113
# 65151  UBERON:0000473          testis  UBERON:0000113
# 65152  UBERON:0000473          testis  UBERON:0000113
# 65153  UBERON:0000473          testis  UBERON:0000113
# 65154  UBERON:0000473          testis  UBERON:0000113
#
#                        stageName  \
# 65148             juvenile stage
# 65149             juvenile stage
# 65150  post-juvenile adult stage
# 65151  post-juvenile adult stage
# 65152  post-juvenile adult stage
# 65153  post-juvenile adult stage
# 65154  post-juvenile adult stage
#
#                                                  url_GSM       infoOrgan  \
# 65148                                                     olfactory lobe
# 65149                                                     olfactory lobe
# 65150  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...          testis
# 65151  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...          testis
# 65152  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...          testis
# 65153  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...          testis
# 65154  http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?...          testis
#
#       infoStage anatAnnotationStatus anatBiologicalStatus  \
# 65148  juvenile        perfect match       not documented
# 65149  juvenile        perfect match       not documented
# 65150     adult        perfect match       not documented
# 65151     adult        perfect match       not documented
# 65152     adult        perfect match       not documented
# 65153     adult        perfect match       not documented
# 65154     adult        perfect match       not documented
#
#       stageAnnotationStatus sex strain genotype speciesId  \
# 65148         perfect match  NA                     13489
# 65149         perfect match  NA                     13489
# 65150         perfect match   M                     13489
# 65151         perfect match   M                     13489
# 65152         perfect match   M                     13489
# 65153         perfect match   M                     13489
# 65154         perfect match   M                     13489
#
#                                 protocol protocolType RNASelection  \
# 65148         NextFlex Rapid RNA-Seq Kit  full_length        polyA
# 65149         NextFlex Rapid RNA-Seq Kit  full_length        polyA
# 65150  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 65151  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 65152  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 65153  TruSeq RNA Sample Preparation Kit  full_length        polyA
# 65154  TruSeq RNA Sample Preparation Kit  full_length        polyA
#
#       globin_reduction replicate         lib_name               sampleName  \
# 65148                             lobe_7days_OA_3             SAMN06242025
# 65149                             lobe_7days_OA_4             SAMN06242026
# 65150                              Testis5-RNAseq  SAMN07714535,GSM2796110
# 65151                              Testis4-RNAseq  SAMN07714536,GSM2796109
# 65152                              Testis3-RNAseq  SAMN07714537,GSM2796108
# 65153                              Testis2-RNAseq  SAMN07714538,GSM2796107
# 65154                              Testis1-RNAseq  SAMN07714539,GSM2796106
#
#       sampleAge_value sampleAge_unit PATOid PATOname EFOid EFOname  \
# 65148
# 65149
# 65150
# 65151
# 65152
# 65153
# 65154
#
#                                                  comment        condition  \
# 65148  no PMID, see https://ore.exeter.ac.uk/articles...  High CO2 7 days
# 65149  no PMID, see https://ore.exeter.ac.uk/articles...  High CO2 7 days
# 65150                                     PMID: 29958539
# 65151                                     PMID: 29958539
# 65152                                     PMID: 29958539
# 65153                                     PMID: 29958539
# 65154                                     PMID: 29958539
#
#       physiologicalStatus annotatorId lastModificationDate
# 65148                             SAC           2026-06-03
# 65149                             SAC           2026-06-03
# 65150                             SAC           2026-06-08
# 65151                             SAC           2026-06-08
# 65152                             SAC           2026-06-08
# 65153                             SAC           2026-06-08
# 65154                             SAC           2026-06-08

# %%
experiment_git_plus_new = pd.concat([git_experiment, experiment_to_add], ignore_index = True, sort = False)
experiment_git_plus_new.tail(n=3)
# Out:
#      #experimentId                                     experimentName  \
# 1243     SRP071200  Dicentrarchus labrax Transcriptome or Gene exp...
# 1244     SRP097118  Near-future CO2 directly impairs the olfactory...
# 1245     SRP119034  Consistent inverse correlation between DNA met...
#
#                                   experimentDescription experimentSource  \
# 1243  The European sea bass (Dicentrarchus labrax) i...              SRA
# 1244  Simulated ocean acidification impairs the sens...              SRA
# 1245  Background: DNA methylation is one of the main...              SRA
#
#      experimentStatus projectTags numberOfAnnotatedLibraries  \
# 1243            total     Bgee 1K                          2
# 1244            total     Bgee 1K                         40
# 1245          partial     Bgee 1K                         10
#
#                                protocol protocolType        GSE   Bioproject  \
# 1243        TruSeq RNA Library Prep Kit  full_length             PRJNA314453
# 1244         NextFlex Rapid RNA-Seq Kit  full_length             PRJNA362551
# 1245  TruSeq RNA Sample Preparation Kit  full_length  GSE104366  PRJNA412454
#
#           PMID                                      reference_url  \
# 1243            https://sapientia.ualg.pt/bitstreams/c361cc2e-...
# 1244            https://ore.exeter.ac.uk/articles/journal_cont...
# 1245  29958539  https://pmc.ncbi.nlm.nih.gov/articles/PMC6025724/
#
#                                DOI           xrefs  \
# 1243  10.1016/j.margen.2017.05.002
# 1244        10.1594/PANGAEA.884674
# 1245     10.1186/s13072-018-0205-1  35741749[PMID]
#
#                                                 comment
# 1243                                            no PMID
# 1244                                            no PMID
# 1245  partial because bisulfite seq libaries were re...

# %% [markdown]
# ### add annotations to git

# %%
! git pull
# Out:
# Already up to date.

# %%
library_git_plus_new.to_csv(git_library_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
experiment_git_plus_new.to_csv(git_experiment_path, sep="\t", index=False, quoting=csv.QUOTE_ALL)
update_format(git_library_path)
update_format(git_experiment_path)

# %%
! git status

# %%
! git add $git_experiment_path $git_library_path

# %%
! git commit -m $commit_message_exp
# Out:
# [develop 7d7c365] adding annotated bulk experiment SRP119034
#  2 files changed, 11 insertions(+)

# %%
! git push
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 3.28 KiB | 839.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# remote:
# remote: To create a merge request for develop, visit:
# remote:   https://gitlab.sib.swiss/Bgee/expression-annotations/-/merge_requests/new?merge_request%5Bsource_branch%5D=develop
# remote:
# To https://gitlab.sib.swiss/Bgee/expression-annotations.git/
#    7dcf071..7d7c365  develop -> develop

# %% [markdown]
# ### add annotation folder and script to git

# %%
! git pull

# %% [markdown]
# 1. run first two cells (annotation summary)
# 2. export as html

# %%
! git add $path_to_output

# %%
! git commit -m $commit_message_py

# %%
! git push
